# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %%
csv_file = 'IHM10050180.csv'

# %%
custom_delimiter = ';'

# %%
cha_station4 = pd.read_csv(csv_file, delimiter=custom_delimiter)

# %%
cha_station4.to_csv('output.csv', index=False, sep=custom_delimiter)

# %%
cha_station4
# Out:
#           Reading values               Profile               Reading time  \
# 0                  0.000  InstantaneousProfile  2023-03-01T00:07:40+05:30
# 1                  0.000  InstantaneousProfile  2023-03-01T00:22:52+05:30
# 2                  0.000  InstantaneousProfile  2023-03-01T00:37:43+05:30
# 3                  0.000  InstantaneousProfile  2023-03-01T00:52:55+05:30
# 4                  0.000  InstantaneousProfile  2023-03-01T01:07:45+05:30
# ...                  ...                   ...                        ...
# 58252            235.290    Block Load Profile  2023-03-31T13:30:00+05:30
# 58253            235.370    Block Load Profile  2023-03-31T14:00:00+05:30
# 58254            230.890    Block Load Profile  2023-03-31T14:30:00+05:30
# 58255            228.550    Block Load Profile  2023-03-31T15:00:00+05:30
# 58256  1,677,609,701.000       Billing Profile  2023-03-01T00:11:41+05:30
#
#                      Insert time               Capture time        OBIS code  \
# 0      2023-03-01T00:01:21+05:30  2023-03-01T00:07:40+05:30    1-0:1.6.0*255
# 1      2023-03-01T00:16:33+05:30  2023-03-01T00:22:52+05:30    1-0:1.6.0*255
# 2      2023-03-01T00:31:24+05:30  2023-03-01T00:37:43+05:30    1-0:1.6.0*255
# 3      2023-03-01T00:46:36+05:30  2023-03-01T00:52:55+05:30    1-0:1.6.0*255
# 4      2023-03-01T01:01:26+05:30  2023-03-01T01:07:45+05:30    1-0:1.6.0*255
# ...                          ...                        ...              ...
# 58252  2023-03-31T13:46:24+05:30  2023-03-31T13:30:00+05:30  1-0:12.27.0*255
# 58253  2023-03-31T14:16:27+05:30  2023-03-31T14:00:00+05:30  1-0:12.27.0*255
# 58254  2023-03-31T14:46:29+05:30  2023-03-31T14:30:00+05:30  1-0:12.27.0*255
# 58255  2023-03-31T15:16:35+05:30  2023-03-31T15:00:00+05:30  1-0:12.27.0*255
# 58256  2023-03-01T00:05:24+05:30  2023-03-01T00:11:41+05:30    0-0:0.1.2*255
#
#       Unit  Transformer factor Status word Reading reason     Data source
# 0       kW                   1   No errors       Periodic  DLMS Connector
# 1       kW                   1   No errors       Periodic  DLMS Connector
# 2       kW                   1   No errors       Periodic  DLMS Connector
# 3       kW                   1   No errors       Periodic  DLMS Connector
# 4       kW                   1   No errors       Periodic  DLMS Connector
# ...    ...                 ...         ...            ...             ...
# 58252    V                   1   No errors       Periodic  DLMS Connector
# 58253    V                   1   No errors       Periodic  DLMS Connector
# 58254    V                   1   No errors       Periodic  DLMS Connector
# 58255    V                   1   No errors       Periodic  DLMS Connector
# 58256    s                   1   No errors       Periodic  DLMS Connector
#
# [58257 rows x 11 columns]

# %%
filter1 = cha_station4[cha_station4['Unit'] == 'kWh']

# %%
filter2 = filter1[filter1['Profile'] == 'InstantaneousProfile']

# %%
filter2
# Out:
#       Reading values               Profile               Reading time  \
# 5831       1,854.840  InstantaneousProfile  2023-03-01T00:07:40+05:30
# 5832       1,854.840  InstantaneousProfile  2023-03-01T00:22:52+05:30
# 5833       1,854.840  InstantaneousProfile  2023-03-01T00:37:43+05:30
# 5834       1,854.840  InstantaneousProfile  2023-03-01T00:52:55+05:30
# 5835       1,854.840  InstantaneousProfile  2023-03-01T01:07:45+05:30
# ...              ...                   ...                        ...
# 11661          0.000  InstantaneousProfile  2023-03-31T14:08:09+05:30
# 11662          0.000  InstantaneousProfile  2023-03-31T14:23:05+05:30
# 11663          0.000  InstantaneousProfile  2023-03-31T14:38:11+05:30
# 11664          0.000  InstantaneousProfile  2023-03-31T14:53:07+05:30
# 11665          0.000  InstantaneousProfile  2023-03-31T15:08:09+05:30
#
#                      Insert time               Capture time      OBIS code  \
# 5831   2023-03-01T00:01:21+05:30  2023-03-01T00:07:40+05:30  1-0:1.8.0*255
# 5832   2023-03-01T00:16:33+05:30  2023-03-01T00:22:52+05:30  1-0:1.8.0*255
# 5833   2023-03-01T00:31:24+05:30  2023-03-01T00:37:43+05:30  1-0:1.8.0*255
# 5834   2023-03-01T00:46:36+05:30  2023-03-01T00:52:55+05:30  1-0:1.8.0*255
# 5835   2023-03-01T01:01:26+05:30  2023-03-01T01:07:45+05:30  1-0:1.8.0*255
# ...                          ...                        ...            ...
# 11661  2023-03-31T14:01:12+05:30  2023-03-31T14:08:09+05:30  1-0:2.8.0*255
# 11662  2023-03-31T14:16:08+05:30  2023-03-31T14:23:05+05:30  1-0:2.8.0*255
# 11663  2023-03-31T14:31:14+05:30  2023-03-31T14:38:11+05:30  1-0:2.8.0*255
# 11664  2023-03-31T14:46:10+05:30  2023-03-31T14:53:07+05:30  1-0:2.8.0*255
# 11665  2023-03-31T15:01:12+05:30  2023-03-31T15:08:09+05:30  1-0:2.8.0*255
#
#       Unit  Transformer factor Status word Reading reason     Data source
# 5831   kWh                   1   No errors       Periodic  DLMS Connector
# 5832   kWh                   1   No errors       Periodic  DLMS Connector
# 5833   kWh                   1   No errors       Periodic  DLMS Connector
# 5834   kWh                   1   No errors       Periodic  DLMS Connector
# 5835   kWh                   1   No errors       Periodic  DLMS Connector
# ...    ...                 ...         ...            ...             ...
# 11661  kWh                   1   No errors       Periodic  DLMS Connector
# 11662  kWh                   1   No errors       Periodic  DLMS Connector
# 11663  kWh                   1   No errors       Periodic  DLMS Connector
# 11664  kWh                   1   No errors       Periodic  DLMS Connector
# 11665  kWh                   1   No errors       Periodic  DLMS Connector
#
# [5800 rows x 11 columns]

# %%
filter2['Reading time'] = pd.to_datetime(filter2['Reading time'])
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_27164\607307215.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter2['Reading time'] = pd.to_datetime(filter2['Reading time'])

# %%
filter2['Reading values'] = filter2['Reading values'].str.replace(',', '')
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_27164\3993206803.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter2['Reading values'] = filter2['Reading values'].str.replace(',', '')

# %%
filter2
# Out:
#       Reading values               Profile              Reading time  \
# 5831        1854.840  InstantaneousProfile 2023-03-01 00:07:40+05:30
# 5832        1854.840  InstantaneousProfile 2023-03-01 00:22:52+05:30
# 5833        1854.840  InstantaneousProfile 2023-03-01 00:37:43+05:30
# 5834        1854.840  InstantaneousProfile 2023-03-01 00:52:55+05:30
# 5835        1854.840  InstantaneousProfile 2023-03-01 01:07:45+05:30
# ...              ...                   ...                       ...
# 11661          0.000  InstantaneousProfile 2023-03-31 14:08:09+05:30
# 11662          0.000  InstantaneousProfile 2023-03-31 14:23:05+05:30
# 11663          0.000  InstantaneousProfile 2023-03-31 14:38:11+05:30
# 11664          0.000  InstantaneousProfile 2023-03-31 14:53:07+05:30
# 11665          0.000  InstantaneousProfile 2023-03-31 15:08:09+05:30
#
#                      Insert time               Capture time      OBIS code  \
# 5831   2023-03-01T00:01:21+05:30  2023-03-01T00:07:40+05:30  1-0:1.8.0*255
# 5832   2023-03-01T00:16:33+05:30  2023-03-01T00:22:52+05:30  1-0:1.8.0*255
# 5833   2023-03-01T00:31:24+05:30  2023-03-01T00:37:43+05:30  1-0:1.8.0*255
# 5834   2023-03-01T00:46:36+05:30  2023-03-01T00:52:55+05:30  1-0:1.8.0*255
# 5835   2023-03-01T01:01:26+05:30  2023-03-01T01:07:45+05:30  1-0:1.8.0*255
# ...                          ...                        ...            ...
# 11661  2023-03-31T14:01:12+05:30  2023-03-31T14:08:09+05:30  1-0:2.8.0*255
# 11662  2023-03-31T14:16:08+05:30  2023-03-31T14:23:05+05:30  1-0:2.8.0*255
# 11663  2023-03-31T14:31:14+05:30  2023-03-31T14:38:11+05:30  1-0:2.8.0*255
# 11664  2023-03-31T14:46:10+05:30  2023-03-31T14:53:07+05:30  1-0:2.8.0*255
# 11665  2023-03-31T15:01:12+05:30  2023-03-31T15:08:09+05:30  1-0:2.8.0*255
#
#       Unit  Transformer factor Status word Reading reason     Data source
# 5831   kWh                   1   No errors       Periodic  DLMS Connector
# 5832   kWh                   1   No errors       Periodic  DLMS Connector
# 5833   kWh                   1   No errors       Periodic  DLMS Connector
# 5834   kWh                   1   No errors       Periodic  DLMS Connector
# 5835   kWh                   1   No errors       Periodic  DLMS Connector
# ...    ...                 ...         ...            ...             ...
# 11661  kWh                   1   No errors       Periodic  DLMS Connector
# 11662  kWh                   1   No errors       Periodic  DLMS Connector
# 11663  kWh                   1   No errors       Periodic  DLMS Connector
# 11664  kWh                   1   No errors       Periodic  DLMS Connector
# 11665  kWh                   1   No errors       Periodic  DLMS Connector
#
# [5800 rows x 11 columns]

# %%
filter2['Reading values'] = filter2['Reading values'].astype(float)
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_27164\1969268204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter2['Reading values'] = filter2['Reading values'].astype(float)

# %%
filter3 = filter2.drop(columns= ['Insert time', 'Capture time','Profile','OBIS code','Transformer factor','Status word','Reading reason','Data source'])

# %%
filtered_march = filter3[filter3['Reading time'].dt.month == 3]

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit
# 5831          1854.84 2023-03-01 00:07:40+05:30  kWh
# 5832          1854.84 2023-03-01 00:22:52+05:30  kWh
# 5833          1854.84 2023-03-01 00:37:43+05:30  kWh
# 5834          1854.84 2023-03-01 00:52:55+05:30  kWh
# 5835          1854.84 2023-03-01 01:07:45+05:30  kWh
# ...               ...                       ...  ...
# 11661            0.00 2023-03-31 14:08:09+05:30  kWh
# 11662            0.00 2023-03-31 14:23:05+05:30  kWh
# 11663            0.00 2023-03-31 14:38:11+05:30  kWh
# 11664            0.00 2023-03-31 14:53:07+05:30  kWh
# 11665            0.00 2023-03-31 15:08:09+05:30  kWh
#
# [5800 rows x 3 columns]

# %%
filtered_march['Difference'] = filtered_march['Reading values'].diff()

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit  Difference
# 5831          1854.84 2023-03-01 00:07:40+05:30  kWh         NaN
# 5832          1854.84 2023-03-01 00:22:52+05:30  kWh         0.0
# 5833          1854.84 2023-03-01 00:37:43+05:30  kWh         0.0
# 5834          1854.84 2023-03-01 00:52:55+05:30  kWh         0.0
# 5835          1854.84 2023-03-01 01:07:45+05:30  kWh         0.0
# ...               ...                       ...  ...         ...
# 11661            0.00 2023-03-31 14:08:09+05:30  kWh         0.0
# 11662            0.00 2023-03-31 14:23:05+05:30  kWh         0.0
# 11663            0.00 2023-03-31 14:38:11+05:30  kWh         0.0
# 11664            0.00 2023-03-31 14:53:07+05:30  kWh         0.0
# 11665            0.00 2023-03-31 15:08:09+05:30  kWh         0.0
#
# [5800 rows x 4 columns]

# %%
filtered_march['Difference'] = filtered_march['Difference'].fillna(0)

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit  Difference
# 5831          1854.84 2023-03-01 00:07:40+05:30  kWh         0.0
# 5832          1854.84 2023-03-01 00:22:52+05:30  kWh         0.0
# 5833          1854.84 2023-03-01 00:37:43+05:30  kWh         0.0
# 5834          1854.84 2023-03-01 00:52:55+05:30  kWh         0.0
# 5835          1854.84 2023-03-01 01:07:45+05:30  kWh         0.0
# ...               ...                       ...  ...         ...
# 11661            0.00 2023-03-31 14:08:09+05:30  kWh         0.0
# 11662            0.00 2023-03-31 14:23:05+05:30  kWh         0.0
# 11663            0.00 2023-03-31 14:38:11+05:30  kWh         0.0
# 11664            0.00 2023-03-31 14:53:07+05:30  kWh         0.0
# 11665            0.00 2023-03-31 15:08:09+05:30  kWh         0.0
#
# [5800 rows x 4 columns]

# %%
has_negative_values = filtered_march['Difference'].any()
print(has_negative_values)
# Out:
# True

# %%
filtered_march['Difference'] = filtered_march['Difference'].fillna(0)

# %%
import numpy as np
filtered_march['Difference'] = filtered_march['Difference'].replace(np.nan, 0)

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit  Difference
# 5831          1854.84 2023-03-01 00:07:40+05:30  kWh         0.0
# 5832          1854.84 2023-03-01 00:22:52+05:30  kWh         0.0
# 5833          1854.84 2023-03-01 00:37:43+05:30  kWh         0.0
# 5834          1854.84 2023-03-01 00:52:55+05:30  kWh         0.0
# 5835          1854.84 2023-03-01 01:07:45+05:30  kWh         0.0
# ...               ...                       ...  ...         ...
# 11661            0.00 2023-03-31 14:08:09+05:30  kWh         0.0
# 11662            0.00 2023-03-31 14:23:05+05:30  kWh         0.0
# 11663            0.00 2023-03-31 14:38:11+05:30  kWh         0.0
# 11664            0.00 2023-03-31 14:53:07+05:30  kWh         0.0
# 11665            0.00 2023-03-31 15:08:09+05:30  kWh         0.0
#
# [5800 rows x 4 columns]

# %%
has_negative_values = filtered_march['Difference'].any()
print(has_negative_values)
# Out:
# True

# %%
negative_values = filtered_march['Difference'].where(filtered_march['Difference'] < 0)

print(negative_values)
# Out:
# 5831    NaN
# 5832    NaN
# 5833    NaN
# 5834    NaN
# 5835    NaN
#          ..
# 11661   NaN
# 11662   NaN
# 11663   NaN
# 11664   NaN
# 11665   NaN
# Name: Difference, Length: 5800, dtype: float64

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit  Difference
# 5831          1854.84 2023-03-01 00:07:40+05:30  kWh         0.0
# 5832          1854.84 2023-03-01 00:22:52+05:30  kWh         0.0
# 5833          1854.84 2023-03-01 00:37:43+05:30  kWh         0.0
# 5834          1854.84 2023-03-01 00:52:55+05:30  kWh         0.0
# 5835          1854.84 2023-03-01 01:07:45+05:30  kWh         0.0
# ...               ...                       ...  ...         ...
# 11661            0.00 2023-03-31 14:08:09+05:30  kWh         0.0
# 11662            0.00 2023-03-31 14:23:05+05:30  kWh         0.0
# 11663            0.00 2023-03-31 14:38:11+05:30  kWh         0.0
# 11664            0.00 2023-03-31 14:53:07+05:30  kWh         0.0
# 11665            0.00 2023-03-31 15:08:09+05:30  kWh         0.0
#
# [5800 rows x 4 columns]

# %%
def replace_negative_values(value):
    if value < 0:
        return 0
    else:
        return value

filtered_march['Difference'] = filtered_march['Difference'].apply(replace_negative_values)

# %%
filtered_march['Cumulative_Increase'] = filtered_march['Difference'].cumsum()

# %%
filtered_march["Time_Stamp"] = filtered_march["Reading time"].dt.strftime("%H-%M-%S")

# %%
total_energy_consumption = filtered_march["Difference"].sum()

# %%
total_energy_consumption
# Out:
# 562.8999999999999

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit  Difference  \
# 5831          1854.84 2023-03-01 00:07:40+05:30  kWh         0.0
# 5832          1854.84 2023-03-01 00:22:52+05:30  kWh         0.0
# 5833          1854.84 2023-03-01 00:37:43+05:30  kWh         0.0
# 5834          1854.84 2023-03-01 00:52:55+05:30  kWh         0.0
# 5835          1854.84 2023-03-01 01:07:45+05:30  kWh         0.0
# ...               ...                       ...  ...         ...
# 11661            0.00 2023-03-31 14:08:09+05:30  kWh         0.0
# 11662            0.00 2023-03-31 14:23:05+05:30  kWh         0.0
# 11663            0.00 2023-03-31 14:38:11+05:30  kWh         0.0
# 11664            0.00 2023-03-31 14:53:07+05:30  kWh         0.0
# 11665            0.00 2023-03-31 15:08:09+05:30  kWh         0.0
#
#        Cumulative_Increase Time_Stamp
# 5831                   0.0   00-07-40
# 5832                   0.0   00-22-52
# 5833                   0.0   00-37-43
# 5834                   0.0   00-52-55
# 5835                   0.0   01-07-45
# ...                    ...        ...
# 11661                562.9   14-08-09
# 11662                562.9   14-23-05
# 11663                562.9   14-38-11
# 11664                562.9   14-53-07
# 11665                562.9   15-08-09
#
# [5800 rows x 6 columns]

# %%
# Convert 'reading_time' column to datetime format
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Define tariff rates
tariff_rates = {
    'off-peak': 6,
    'peak': 8,
    'mid-peak': 7,
    'high-peak': 8
}

# Function to determine the tariff based on the time of day
def get_tariff(reading_time):
    hour = reading_time.hour
    if 23 <= hour or hour < 6:
        return 'off-peak'
    elif 7 <= hour < 11:
        return 'peak'
    elif 11 <= hour < 19:
        return 'mid-peak'
    else:
        return 'high-peak'

# Apply the get_tariff function to each row to get the tariff for each reading
filtered_march['tariff'] = filtered_march['Reading time'].apply(get_tariff)

# Calculate the price for each 15-minute interval
filtered_march['price'] = filtered_march.apply(lambda row: row['Difference'] * tariff_rates[row['tariff']], axis=1)

# %%
filtered_march.head(1000)
# Out:
#       Reading values              Reading time Unit  Difference  \
# 5831         1854.84 2023-03-01 00:07:40+05:30  kWh        0.00
# 5832         1854.84 2023-03-01 00:22:52+05:30  kWh        0.00
# 5833         1854.84 2023-03-01 00:37:43+05:30  kWh        0.00
# 5834         1854.84 2023-03-01 00:52:55+05:30  kWh        0.00
# 5835         1854.84 2023-03-01 01:07:45+05:30  kWh        0.00
# ...              ...                       ...  ...         ...
# 6826         2055.64 2023-03-11 11:37:43+05:30  kWh        0.38
# 6827         2056.04 2023-03-11 11:53:09+05:30  kWh        0.40
# 6828         2056.42 2023-03-11 12:07:46+05:30  kWh        0.38
# 6829         2056.82 2023-03-11 12:23:11+05:30  kWh        0.40
# 6830         2057.20 2023-03-11 12:37:53+05:30  kWh        0.38
#
#       Cumulative_Increase Time_Stamp    tariff  price
# 5831                 0.00   00-07-40  off-peak   0.00
# 5832                 0.00   00-22-52  off-peak   0.00
# 5833                 0.00   00-37-43  off-peak   0.00
# 5834                 0.00   00-52-55  off-peak   0.00
# 5835                 0.00   01-07-45  off-peak   0.00
# ...                   ...        ...       ...    ...
# 6826               200.80   11-37-43  mid-peak   2.66
# 6827               201.20   11-53-09  mid-peak   2.80
# 6828               201.58   12-07-46  mid-peak   2.66
# 6829               201.98   12-23-11  mid-peak   2.80
# 6830               202.36   12-37-53  mid-peak   2.66
#
# [1000 rows x 8 columns]

# %%
# Calculate the total of the 'price' column
total_price = filtered_march['price'].sum()
total_energy = filtered_march['Difference'].sum()
# Print the total
print(f"Total Energy :{round(total_energy,2)} Units")
print("Total Price Rs:", round(total_price,2))
# Out:
# Total Energy :562.9 Units
# Total Price Rs: 3987.4

# %%
peak_df = filtered_march[filtered_march['tariff'] == 'peak']

# Calculate the total energy consumed during peak hours
total_energy_consumed_peak = peak_df['Difference'].sum()

# Calculate the total price during peak hours
total_price_peak = peak_df['price'].sum()

# Print the results
print("Total Energy Consumed During Peak Hours:", round(total_energy_consumed_peak,2))
print("Total Price During Peak Hours:", round(total_price_peak,2))
# Out:
# Total Energy Consumed During Peak Hours: 89.27
# Total Price During Peak Hours: 714.16

# %%
# Filter rows for off-peak hours (assuming 'off-peak' corresponds to the off-peak hours)
off_peak_df = filtered_march[filtered_march['tariff'] == 'off-peak']

# Calculate the total energy consumed during off-peak hours
total_energy_consumed_off_peak = off_peak_df['Difference'].sum()

# Calculate the total price during off-peak hours
total_price_off_peak = off_peak_df['price'].sum()

# Print the results
print("Total Energy Consumed During Off-Peak Hours:", round(total_energy_consumed_off_peak,2))
print("Total Price During Off-Peak Hours:", round(total_price_off_peak,2))
# Out:
# Total Energy Consumed During Off-Peak Hours: 165.36
# Total Price During Off-Peak Hours: 992.16

# %%
# Filter rows for mid-peak hours (assuming 'mid-peak' corresponds to the mid-peak hours)
mid_peak_df = filtered_march[filtered_march['tariff'] == 'mid-peak']

# Calculate the total energy consumed during mid-peak hours
total_energy_consumed_mid_peak = mid_peak_df['Difference'].sum()

# Calculate the total price during mid-peak hours
total_price_mid_peak = mid_peak_df['price'].sum()

# Print the results
print("Total Energy Consumed During Mid-Peak Hours:", round(total_energy_consumed_mid_peak,2))
print("Total Price During Mid-Peak Hours:", round(total_price_mid_peak,2))
# Out:
# Total Energy Consumed During Mid-Peak Hours: 185.08
# Total Price During Mid-Peak Hours: 1295.56

# %%
# Filter rows for high-peak hours (assuming 'high-peak' corresponds to the high-peak hours)
high_peak_df = filtered_march[filtered_march['tariff'] == 'high-peak']

# Calculate the total energy consumed during high-peak hours
total_energy_consumed_high_peak = high_peak_df['Difference'].sum()

# Calculate the total price during high-peak hours
total_price_high_peak = high_peak_df['price'].sum()

# Print the results
print("Total Energy Consumed During High-Peak Hours:", round(total_energy_consumed_high_peak,2))
print("Total Price During High-Peak Hours:", round(total_price_high_peak,2))
# Out:
# Total Energy Consumed During High-Peak Hours: 123.19
# Total Price During High-Peak Hours: 985.52

# %%
Total_Energy_Consumption = total_energy_consumed_peak + total_energy_consumed_off_peak + total_energy_consumed_mid_peak +total_energy_consumed_high_peak

# %%
Total_Energy_Consumption
# Out:
# 562.8999999999999

# %%
Total_Price = total_price_peak + total_price_off_peak + total_price_mid_peak + total_price_high_peak

# %%
Total_Price
# Out:
# 3987.4000000000005

# %%
plt.figure(figsize=(12, 6))
plt.plot(filtered_march['Reading time'], filtered_march['Difference'], marker='o', linestyle='-')
plt.xlabel('Date')
plt.ylabel('Energy Usage')
plt.title('Energy Usage Trend for the Month')
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

plt.show()

# %%
# Price plot
plt.figure(figsize=(12, 6))
plt.plot(filtered_march['Reading time'], filtered_march['price'], marker='o', linestyle='-')
plt.xlabel('Reading time')
plt.ylabel('Energy Price based on TOD Tariff')
plt.title('Energy Price Vs Reading Time (based on TOD Tariff)')
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

plt.show()

# %%
total_energy = [total_energy_consumed_peak, total_energy_consumed_off_peak, total_energy_consumed_mid_peak, total_energy_consumed_high_peak]
tariff_categories = ['Peak', 'off-Peak', 'mid-Peak', 'High Peak']
# Create a bar plot
plt.figure(figsize=(4, 3))
plt.bar(tariff_categories, total_energy, color=['skyblue', 'lightgreen', 'lightcoral', 'gold'])
plt.xlabel('Time-of-Day ')
plt.ylabel('Total Energy Usage')
plt.title('Total Energy Usage by Time-of-Day ')
plt.show()

# %%
total_prices = [total_price_peak, total_price_off_peak, total_price_mid_peak, total_price_high_peak]
tariff_categories = ['Peak', 'off-Peak', 'mid-Peak', 'High Peak']
# Create a bar plot
plt.figure(figsize=(4, 3))
plt.bar(tariff_categories, total_prices, color=['yellow', 'blue', 'green', 'red'])
plt.xlabel('Time-of-Day ')
plt.ylabel('Total Price')
plt.title('Total Price based on Time-of-Day Tariff ')
plt.show()

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit  Difference  \
# 5831          1854.84 2023-03-01 00:07:40+05:30  kWh         0.0
# 5832          1854.84 2023-03-01 00:22:52+05:30  kWh         0.0
# 5833          1854.84 2023-03-01 00:37:43+05:30  kWh         0.0
# 5834          1854.84 2023-03-01 00:52:55+05:30  kWh         0.0
# 5835          1854.84 2023-03-01 01:07:45+05:30  kWh         0.0
# ...               ...                       ...  ...         ...
# 11661            0.00 2023-03-31 14:08:09+05:30  kWh         0.0
# 11662            0.00 2023-03-31 14:23:05+05:30  kWh         0.0
# 11663            0.00 2023-03-31 14:38:11+05:30  kWh         0.0
# 11664            0.00 2023-03-31 14:53:07+05:30  kWh         0.0
# 11665            0.00 2023-03-31 15:08:09+05:30  kWh         0.0
#
#        Cumulative_Increase Time_Stamp    tariff  price
# 5831                   0.0   00-07-40  off-peak    0.0
# 5832                   0.0   00-22-52  off-peak    0.0
# 5833                   0.0   00-37-43  off-peak    0.0
# 5834                   0.0   00-52-55  off-peak    0.0
# 5835                   0.0   01-07-45  off-peak    0.0
# ...                    ...        ...       ...    ...
# 11661                562.9   14-08-09  mid-peak    0.0
# 11662                562.9   14-23-05  mid-peak    0.0
# 11663                562.9   14-38-11  mid-peak    0.0
# 11664                562.9   14-53-07  mid-peak    0.0
# 11665                562.9   15-08-09  mid-peak    0.0
#
# [5800 rows x 8 columns]

# %%
# Filter data for the month of March
march_data = filtered_march[(filtered_march['Reading time'] >= '2023-03-01') & (filtered_march['Reading time'] < '2023-04-01')]

# Group by date and sum the energy usage for each day
daily_energy_usage = march_data.groupby(march_data['Reading time'].dt.date)['Difference'].sum()

# The result will be a Series with daily energy usage for each day in March
print(daily_energy_usage)
# Out:
# Reading time
# 2023-03-01    18.99
# 2023-03-02    17.07
# 2023-03-03    24.65
# 2023-03-04    28.18
# 2023-03-05    21.70
# 2023-03-06    13.84
# 2023-03-07    16.73
# 2023-03-08    17.62
# 2023-03-09    21.45
# 2023-03-10    17.18
# 2023-03-11    13.47
# 2023-03-12     6.39
# 2023-03-13    23.35
# 2023-03-14    18.86
# 2023-03-15    30.70
# 2023-03-16    30.99
# 2023-03-17    24.62
# 2023-03-18    29.60
# 2023-03-19    27.54
# 2023-03-20    22.37
# 2023-03-21    21.27
# 2023-03-22     0.12
# 2023-03-23     6.60
# 2023-03-24    24.33
# 2023-03-25    14.75
# 2023-03-26     6.07
# 2023-03-27    14.61
# 2023-03-28    15.89
# 2023-03-29    16.19
# 2023-03-30    15.80
# 2023-03-31     1.97
# Name: Difference, dtype: float64

# %%
# Filter data for the month of March
march_data = filtered_march[(filtered_march['Reading time'] >= '2023-03-01') & (filtered_march['Reading time'] < '2023-04-01')]

# Group by date and sum the price based on tod for each day
daily_energy_pricing = march_data.groupby(march_data['Reading time'].dt.date)['price'].sum()

# The result will be a Series with daily energy usage for each day in March
print(daily_energy_pricing)
# Out:
# Reading time
# 2023-03-01    141.14
# 2023-03-02    114.40
# 2023-03-03    171.97
# 2023-03-04    198.18
# 2023-03-05    152.50
# 2023-03-06    101.36
# 2023-03-07    122.50
# 2023-03-08    122.45
# 2023-03-09    153.43
# 2023-03-10    123.85
# 2023-03-11     98.46
# 2023-03-12     45.55
# 2023-03-13    166.82
# 2023-03-14    134.73
# 2023-03-15    213.41
# 2023-03-16    219.73
# 2023-03-17    170.80
# 2023-03-18    207.32
# 2023-03-19    191.28
# 2023-03-20    154.60
# 2023-03-21    147.08
# 2023-03-22      0.83
# 2023-03-23     51.44
# 2023-03-24    170.25
# 2023-03-25    101.34
# 2023-03-26     44.76
# 2023-03-27    105.45
# 2023-03-28    111.84
# 2023-03-29    120.47
# 2023-03-30    116.11
# 2023-03-31     13.35
# Name: price, dtype: float64

# %%
# Create a bar plot
plt.figure(figsize=(12, 6))
plt.bar(daily_energy_usage.index, daily_energy_usage.values, color='b')
plt.title('Daily Energy Usage in March 2023')
plt.xlabel('Date')
plt.ylabel('Energy Usage')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Create a bar plot
plt.figure(figsize=(12, 6))
plt.bar(daily_energy_pricing.index, daily_energy_pricing.values, color='g')
plt.title('Daily Pricing in March 2023')
plt.xlabel('Date')
plt.ylabel('Energy Usage')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
mean_energy_usage = daily_energy_usage.mean()

# Calculate the median of daily energy usage
median_energy_usage = daily_energy_usage.median()

# Calculate the standard deviation of daily energy usage
std_deviation_energy_usage = daily_energy_usage.std()

# Print the results
print(f"Mean Energy Usage: {mean_energy_usage:.2f}")
print(f"Median Energy Usage: {median_energy_usage:.2f}")
print(f"Standard Deviation of Energy Usage: {std_deviation_energy_usage:.2f}")
# Out:
# Mean Energy Usage: 18.16
# Median Energy Usage: 17.62
# Standard Deviation of Energy Usage: 8.02

# %%
mean_energy_pricing = daily_energy_pricing.mean()

# Calculate the median of daily energy usage
median_energy_pricing = daily_energy_pricing.median()

# Calculate the standard deviation of daily energy usage
std_deviation_energy_pricing = daily_energy_pricing.std()

# Print the results
print(f"Mean Energy Pricing: {mean_energy_pricing:.2f}")
print(f"Median Energy Pricing: {median_energy_pricing:.2f}")
print(f"Standard Deviation of Energy pricing: {std_deviation_energy_pricing:.2f}")
# Out:
# Mean Energy Pricing: 128.63
# Median Energy Pricing: 123.85
# Standard Deviation of Energy pricing: 55.66

# %%
import seaborn as sns

# Create a density plot (KDE)
plt.figure(figsize=(3, 3))
sns.histplot(daily_energy_usage, kde=True, color='skyblue')
plt.title('Density Plot of Daily Energy Usage')
plt.xlabel('Energy Usage')
plt.ylabel('Density')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\et22m\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import seaborn as sns

# Create a density plot (KDE)
plt.figure(figsize=(3, 3))
sns.histplot(daily_energy_pricing, kde=True, color='green')
plt.title('Density Plot of Daily Energy Usage Pricing')
plt.xlabel('Energy Usage Pricing based on TOD')
plt.ylabel('Density')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Calculate the day of the week for each data point (0 = Monday, 6 = Sunday)
filtered_march['Day_of_Week'] = filtered_march['Reading time'].dt.dayofweek

# Group data by the day of the week and calculate the mean energy usage
sum_energy_by_day = filtered_march.groupby('Day_of_Week')['Difference'].sum()

# Define the day names for plotting
day_names = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
print(sum_energy_by_day)
# Out:
# Day_of_Week
# 0    74.17
# 1    72.75
# 2    83.62
# 3    91.91
# 4    92.75
# 5    86.00
# 6    61.70
# Name: Difference, dtype: float64

# %%
# Create a bar plot to visualize mean energy usage by day
plt.figure(figsize=(7, 5))
plt.bar(day_names, sum_energy_by_day, color='green')
plt.title('Sum of Energy Usage by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Sum Energy Usage')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Calculate the day of the week for each data point (0 = Monday, 6 = Sunday)
filtered_march['Day_of_Week'] = filtered_march['Reading time'].dt.dayofweek

# Group data by the day of the week and calculate the mean energy usage
sum_energy_price_by_day = filtered_march.groupby('Day_of_Week')['price'].sum()

# Define the day names for plotting
day_names = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
print(sum_energy_price_by_day)
# Out:
# Day_of_Week
# 0    528.23
# 1    516.15
# 2    598.30
# 3    655.11
# 4    650.22
# 5    605.30
# 6    434.09
# Name: price, dtype: float64

# %%
# Create a bar plot to visualize mean energy usage by day
plt.figure(figsize=(7, 5))
plt.bar(day_names, sum_energy_price_by_day, color='yellow')
plt.title('Sum of Energy Price by Day of the Week(TOD)')
plt.xlabel('Day of the Week')
plt.ylabel('Sum Energy Price')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
filtered_march['Weekday_Or_Weekend'] = filtered_march['Day_of_Week'].apply(lambda x: 'Weekend' if x >= 5 else 'Weekday')

# Calculate the average energy usage for weekdays and weekends
average_energy_by_category = filtered_march.groupby('Weekday_Or_Weekend')['Difference'].mean()

# Display the result
print(average_energy_by_category)
# Out:
# Weekday_Or_Weekend
# Weekday    0.097237
# Weekend    0.096536
# Name: Difference, dtype: float64

# %%
filtered_march['Weekday_Or_Weekend'] = filtered_march['Day_of_Week'].apply(lambda x: 'Weekend' if x >= 5 else 'Weekday')

# Calculate the average energy usage for weekdays and weekends
average_energy_by_category_sum = filtered_march.groupby('Weekday_Or_Weekend')['Difference'].sum()

# Display the result
print(average_energy_by_category_sum)
# Out:
# Weekday_Or_Weekend
# Weekday    415.2
# Weekend    147.7
# Name: Difference, dtype: float64

# %%
filtered_march['Weekday_Or_Weekend'] = filtered_march['Day_of_Week'].apply(lambda x: 'Weekend' if x >= 5 else 'Weekday')

# Calculate the average energy usage(price) for weekdays and weekends
average_energy_by_category_mean = filtered_march.groupby('Weekday_Or_Weekend')['price'].mean()

# Display the result
print(average_energy_by_category_mean)
# Out:
# Weekday_Or_Weekend
# Weekday    0.69040
# Weekend    0.67934
# Name: price, dtype: float64

# %%
filtered_march['Weekday_Or_Weekend'] = filtered_march['Day_of_Week'].apply(lambda x: 'Weekend' if x >= 5 else 'Weekday')

# Calculate the sum energy usage (price)for weekdays and weekends
average_energy_by_category_sum_price = filtered_march.groupby('Weekday_Or_Weekend')['price'].sum()

# Display the result
print(average_energy_by_category_sum_price)
# Out:
# Weekday_Or_Weekend
# Weekday    2948.01
# Weekend    1039.39
# Name: price, dtype: float64

# %%
from scipy import stats

# %%
weekday_data = filtered_march[filtered_march['Weekday_Or_Weekend'] == 'Weekday']['Difference']
weekend_data = filtered_march[filtered_march['Weekday_Or_Weekend'] == 'Weekend']['Difference']

# Perform a t-test to compare the means of the two groups
t_stat, p_value = stats.ttest_ind(weekday_data, weekend_data)

# Set the significance level (alpha)
alpha = 0.05

# Check if the p-value is less than alpha (indicating statistical significance)
if p_value < alpha:
    print("There is a statistically significant difference in energy consumption between weekdays and weekends.")
else:
    print("There is no statistically significant difference in energy consumption between weekdays and weekends.")
# Out:
# There is no statistically significant difference in energy consumption between weekdays and weekends.

# %%
daily_energy_usage = filtered_march.groupby(filtered_march['Reading time'].dt.date)['Difference'].sum()

# Compute basic statistics
mean_energy = daily_energy_usage.mean()
std_deviation_energy = daily_energy_usage.std()

# %%
threshold_high = mean_energy + 1 * std_deviation_energy
threshold_low = mean_energy - 1 * std_deviation_energy
print(threshold_high)
print(threshold_high)
# Out:
# 26.182560520803193
# 26.182560520803193

# %%
# Detect days with exceptionally high energy usage
high_energy_days = daily_energy_usage[daily_energy_usage > threshold_high]
print(high_energy_days)
# Detect days with exceptionally low energy usage
low_energy_days = daily_energy_usage[daily_energy_usage < threshold_low]
print(low_energy_days)
# Out:
# Reading time
# 2023-03-04    28.18
# 2023-03-15    30.70
# 2023-03-16    30.99
# 2023-03-18    29.60
# 2023-03-19    27.54
# Name: Difference, dtype: float64
# Reading time
# 2023-03-12    6.39
# 2023-03-22    0.12
# 2023-03-23    6.60
# 2023-03-26    6.07
# 2023-03-31    1.97
# Name: Difference, dtype: float64

# %%
plt.figure(figsize=(31, 6))
plt.plot(daily_energy_usage.index, daily_energy_usage.values, marker='o', linestyle='-', color='b', label='Daily Energy Usage')

# Scatter plot for high energy days (in red)
plt.scatter(high_energy_days.index, high_energy_days.values, color='red', marker='*', label='High Energy Days')

# Scatter plot for low energy days (in green)
plt.scatter(low_energy_days.index, low_energy_days.values, color='green', marker='*', label='Low Energy Days')

plt.title('Daily Energy Usage with Anomalous Days')
plt.xlabel('Date')
plt.ylabel('Energy Usage')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit  Difference  \
# 5831          1854.84 2023-03-01 00:07:40+05:30  kWh         0.0
# 5832          1854.84 2023-03-01 00:22:52+05:30  kWh         0.0
# 5833          1854.84 2023-03-01 00:37:43+05:30  kWh         0.0
# 5834          1854.84 2023-03-01 00:52:55+05:30  kWh         0.0
# 5835          1854.84 2023-03-01 01:07:45+05:30  kWh         0.0
# ...               ...                       ...  ...         ...
# 11661            0.00 2023-03-31 14:08:09+05:30  kWh         0.0
# 11662            0.00 2023-03-31 14:23:05+05:30  kWh         0.0
# 11663            0.00 2023-03-31 14:38:11+05:30  kWh         0.0
# 11664            0.00 2023-03-31 14:53:07+05:30  kWh         0.0
# 11665            0.00 2023-03-31 15:08:09+05:30  kWh         0.0
#
#        Cumulative_Increase Time_Stamp    tariff  price  Day_of_Week  \
# 5831                   0.0   00-07-40  off-peak    0.0            2
# 5832                   0.0   00-22-52  off-peak    0.0            2
# 5833                   0.0   00-37-43  off-peak    0.0            2
# 5834                   0.0   00-52-55  off-peak    0.0            2
# 5835                   0.0   01-07-45  off-peak    0.0            2
# ...                    ...        ...       ...    ...          ...
# 11661                562.9   14-08-09  mid-peak    0.0            4
# 11662                562.9   14-23-05  mid-peak    0.0            4
# 11663                562.9   14-38-11  mid-peak    0.0            4
# 11664                562.9   14-53-07  mid-peak    0.0            4
# 11665                562.9   15-08-09  mid-peak    0.0            4
#
#       Weekday_Or_Weekend
# 5831             Weekday
# 5832             Weekday
# 5833             Weekday
# 5834             Weekday
# 5835             Weekday
# ...                  ...
# 11661            Weekday
# 11662            Weekday
# 11663            Weekday
# 11664            Weekday
# 11665            Weekday
#
# [5800 rows x 10 columns]

# %%
# Convert the "Reading Time" column to a datetime object
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Extract the date and hour from the timestamp
filtered_march['Date'] = filtered_march['Reading time'].dt.date
filtered_march['Hour'] = filtered_march['Reading time'].dt.hour

# Group the data by Date and Hour, and sum the energy usage for each hour
hourly_energy_usageev2 = filtered_march.groupby(['Date', 'Hour'])['Difference'].sum()

hourly_energy_usageev2 = hourly_energy_usageev2.reset_index()

# %%
hourly_energy_usageev2
hourly_energy_usageev2.to_csv("hourly_energy_usageev2.csv", index=False)

# %%
filtered_march['Hour'] = filtered_march['Reading time'].dt.hour

# Group the data by Hour and sum the energy usage for each hour over the entire 31 days
hourly_energy_usage1ev2 = filtered_march.groupby('Hour')['Difference'].sum()

# Reset the index to make it a DataFrame
hourly_energy_usage1ev2 = hourly_energy_usage1ev2.reset_index()

# Save the result to a new CSV file
hourly_energy_usage1ev2.to_csv("hourly_energy_usage_over_31_daysev2.csv", index=False)

# %%
hourly_energy_usage1ev2
# Out:
#     Hour  Difference
# 0      0       25.18
# 1      1       21.64
# 2      2       24.26
# 3      3       25.49
# 4      4       23.36
# 5      5       18.50
# 6      6       16.06
# 7      7       22.18
# 8      8       23.22
# 9      9       22.90
# 10    10       20.97
# 11    11       30.85
# 12    12       21.60
# 13    13       17.81
# 14    14       23.72
# 15    15       24.00
# 16    16       24.79
# 17    17       22.41
# 18    18       19.90
# 19    19       24.82
# 20    20       27.36
# 21    21       31.69
# 22    22       23.26
# 23    23       26.93

# %%
total_energy_usage = filtered_march['Difference'].sum()

# %%
total_energy_usage
# Out:
# 562.8999999999999

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame called 'filtered_march' with columns 'Reading time' and 'Difference'
# Convert 'Reading time' to a datetime format
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Group the data by day and hour
filtered_march['date'] = filtered_march['Reading time'].dt.date
filtered_march['hour'] = filtered_march['Reading time'].dt.hour
hourly_usage = filtered_march.groupby(['date', 'hour'])['Difference'].sum()

# Pivot the data to have days on the y-axis and hours on the x-axis
hourly_usage_pivot = hourly_usage.unstack(level='date').fillna(0)

# Create a heatmap to visualize the data with red shades and white cell borders
plt.figure(figsize=(12, 6))
sns.heatmap(hourly_usage_pivot, cmap='Reds', cbar_kws={'label': 'Energy Usage (kWh)'},
            linewidths=0.5, linecolor='white')

# Customize the plot

plt.xlabel('Date')
plt.ylabel('Hour of the Day')

# Format x-axis labels to include both day and month
date_labels = [f"{d.day} {d.strftime('%B')}" for d in hourly_usage_pivot.columns]
plt.xticks(ticks=range(len(hourly_usage_pivot.columns)), labels=date_labels, rotation=45)

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Patch

# Assuming you have a DataFrame called 'filtered_march' with columns 'Reading time' and 'Difference'
# Convert 'Reading time' to a datetime format
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Group the data by day and hour
filtered_march['date'] = filtered_march['Reading time'].dt.date
filtered_march['hour'] = filtered_march['Reading time'].dt.hour
hourly_usage = filtered_march.groupby(['date', 'hour'])['Difference'].sum()

# Pivot the data to have days on the y-axis and hours on the x-axis
hourly_usage_pivot = hourly_usage.unstack(level='date').fillna(0)

# Create a line plot to visualize the data
plt.figure(figsize=(12, 8))
sns.set(style="whitegrid")

# Plot a line for each day with distinct colors
colors = sns.color_palette("husl", n_colors=len(hourly_usage_pivot.columns))
for i, date in enumerate(hourly_usage_pivot.columns):
    plt.plot(hourly_usage_pivot.index, hourly_usage_pivot[date], color=colors[i], linewidth=2)

# Create custom legend with colored bars
legend_labels = [date.strftime('%d %B') for date in hourly_usage_pivot.columns]
legend_handles = [Patch(color=colors[i], label=label) for i, label in enumerate(legend_labels)]

# Add the legend with colored bars in a matrix format
plt.legend(handles=legend_handles, title='Date', title_fontsize='12', fontsize='10', bbox_to_anchor=(1.05, 1), loc='upper left', ncol=2)  # Set ncol to the number of columns you desire

# Customize plot details
plt.title('Hourly Energy Usage for Charging Station', fontsize=16)
plt.xlabel('Hour of the Day', fontsize=14)
plt.ylabel('Energy Usage (kWh)', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Assuming your DataFrame is named filtered_march

# Convert 'Reading time' to Timestamp with the same timezone
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Define the date for March 8th and March 22nd
march_8_date = pd.Timestamp('2023-03-08', tz='Asia/Kolkata')
march_22_date = pd.Timestamp('2023-03-22', tz='Asia/Kolkata')

# Mark March 8th and March 22nd as holidays
filtered_march['Holiday'] = 'Other Days'
filtered_march.loc[filtered_march['Reading time'].dt.date.isin([march_8_date.date(), march_22_date.date()]), 'Holiday'] = 'Holiday'

# Calculate total energy consumption on holidays
holiday_energy_consumption = filtered_march[
    (filtered_march['Holiday'] == 'Holiday')
]['Difference'].sum()

# Calculate total energy consumption on other days
other_days_energy_consumption = filtered_march[
    (filtered_march['Holiday'] == 'Other Days')
]['Difference'].sum()

# Display the total energy consumption
print(f'Total Energy Consumption on Holidays: {holiday_energy_consumption} units')
print(f'Total Energy Consumption on Other Days: {other_days_energy_consumption} units')
# Out:
# Total Energy Consumption on Holidays: 17.740000000000236 units
# Total Energy Consumption on Other Days: 545.1599999999996 units

# %%
# Assuming your DataFrame is named filtered_march

# Convert 'Reading time' to Timestamp with the same timezone
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Define the date for March 8th and March 22nd
march_8_date = pd.Timestamp('2023-03-08', tz='Asia/Kolkata')
march_22_date = pd.Timestamp('2023-03-22', tz='Asia/Kolkata')

# Mark March 8th and March 22nd as holidays
filtered_march['Holiday'] = 'Other Days'
filtered_march.loc[filtered_march['Reading time'].dt.date.isin([march_8_date.date(), march_22_date.date()]), 'Holiday'] = 'Holiday'

# Calculate average energy consumption on holidays and other days
average_holiday_consumption = filtered_march[filtered_march['Holiday'] == 'Holiday']['Difference'].mean()
average_other_days_consumption = filtered_march[filtered_march['Holiday'] == 'Other Days']['Difference'].mean()

# Display the average energy consumption
print(f'Average Energy Consumption on Holidays: {average_holiday_consumption} units')
print(f'Average Energy Consumption on Other Days: {average_other_days_consumption} units')

# Check if holiday consumption is higher than normal
if average_holiday_consumption > average_other_days_consumption:
    print('Holiday consumption is higher than normal.')
else:
    print('Holiday consumption is normal or lower than normal.')
# Out:
# Average Energy Consumption on Holidays: 0.049277777777778434 units
# Average Energy Consumption on Other Days: 0.10021323529411758 units
# Holiday consumption is normal or lower than normal.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named filtered_march

# Convert 'Reading time' to Timestamp with the same timezone
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Define the date for March 8th and March 22nd
march_8_date = pd.Timestamp('2023-03-08', tz='Asia/Kolkata')
march_22_date = pd.Timestamp('2023-03-22', tz='Asia/Kolkata')

# Mark March 8th and March 22nd as holidays
filtered_march['Holiday'] = 'Other Days'
filtered_march.loc[filtered_march['Reading time'].dt.date.isin([march_8_date.date(), march_22_date.date()]), 'Holiday'] = 'Holiday'

# Set the style of seaborn for better aesthetics
sns.set(style="whitegrid")

# Plot the hourly consumption pattern
plt.figure(figsize=(12, 6))
sns.lineplot(x=filtered_march['Hour'], y=filtered_march['Difference'], hue=filtered_march['Holiday'], ci=None)
plt.title('Hourly Energy Consumption Pattern on Holidays and Other Days')
plt.xlabel('Hour of the Day')
plt.ylabel('Energy Consumption(kWh)')
plt.legend(title='Day Type')
plt.show()

# %%
import pandas as pd

# Assuming your DataFrame is named filtered_march

# Convert 'Reading time' to Timestamp with the same timezone
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Define the date for March 8th and March 22nd
march_8_date = pd.Timestamp('2023-03-08', tz='Asia/Kolkata')
march_22_date = pd.Timestamp('2023-03-22', tz='Asia/Kolkata')

# Mark March 8th and March 22nd as holidays
filtered_march['Holiday'] = 'Other Days'
filtered_march.loc[filtered_march['Reading time'].dt.date.isin([march_8_date.date(), march_22_date.date()]), 'Holiday'] = 'Holiday'

# Filter data for holidays only
holiday_data = filtered_march[filtered_march['Holiday'] == 'Holiday']

# Find the hour with the highest energy consumption on holidays
max_hour_holiday = holiday_data.loc[holiday_data['Difference'].idxmax()]['Hour']

# Display the result
print(f'Time of the day with the highest energy consumption on holidays: {max_hour_holiday} hours')
# Out:
# Time of the day with the highest energy consumption on holidays: 11 hours

# %%
# Resample the data on a daily basis and sum the 'Difference' values for each day
daily_df = filtered_march.resample('D', on='Reading time').sum()

# Calculate summary statistics for daily energy consumption
mean_daily_energy = daily_df['Difference'].mean()
median_daily_energy = daily_df['Difference'].median()
std_dev_daily_energy = daily_df['Difference'].std()

# Display the summary statistics for daily energy consumption
print(f'Mean Daily Energy Consumption: {mean_daily_energy}')
print(f'Median Daily Energy Consumption: {median_daily_energy}')
print(f'Standard Deviation of Daily Energy Consumption: {std_dev_daily_energy}')
# Out:
# Mean Daily Energy Consumption: 18.158064516129027
# Median Daily Energy Consumption: 17.61999999999989
# Standard Deviation of Daily Energy Consumption: 8.024496004674168

# %%
import pandas as pd

# Assuming your DataFrame is called 'filtered_march'

# Initialize variables
charging_sessions = 0
charging = False

# Iterate through the DataFrame
for index, row in filtered_march.iterrows():
    diff = row['Difference']
    
    # Check if the current value is greater than 0 and not currently charging
    if diff > 0 and not charging:
        charging_sessions += 1
        charging = True
    elif diff == 0 and charging:
        charging = False

# Print the result
print("Total number of charging sessions:", charging_sessions)
# Out:
# Total number of charging sessions: 210

# %%
import pandas as pd

# Assuming your DataFrame is called 'filtered_march'

# Initialize variables
charging_sessions = 0
charging = False
total_sessions_greater_than_025 = 0

# Iterate through the DataFrame
for index, row in filtered_march.iterrows():
    diff = row['Difference']
    
    # Check if the current value is greater than 0 and not currently charging
    if diff > 0 and not charging:
        charging_sessions += 1
        charging = True
        energy_in_session = diff
    elif diff > 0 and charging:
        energy_in_session += diff
    elif diff == 0 and charging:
        charging = False
        print(f"Energy consumption in session {charging_sessions}: {energy_in_session}")
        
        # Check if the energy consumption in the session is greater than 0.25
        if energy_in_session > 0.25:
            total_sessions_greater_than_025 += 1

# Check if the last session is still ongoing and if the total energy consumption in the session is greater than 0.25
if charging and energy_in_session > 0.25:
    print(f"Energy consumption in session {charging_sessions}: {energy_in_session}")
    total_sessions_greater_than_025 += 1

# Print the total number of sessions where energy consumption is greater than 0.25
print("Total number of sessions where energy consumption is greater than 0.25:", total_sessions_greater_than_025)
# Out:
# Energy consumption in session 1: 7.650000000000091
# Energy consumption in session 2: 2.150000000000091
# Energy consumption in session 3: 5.649999999999864
# Energy consumption in session 4: 1.3500000000001364
# Energy consumption in session 5: 8.459999999999809
# Energy consumption in session 6: 0.009999999999990905
# Energy consumption in session 7: 0.009999999999990905
# Energy consumption in session 8: 2.0700000000001637
# Energy consumption in session 9: 4.4500000000000455
# Energy consumption in session 10: 1.2999999999999545
# Energy consumption in session 11: 5.4500000000000455
# Energy consumption in session 12: 6.939999999999827
# Energy consumption in session 13: 3.759999999999991
# Energy consumption in session 14: 4.8900000000001
# Energy consumption in session 15: 0.599999999999909
# Energy consumption in session 16: 23.710000000000036
# Energy consumption in session 17: 1.740000000000009
# Energy consumption in session 18: 3.759999999999991
# Energy consumption in session 19: 13.039999999999964
# Energy consumption in session 20: 4.460000000000036
# Energy consumption in session 21: 2.910000000000082
# Energy consumption in session 22: 0.5399999999999636
# Energy consumption in session 23: 6.319999999999936
# Energy consumption in session 24: 0.009999999999990905
# Energy consumption in session 25: 0.009999999999990905
# Energy consumption in session 26: 0.5299999999999727
# Energy consumption in session 27: 0.25
# Energy consumption in session 28: 0.2800000000002001
# Energy consumption in session 29: 0.2699999999999818
# Energy consumption in session 30: 5.389999999999873
# Energy consumption in session 31: 1.0699999999999363
# Energy consumption in session 32: 0.10000000000013642
# Energy consumption in session 33: 5.670000000000073
# Energy consumption in session 34: 0.009999999999990905
# Energy consumption in session 35: 0.009999999999990905
# Energy consumption in session 36: 0.009999999999990905
# Energy consumption in session 37: 0.4600000000000364
# Energy consumption in session 38: 0.2999999999999545
# Energy consumption in session 39: 0.2400000000000091
# Energy consumption in session 40: 0.30999999999994543
# Energy consumption in session 41: 5.819999999999936
# Energy consumption in session 42: 1.1300000000001091
# Energy consumption in session 43: 0.2599999999999909
# Energy consumption in session 44: 0.2300000000000182
# Energy consumption in session 45: 10.909999999999854
# Energy consumption in session 46: 0.009999999999990905
# Energy consumption in session 47: 0.5
# Energy consumption in session 48: 2.880000000000109
# Energy consumption in session 49: 0.2699999999999818
# Energy consumption in session 50: 5.7000000000000455
# Energy consumption in session 51: 9.889999999999873
# Energy consumption in session 52: 0.009999999999990905
# Energy consumption in session 53: 4.310000000000173
# Energy consumption in session 54: 6.5499999999999545
# Energy consumption in session 55: 0.2400000000000091
# Energy consumption in session 56: 5.899999999999864
# Energy consumption in session 57: 3.0
# Energy consumption in session 58: 0.5199999999999818
# Energy consumption in session 59: 0.2800000000002001
# Energy consumption in session 60: 0.2699999999999818
# Energy consumption in session 61: 4.269999999999982
# Energy consumption in session 62: 1.0
# Energy consumption in session 63: 0.5599999999999454
# Energy consumption in session 64: 0.37999999999988177
# Energy consumption in session 65: 7.269999999999982
# Energy consumption in session 66: 0.010000000000218279
# Energy consumption in session 67: 0.009999999999763531
# Energy consumption in session 68: 0.24000000000023647
# Energy consumption in session 69: 0.5
# Energy consumption in session 70: 0.23999999999978172
# Energy consumption in session 71: 0.2600000000002183
# Energy consumption in session 72: 0.2300000000000182
# Energy consumption in session 73: 5.079999999999927
# Energy consumption in session 74: 0.5500000000001819
# Energy consumption in session 75: 0.27999999999974534
# Energy consumption in session 76: 0.2600000000002183
# Energy consumption in session 77: 0.2699999999999818
# Energy consumption in session 78: 4.929999999999836
# Energy consumption in session 79: 0.010000000000218279
# Energy consumption in session 80: 0.009999999999763531
# Energy consumption in session 81: 0.010000000000218279
# Energy consumption in session 82: 0.4399999999995998
# Energy consumption in session 83: 0.330000000000382
# Energy consumption in session 84: 0.33999999999969077
# Energy consumption in session 85: 4.930000000000291
# Energy consumption in session 86: 0.009999999999763531
# Energy consumption in session 87: 0.010000000000218279
# Energy consumption in session 88: 0.009999999999763531
# Energy consumption in session 89: 0.010000000000218279
# Energy consumption in session 90: 0.23999999999978172
# Energy consumption in session 91: 5.0
# Energy consumption in session 92: 0.5500000000001819
# Energy consumption in session 93: 6.190000000000055
# Energy consumption in session 94: 0.6900000000000546
# Energy consumption in session 95: 4.179999999999836
# Energy consumption in session 96: 0.2699999999999818
# Energy consumption in session 97: 0.2199999999997999
# Energy consumption in session 98: 6.050000000000182
# Energy consumption in session 99: 10.449999999999818
# Energy consumption in session 100: 1.0900000000001455
# Energy consumption in session 101: 0.32999999999992724
# Energy consumption in session 102: 0.010000000000218279
# Energy consumption in session 103: 0.009999999999763531
# Energy consumption in session 104: 25.640000000000327
# Energy consumption in session 105: 8.58999999999969
# Energy consumption in session 106: 1.3600000000001273
# Energy consumption in session 107: 20.929999999999836
# Energy consumption in session 108: 11.760000000000218
# Energy consumption in session 109: 7.029999999999745
# Energy consumption in session 110: 1.6100000000001273
# Energy consumption in session 111: 5.670000000000073
# Energy consumption in session 112: 1.0900000000001455
# Energy consumption in session 113: 7.690000000000055
# Energy consumption in session 114: 1.4099999999998545
# Energy consumption in session 115: 19.949999999999818
# Energy consumption in session 116: 8.800000000000182
# Energy consumption in session 117: 1.3099999999999454
# Energy consumption in session 118: 17.909999999999854
# Energy consumption in session 119: 0.45000000000027285
# Energy consumption in session 120: 6.109999999999673
# Energy consumption in session 121: 1.650000000000091
# Energy consumption in session 122: 2.1100000000001273
# Energy consumption in session 123: 11.230000000000018
# Energy consumption in session 124: 0.009999999999763531
# Energy consumption in session 125: 0.2699999999999818
# Energy consumption in session 126: 6.710000000000036
# Energy consumption in session 127: 1.3700000000003456
# Energy consumption in session 128: 2.980000000000018
# Energy consumption in session 129: 1.9099999999998545
# Energy consumption in session 130: 8.019999999999982
# Energy consumption in session 131: 6.070000000000164
# Energy consumption in session 132: 4.359999999999673
# Energy consumption in session 133: 0.010000000000218279
# Energy consumption in session 134: 0.009999999999763531
# Energy consumption in session 135: 0.010000000000218279
# Energy consumption in session 136: 0.009999999999763531
# Energy consumption in session 137: 0.010000000000218279
# Energy consumption in session 138: 0.09000000000014552
# Energy consumption in session 139: 0.6499999999996362
# Energy consumption in session 140: 5.950000000000273
# Energy consumption in session 141: 3.8599999999996726
# Energy consumption in session 142: 4.960000000000036
# Energy consumption in session 143: 0.16000000000030923
# Energy consumption in session 144: 0.2699999999999818
# Energy consumption in session 145: 3.8399999999996908
# Energy consumption in session 146: 1.3700000000003456
# Energy consumption in session 147: 0.4899999999997817
# Energy consumption in session 148: 0.5799999999999272
# Energy consumption in session 149: 0.3900000000003274
# Energy consumption in session 150: 8.6899999999996
# Energy consumption in session 151: 5.700000000000273
# Energy consumption in session 152: 0.3200000000001637
# Energy consumption in session 153: 0.1299999999996544
# Energy consumption in session 154: 3.7800000000002
# Energy consumption in session 155: 4.539999999999964
# Energy consumption in session 156: 0.9099999999998545
# Energy consumption in session 157: 0.010000000000218279
# Energy consumption in session 158: 2.6900000000000546
# Energy consumption in session 159: 0.2699999999999818
# Energy consumption in session 160: 1.75
# Energy consumption in session 161: 0.009999999999763531
# Energy consumption in session 162: 0.010000000000218279
# Energy consumption in session 163: 0.75
# Energy consumption in session 164: 0.25
# Energy consumption in session 165: 1.0
# Energy consumption in session 166: 1.7300000000000182
# Energy consumption in session 167: 0.009999999999763531
# Energy consumption in session 168: 0.43000000000029104
# Energy consumption in session 169: 3.799999999999727
# Energy consumption in session 170: 1.7699999999999818
# Energy consumption in session 171: 0.3400000000001455
# Energy consumption in session 172: 0.36000000000012733
# Energy consumption in session 173: 0.1799999999998363
# Energy consumption in session 174: 0.1999999999998181
# Energy consumption in session 175: 0.19000000000005457
# Energy consumption in session 176: 2.650000000000091
# Energy consumption in session 177: 1.3699999999998909
# Energy consumption in session 178: 0.19000000000005457
# Energy consumption in session 179: 4.550000000000182
# Energy consumption in session 180: 0.009999999999763531
# Energy consumption in session 181: 0.01999999999998181
# Energy consumption in session 182: 0.3700000000003456
# Energy consumption in session 183: 1.25
# Energy consumption in session 184: 0.5099999999997635
# Energy consumption in session 185: 2.5599999999999454
# Energy consumption in session 186: 7.800000000000182
# Energy consumption in session 187: 0.009999999999763531
# Energy consumption in session 188: 0.47000000000025466
# Energy consumption in session 189: 0.5
# Energy consumption in session 190: 0.1999999999998181
# Energy consumption in session 191: 2.5700000000001637
# Energy consumption in session 192: 1.0
# Energy consumption in session 193: 2.299999999999727
# Energy consumption in session 194: 0.5
# Energy consumption in session 195: 0.2300000000000182
# Energy consumption in session 196: 0.21000000000003638
# Energy consumption in session 197: 8.63000000000011
# Energy consumption in session 198: 0.010000000000218279
# Energy consumption in session 199: 0.009999999999763531
# Energy consumption in session 200: 0.5399999999999636
# Energy consumption in session 201: 0.34999999999990905
# Energy consumption in session 202: 0.2699999999999818
# Energy consumption in session 203: 3.6400000000003274
# Energy consumption in session 204: 1.8899999999998727
# Energy consumption in session 205: 0.5700000000001637
# Energy consumption in session 206: 0.25
# Energy consumption in session 207: 6.889999999999873
# Energy consumption in session 208: 0.009999999999763531
# Energy consumption in session 209: 0.010000000000218279
# Energy consumption in session 210: 1.5299999999997453
# Total number of sessions where energy consumption is greater than 0.25: 151

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense

# Assuming your DataFrame is called 'filtered_march'
# Make sure 'Reading time' column is in datetime format
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Extract relevant columns and set 'Reading time' as the index
df = filtered_march[['Reading time', 'Difference']].set_index('Reading time')

# Resample the data to hourly frequency and sum the energy consumption for each hour
hourly_energy = df.resample('H').sum()

# Normalize the data
scaler = MinMaxScaler()
scaled_energy = scaler.fit_transform(hourly_energy)

# Function to create time series dataset
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# Define the look-back period (number of previous hours to consider)
look_back = 24  # For example, using the past 24 hours to predict the next hour

# Create the dataset with the look-back period
X, Y = create_dataset(scaled_energy, look_back)

# Reshape the input data for LSTM
X = np.reshape(X, (X.shape[0], 1, X.shape[1]))

# Create and compile the LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(X, Y, epochs=50, batch_size=1, verbose=2)

# Forecast energy consumption for a single day
# Use the last 24 hours of available data to predict the next hour
last_24_hours = scaled_energy[-look_back:]
forecast_input = np.reshape(last_24_hours, (1, 1, look_back))
forecast = model.predict(forecast_input)

# Invert the forecast to get it in the original scale
forecast = scaler.inverse_transform(np.reshape(forecast, (forecast.shape[0], 1)))

print(f"Forecasted energy consumption for the next hour: {forecast[0][0]}")
# Out:
# WARNING:tensorflow:From C:\Users\et22m\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\et22m\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\et22m\anaconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\et22m\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 712/712 - 9s - loss: 0.0229 - 9s/epoch - 12ms/step
# Epoch 2/50
# 712/712 - 3s - loss: 0.0195 - 3s/epoch - 4ms/step
# Epoch 3/50
# 712/712 - 3s - loss: 0.0190 - 3s/epoch - 4ms/step
# Epoch 4/50
# 712/712 - 3s - loss: 0.0186 - 3s/epoch - 4ms/step
# Epoch 5/50
# 712/712 - 3s - loss: 0.0183 - 3s/epoch - 4ms/step
# Epoch 6/50
# 712/712 - 3s - loss: 0.0182 - 3s/epoch - 4ms/step
# Epoch 7/50
# 712/712 - 3s - loss: 0.0180 - 3s/epoch - 4ms/step
# Epoch 8/50
# 712/712 - 3s - loss: 0.0183 - 3s/epoch - 4ms/step
# Epoch 9/50
# 712/712 - 3s - loss: 0.0176 - 3s/epoch - 4ms/step
# Epoch 10/50
# 712/712 - 3s - loss: 0.0178 - 3s/epoch - 4ms/step
# Epoch 11/50
# 712/712 - 3s - loss: 0.0179 - 3s/epoch - 5ms/step
# Epoch 12/50
# 712/712 - 3s - loss: 0.0177 - 3s/epoch - 4ms/step
# Epoch 13/50
# 712/712 - 3s - loss: 0.0177 - 3s/epoch - 4ms/step
# Epoch 14/50
# 712/712 - 3s - loss: 0.0176 - 3s/epoch - 4ms/step
# Epoch 15/50
# 712/712 - 3s - loss: 0.0172 - 3s/epoch - 5ms/step
# Epoch 16/50
# 712/712 - 3s - loss: 0.0170 - 3s/epoch - 5ms/step
# Epoch 17/50
# 712/712 - 3s - loss: 0.0170 - 3s/epoch - 5ms/step
# Epoch 18/50
# 712/712 - 3s - loss: 0.0170 - 3s/epoch - 4ms/step
# Epoch 19/50
# 712/712 - 3s - loss: 0.0173 - 3s/epoch - 5ms/step
# Epoch 20/50
# 712/712 - 3s - loss: 0.0168 - 3s/epoch - 5ms/step
# Epoch 21/50
# 712/712 - 3s - loss: 0.0166 - 3s/epoch - 5ms/step
# Epoch 22/50
# 712/712 - 3s - loss: 0.0164 - 3s/epoch - 5ms/step
# Epoch 23/50
# 712/712 - 3s - loss: 0.0162 - 3s/epoch - 5ms/step
# Epoch 24/50
# 712/712 - 3s - loss: 0.0162 - 3s/epoch - 5ms/step
# Epoch 25/50
# 712/712 - 3s - loss: 0.0161 - 3s/epoch - 5ms/step
# Epoch 26/50
# 712/712 - 3s - loss: 0.0160 - 3s/epoch - 5ms/step
# Epoch 27/50
# 712/712 - 3s - loss: 0.0159 - 3s/epoch - 5ms/step
# Epoch 28/50
# 712/712 - 4s - loss: 0.0157 - 4s/epoch - 5ms/step
# Epoch 29/50
# 712/712 - 3s - loss: 0.0157 - 3s/epoch - 5ms/step
# Epoch 30/50
# 712/712 - 3s - loss: 0.0152 - 3s/epoch - 4ms/step
# Epoch 31/50
# 712/712 - 4s - loss: 0.0154 - 4s/epoch - 5ms/step
# Epoch 32/50
# 712/712 - 3s - loss: 0.0154 - 3s/epoch - 5ms/step
# Epoch 33/50
# 712/712 - 3s - loss: 0.0152 - 3s/epoch - 4ms/step
# Epoch 34/50
# 712/712 - 3s - loss: 0.0151 - 3s/epoch - 4ms/step
# Epoch 35/50
# 712/712 - 3s - loss: 0.0148 - 3s/epoch - 4ms/step
# Epoch 36/50
# 712/712 - 3s - loss: 0.0148 - 3s/epoch - 4ms/step
# Epoch 37/50
# 712/712 - 3s - loss: 0.0147 - 3s/epoch - 4ms/step
# Epoch 38/50
# 712/712 - 3s - loss: 0.0148 - 3s/epoch - 4ms/step
# Epoch 39/50
# 712/712 - 3s - loss: 0.0146 - 3s/epoch - 5ms/step
# Epoch 40/50
# 712/712 - 3s - loss: 0.0145 - 3s/epoch - 5ms/step
# Epoch 41/50
# 712/712 - 3s - loss: 0.0143 - 3s/epoch - 4ms/step
# Epoch 42/50
# 712/712 - 3s - loss: 0.0143 - 3s/epoch - 4ms/step
# Epoch 43/50
# 712/712 - 3s - loss: 0.0142 - 3s/epoch - 4ms/step
# Epoch 44/50
# 712/712 - 3s - loss: 0.0142 - 3s/epoch - 4ms/step
# Epoch 45/50
# 712/712 - 3s - loss: 0.0141 - 3s/epoch - 4ms/step
# Epoch 46/50
# 712/712 - 3s - loss: 0.0139 - 3s/epoch - 4ms/step
# Epoch 47/50
# 712/712 - 3s - loss: 0.0136 - 3s/epoch - 4ms/step
# Epoch 48/50
# 712/712 - 3s - loss: 0.0135 - 3s/epoch - 4ms/step
# Epoch 49/50
# 712/712 - 3s - loss: 0.0136 - 3s/epoch - 4ms/step
# Epoch 50/50
# 712/712 - 3s - loss: 0.0136 - 3s/epoch - 4ms/step
# 1/1 [==============================] - 1s 1s/step
# Forecasted energy consumption for the next hour: 0.14449474215507507

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

# Assuming your DataFrame is called 'filtered_march'
# Make sure 'Reading time' column is in datetime format
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Extract relevant columns and set 'Reading time' as the index
df = filtered_march[['Reading time', 'Difference']].set_index('Reading time')

# Resample the data to daily frequency and sum the energy consumption for each day
daily_energy = df.resample('D').sum()

# Normalize the data
scaler = MinMaxScaler()
scaled_energy = scaler.fit_transform(daily_energy)

# Function to create time series dataset
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# Define the look-back period (number of previous days to consider)
look_back = 29  # Using the past 7 days to predict the next day

# Create the dataset with the look-back period
X, Y = create_dataset(scaled_energy, look_back)

# Reshape the input data for LSTM
X = np.reshape(X, (X.shape[0], 1, X.shape[1]))

# Create and compile the LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(X, Y, epochs=50, batch_size=1, verbose=2)

# Forecast energy consumption for the next day
last_week = scaled_energy[-look_back:]
forecast_input = np.reshape(last_week, (1, 1, look_back))
forecast = model.predict(forecast_input)

# Invert the forecast to get it in the original scale
forecast = scaler.inverse_transform(np.reshape(forecast, (forecast.shape[0], 1)))

print(f"Forecasted energy consumption for the next day: {forecast[0][0]}")

# Plotting the actual and forecasted values
plt.figure(figsize=(12, 6))
plt.plot(daily_energy.index, daily_energy, label='Actual')
plt.plot(daily_energy.index[-1] + pd.DateOffset(days=1), forecast[0], marker='o', color='red', label='Forecasted')
plt.xlabel('Date')
plt.ylabel('Energy Consumption')
plt.title('Actual vs Forecasted Energy Consumption for the Next Day')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 2/2 - 3s - loss: 0.0759 - 3s/epoch - 1s/step
# Epoch 2/50
# 2/2 - 0s - loss: 0.0493 - 13ms/epoch - 6ms/step
# Epoch 3/50
# 2/2 - 0s - loss: 0.0485 - 22ms/epoch - 11ms/step
# Epoch 4/50
# 2/2 - 0s - loss: 0.0414 - 18ms/epoch - 9ms/step
# Epoch 5/50
# 2/2 - 0s - loss: 0.0376 - 17ms/epoch - 9ms/step
# Epoch 6/50
# 2/2 - 0s - loss: 0.0352 - 16ms/epoch - 8ms/step
# Epoch 7/50
# 2/2 - 0s - loss: 0.0322 - 16ms/epoch - 8ms/step
# Epoch 8/50
# 2/2 - 0s - loss: 0.0301 - 14ms/epoch - 7ms/step
# Epoch 9/50
# 2/2 - 0s - loss: 0.0277 - 15ms/epoch - 7ms/step
# Epoch 10/50
# 2/2 - 0s - loss: 0.0252 - 19ms/epoch - 10ms/step
# Epoch 11/50
# 2/2 - 0s - loss: 0.0243 - 13ms/epoch - 7ms/step
# Epoch 12/50
# 2/2 - 0s - loss: 0.0217 - 12ms/epoch - 6ms/step
# Epoch 13/50
# 2/2 - 0s - loss: 0.0183 - 14ms/epoch - 7ms/step
# Epoch 14/50
# 2/2 - 0s - loss: 0.0178 - 14ms/epoch - 7ms/step
# Epoch 15/50
# 2/2 - 0s - loss: 0.0155 - 15ms/epoch - 8ms/step
# Epoch 16/50
# 2/2 - 0s - loss: 0.0141 - 15ms/epoch - 7ms/step
# Epoch 17/50
# 2/2 - 0s - loss: 0.0130 - 14ms/epoch - 7ms/step
# Epoch 18/50
# 2/2 - 0s - loss: 0.0116 - 14ms/epoch - 7ms/step
# Epoch 19/50
# 2/2 - 0s - loss: 0.0105 - 16ms/epoch - 8ms/step
# Epoch 20/50
# 2/2 - 0s - loss: 0.0092 - 13ms/epoch - 6ms/step
# Epoch 21/50
# 2/2 - 0s - loss: 0.0076 - 14ms/epoch - 7ms/step
# Epoch 22/50
# 2/2 - 0s - loss: 0.0066 - 14ms/epoch - 7ms/step
# Epoch 23/50
# 2/2 - 0s - loss: 0.0059 - 14ms/epoch - 7ms/step
# Epoch 24/50
# 2/2 - 0s - loss: 0.0050 - 15ms/epoch - 8ms/step
# Epoch 25/50
# 2/2 - 0s - loss: 0.0042 - 15ms/epoch - 7ms/step
# Epoch 26/50
# 2/2 - 0s - loss: 0.0034 - 15ms/epoch - 8ms/step
# Epoch 27/50
# 2/2 - 0s - loss: 0.0029 - 17ms/epoch - 8ms/step
# Epoch 28/50
# 2/2 - 0s - loss: 0.0023 - 13ms/epoch - 6ms/step
# Epoch 29/50
# 2/2 - 0s - loss: 0.0018 - 14ms/epoch - 7ms/step
# Epoch 30/50
# 2/2 - 0s - loss: 0.0014 - 15ms/epoch - 7ms/step
# Epoch 31/50
# 2/2 - 0s - loss: 0.0011 - 15ms/epoch - 8ms/step
# Epoch 32/50
# 2/2 - 0s - loss: 8.0589e-04 - 15ms/epoch - 7ms/step
# Epoch 33/50
# 2/2 - 0s - loss: 5.3463e-04 - 14ms/epoch - 7ms/step
# Epoch 34/50
# 2/2 - 0s - loss: 3.6177e-04 - 16ms/epoch - 8ms/step
# Epoch 35/50
# 2/2 - 0s - loss: 2.6247e-04 - 15ms/epoch - 8ms/step
# Epoch 36/50
# 2/2 - 0s - loss: 1.4490e-04 - 13ms/epoch - 7ms/step
# Epoch 37/50
# 2/2 - 0s - loss: 9.1013e-05 - 14ms/epoch - 7ms/step
# Epoch 38/50
# 2/2 - 0s - loss: 4.9461e-05 - 14ms/epoch - 7ms/step
# Epoch 39/50
# 2/2 - 0s - loss: 2.4286e-05 - 14ms/epoch - 7ms/step
# Epoch 40/50
# 2/2 - 0s - loss: 1.5723e-05 - 13ms/epoch - 7ms/step
# Epoch 41/50
# 2/2 - 0s - loss: 1.2668e-06 - 14ms/epoch - 7ms/step
# Epoch 42/50
# 2/2 - 0s - loss: 2.0444e-06 - 15ms/epoch - 8ms/step
# Epoch 43/50
# 2/2 - 0s - loss: 4.4718e-06 - 15ms/epoch - 7ms/step
# Epoch 44/50
# 2/2 - 0s - loss: 1.3786e-05 - 13ms/epoch - 7ms/step
# Epoch 45/50
# 2/2 - 0s - loss: 1.7179e-05 - 13ms/epoch - 6ms/step
# Epoch 46/50
# 2/2 - 0s - loss: 2.0233e-05 - 15ms/epoch - 7ms/step
# Epoch 47/50
# 2/2 - 0s - loss: 2.3062e-05 - 17ms/epoch - 9ms/step
# Epoch 48/50
# 2/2 - 0s - loss: 2.0276e-05 - 16ms/epoch - 8ms/step
# Epoch 49/50
# 2/2 - 0s - loss: 2.2664e-05 - 15ms/epoch - 8ms/step
# Epoch 50/50
# 2/2 - 0s - loss: 1.9773e-05 - 15ms/epoch - 8ms/step
# 1/1 [==============================] - 1s 1s/step
# Forecasted energy consumption for the next day: 2.881277084350586

# %%
filtered_march['Power'] = filtered_march['Difference'] / 0.25
total_power_consumption = filtered_march["Power"].sum()
total_power_consumption
# Out:
# 2251.5999999999995

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df' with columns: 'reading_time', 'Difference', 'Power(kW)'
# You may need to load your actual dataset using pd.read_csv or another appropriate method.
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Extract date from the timestamp
filtered_march['date'] = filtered_march['Reading time'].dt.date

# Calculate average and peak load for each day
daily_load = filtered_march.groupby('date')['Power'].agg(['mean', 'max'])

# Calculate load factor for each day
daily_load['load_factor'] = (daily_load['mean'] / daily_load['max']) * 100
print("Load Factor for Each Day:")
print(daily_load[['load_factor']])

# Plot the graph with improved aesthetics
plt.figure(figsize=(10, 6))
plt.plot(daily_load.index, daily_load['load_factor'], marker='o', linestyle='-', color='b', label='Load Factor')
plt.title('Daily Load Factor')
plt.xlabel('Date')
plt.ylabel('Load Factor (%)')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
day_labels = ['Day {}'.format(i + 1) for i in range(len(daily_load))]
plt.xticks(daily_load.index, day_labels, rotation=45)

plt.tight_layout()
plt.show()
# Out:
# Load Factor for Each Day:
#             load_factor
# date
# 2023-03-01    21.043883
# 2023-03-02    21.684451
# 2023-03-03    31.313516
# 2023-03-04    28.522267
# 2023-03-05    28.255208
# 2023-03-06    18.210526
# 2023-03-07    18.539450
# 2023-03-08    22.383130
# 2023-03-09    27.929687
# 2023-03-10     3.629986
# 2023-03-11    17.539062
# 2023-03-12     7.739826
# 2023-03-13    29.662093
# 2023-03-14    23.958333
# 2023-03-15    38.998984
# 2023-03-16    40.351562
# 2023-03-17    29.763056
# 2023-03-18    37.601626
# 2023-03-19    19.274916
# 2023-03-20    17.838915
# 2023-03-21    27.695312
# 2023-03-22     1.428571
# 2023-03-23     8.814103
# 2023-03-24    31.904013
# 2023-03-25    19.205729
# 2023-03-26     9.580177
# 2023-03-27    18.559451
# 2023-03-28    19.704861
# 2023-03-29    13.966529
# 2023-03-30    20.071138
# 2023-03-31     4.036885

# %%
# Convert 'reading_time' column to datetime format
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Define tariff rates
tariff_rates = {
    'off-peak': 10,
    'peak': 20,
    'mid-peak': 15,
    'high-peak': 25
}

# Function to determine the tariff based on the time of day
def get_tariff(reading_time):
    hour = reading_time.hour
    if 23 <= hour or hour < 6:
        return 'off-peak'
    elif 7 <= hour < 11:
        return 'peak'
    elif 11 <= hour < 19:
        return 'mid-peak'
    else:
        return 'high-peak'

# Apply the get_tariff function to each row to get the tariff for each reading
filtered_march['tariff'] = filtered_march['Reading time'].apply(get_tariff)

# Calculate the price for each 15-minute interval
filtered_march['evprice'] = filtered_march.apply(lambda row: row['Difference'] * tariff_rates[row['tariff']], axis=1)

# %%
# Calculate the total of the 'price' column
total_price = filtered_march['evprice'].sum()
total_energy = filtered_march['Difference'].sum()
# Print the total
print(f"Total Energy :{round(total_energy,2)} Units")
print("Total Price Rs:", round(total_price,2))
# Out:
# Total Energy :562.9 Units
# Total Price Rs: 9294.95
