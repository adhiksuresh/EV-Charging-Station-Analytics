# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %%
charge_2 = pd.read_csv('IHM10050178.csv')

# %%
csv_file = 'IHM10050178.csv'

# %%
custom_delimiter = ';'

# %%
cha_station3 = pd.read_csv(csv_file, delimiter=custom_delimiter)

# %%
cha_station3.to_csv('output.csv', index=False, sep=custom_delimiter)

# %%
cha_station3
# Out:
#           Reading values               Profile               Reading time  \
# 0                  0.000  InstantaneousProfile  2023-03-01T00:06:00+05:30
# 1                  0.000  InstantaneousProfile  2023-03-01T00:21:05+05:30
# 2                  0.228  InstantaneousProfile  2023-03-01T00:30:00+05:30
# 3                  0.228  InstantaneousProfile  2023-03-01T00:30:00+05:30
# 4                  0.228  InstantaneousProfile  2023-03-01T00:30:00+05:30
# ...                  ...                   ...                        ...
# 57912            236.180    Block Load Profile  2023-03-31T13:30:00+05:30
# 57913            236.220    Block Load Profile  2023-03-31T14:00:00+05:30
# 57914            236.980    Block Load Profile  2023-03-31T14:30:00+05:30
# 57915            235.590    Block Load Profile  2023-03-31T15:00:00+05:30
# 57916  1,677,609,629.000       Billing Profile  2023-03-01T00:10:29+05:30
#
#                      Insert time               Capture time        OBIS code  \
# 0      2023-03-01T00:00:58+05:30  2023-03-01T00:06:00+05:30    1-0:1.6.0*255
# 1      2023-03-01T00:16:03+05:30  2023-03-01T00:21:05+05:30    1-0:1.6.0*255
# 2      2023-03-01T00:31:00+05:30  2023-03-01T00:36:02+05:30    1-0:1.6.0*255
# 3      2023-03-01T00:45:56+05:30  2023-03-01T00:50:58+05:30    1-0:1.6.0*255
# 4      2023-03-01T01:01:03+05:30  2023-03-01T01:06:05+05:30    1-0:1.6.0*255
# ...                          ...                        ...              ...
# 57912  2023-03-31T13:45:37+05:30  2023-03-31T13:30:00+05:30  1-0:12.27.0*255
# 57913  2023-03-31T14:15:39+05:30  2023-03-31T14:00:00+05:30  1-0:12.27.0*255
# 57914  2023-03-31T14:45:38+05:30  2023-03-31T14:30:00+05:30  1-0:12.27.0*255
# 57915  2023-03-31T15:15:44+05:30  2023-03-31T15:00:00+05:30  1-0:12.27.0*255
# 57916  2023-03-01T00:05:27+05:30  2023-03-01T00:10:29+05:30    0-0:0.1.2*255
#
#       Unit  Transformer factor Status word Reading reason     Data source
# 0       kW                   1   No errors       Periodic  DLMS Connector
# 1       kW                   1   No errors       Periodic  DLMS Connector
# 2       kW                   1   No errors       Periodic  DLMS Connector
# 3       kW                   1   No errors       Periodic  DLMS Connector
# 4       kW                   1   No errors       Periodic  DLMS Connector
# ...    ...                 ...         ...            ...             ...
# 57912    V                   1   No errors       Periodic  DLMS Connector
# 57913    V                   1   No errors       Periodic  DLMS Connector
# 57914    V                   1   No errors       Periodic  DLMS Connector
# 57915    V                   1   No errors       Periodic  DLMS Connector
# 57916    s                   1   No errors       Periodic  DLMS Connector
#
# [57917 rows x 11 columns]

# %%
filter1 = cha_station3[cha_station3['Unit'] == 'kWh']

# %%
filter2 = filter1[filter1['Profile'] == 'InstantaneousProfile']

# %%
filter2
# Out:
#       Reading values               Profile               Reading time  \
# 5791       1,444.880  InstantaneousProfile  2023-03-01T00:06:00+05:30
# 5792       1,444.960  InstantaneousProfile  2023-03-01T00:21:05+05:30
# 5793       1,444.970  InstantaneousProfile  2023-03-01T00:36:02+05:30
# 5794       1,444.970  InstantaneousProfile  2023-03-01T00:50:58+05:30
# 5795       1,444.970  InstantaneousProfile  2023-03-01T01:06:05+05:30
# ...              ...                   ...                        ...
# 11581          0.000  InstantaneousProfile  2023-03-31T14:06:26+05:30
# 11582          0.000  InstantaneousProfile  2023-03-31T14:21:29+05:30
# 11583          0.000  InstantaneousProfile  2023-03-31T14:36:29+05:30
# 11584          0.000  InstantaneousProfile  2023-03-31T14:51:31+05:30
# 11585          0.000  InstantaneousProfile  2023-03-31T15:06:31+05:30
#
#                      Insert time               Capture time      OBIS code  \
# 5791   2023-03-01T00:00:58+05:30  2023-03-01T00:06:00+05:30  1-0:1.8.0*255
# 5792   2023-03-01T00:16:03+05:30  2023-03-01T00:21:05+05:30  1-0:1.8.0*255
# 5793   2023-03-01T00:31:00+05:30  2023-03-01T00:36:02+05:30  1-0:1.8.0*255
# 5794   2023-03-01T00:45:56+05:30  2023-03-01T00:50:58+05:30  1-0:1.8.0*255
# 5795   2023-03-01T01:01:03+05:30  2023-03-01T01:06:05+05:30  1-0:1.8.0*255
# ...                          ...                        ...            ...
# 11581  2023-03-31T14:00:54+05:30  2023-03-31T14:06:26+05:30  1-0:2.8.0*255
# 11582  2023-03-31T14:15:57+05:30  2023-03-31T14:21:29+05:30  1-0:2.8.0*255
# 11583  2023-03-31T14:30:57+05:30  2023-03-31T14:36:29+05:30  1-0:2.8.0*255
# 11584  2023-03-31T14:46:00+05:30  2023-03-31T14:51:31+05:30  1-0:2.8.0*255
# 11585  2023-03-31T15:00:59+05:30  2023-03-31T15:06:31+05:30  1-0:2.8.0*255
#
#       Unit  Transformer factor Status word Reading reason     Data source
# 5791   kWh                   1   No errors       Periodic  DLMS Connector
# 5792   kWh                   1   No errors       Periodic  DLMS Connector
# 5793   kWh                   1   No errors       Periodic  DLMS Connector
# 5794   kWh                   1   No errors       Periodic  DLMS Connector
# 5795   kWh                   1   No errors       Periodic  DLMS Connector
# ...    ...                 ...         ...            ...             ...
# 11581  kWh                   1   No errors       Periodic  DLMS Connector
# 11582  kWh                   1   No errors       Periodic  DLMS Connector
# 11583  kWh                   1   No errors       Periodic  DLMS Connector
# 11584  kWh                   1   No errors       Periodic  DLMS Connector
# 11585  kWh                   1   No errors       Periodic  DLMS Connector
#
# [5760 rows x 11 columns]

# %%
filter2['Reading time'] = pd.to_datetime(filter2['Reading time'])
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_3312\607307215.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter2['Reading time'] = pd.to_datetime(filter2['Reading time'])

# %%
filter2['Reading values'] = filter2['Reading values'].str.replace(',', '')
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_3312\3993206803.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter2['Reading values'] = filter2['Reading values'].str.replace(',', '')

# %%
filter2
# Out:
#       Reading values               Profile              Reading time  \
# 5791        1444.880  InstantaneousProfile 2023-03-01 00:06:00+05:30
# 5792        1444.960  InstantaneousProfile 2023-03-01 00:21:05+05:30
# 5793        1444.970  InstantaneousProfile 2023-03-01 00:36:02+05:30
# 5794        1444.970  InstantaneousProfile 2023-03-01 00:50:58+05:30
# 5795        1444.970  InstantaneousProfile 2023-03-01 01:06:05+05:30
# ...              ...                   ...                       ...
# 11581          0.000  InstantaneousProfile 2023-03-31 14:06:26+05:30
# 11582          0.000  InstantaneousProfile 2023-03-31 14:21:29+05:30
# 11583          0.000  InstantaneousProfile 2023-03-31 14:36:29+05:30
# 11584          0.000  InstantaneousProfile 2023-03-31 14:51:31+05:30
# 11585          0.000  InstantaneousProfile 2023-03-31 15:06:31+05:30
#
#                      Insert time               Capture time      OBIS code  \
# 5791   2023-03-01T00:00:58+05:30  2023-03-01T00:06:00+05:30  1-0:1.8.0*255
# 5792   2023-03-01T00:16:03+05:30  2023-03-01T00:21:05+05:30  1-0:1.8.0*255
# 5793   2023-03-01T00:31:00+05:30  2023-03-01T00:36:02+05:30  1-0:1.8.0*255
# 5794   2023-03-01T00:45:56+05:30  2023-03-01T00:50:58+05:30  1-0:1.8.0*255
# 5795   2023-03-01T01:01:03+05:30  2023-03-01T01:06:05+05:30  1-0:1.8.0*255
# ...                          ...                        ...            ...
# 11581  2023-03-31T14:00:54+05:30  2023-03-31T14:06:26+05:30  1-0:2.8.0*255
# 11582  2023-03-31T14:15:57+05:30  2023-03-31T14:21:29+05:30  1-0:2.8.0*255
# 11583  2023-03-31T14:30:57+05:30  2023-03-31T14:36:29+05:30  1-0:2.8.0*255
# 11584  2023-03-31T14:46:00+05:30  2023-03-31T14:51:31+05:30  1-0:2.8.0*255
# 11585  2023-03-31T15:00:59+05:30  2023-03-31T15:06:31+05:30  1-0:2.8.0*255
#
#       Unit  Transformer factor Status word Reading reason     Data source
# 5791   kWh                   1   No errors       Periodic  DLMS Connector
# 5792   kWh                   1   No errors       Periodic  DLMS Connector
# 5793   kWh                   1   No errors       Periodic  DLMS Connector
# 5794   kWh                   1   No errors       Periodic  DLMS Connector
# 5795   kWh                   1   No errors       Periodic  DLMS Connector
# ...    ...                 ...         ...            ...             ...
# 11581  kWh                   1   No errors       Periodic  DLMS Connector
# 11582  kWh                   1   No errors       Periodic  DLMS Connector
# 11583  kWh                   1   No errors       Periodic  DLMS Connector
# 11584  kWh                   1   No errors       Periodic  DLMS Connector
# 11585  kWh                   1   No errors       Periodic  DLMS Connector
#
# [5760 rows x 11 columns]

# %%
filter2['Reading values'] = filter2['Reading values'].astype(float)
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_3312\1969268204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter2['Reading values'] = filter2['Reading values'].astype(float)

# %%
filter3 = filter2.drop(columns= ['Insert time', 'Capture time','Profile','OBIS code','Transformer factor','Status word','Reading reason','Data source'])

# %%
filtered_march = filter3[filter3['Reading time'].dt.month == 3]

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit
# 5791          1444.88 2023-03-01 00:06:00+05:30  kWh
# 5792          1444.96 2023-03-01 00:21:05+05:30  kWh
# 5793          1444.97 2023-03-01 00:36:02+05:30  kWh
# 5794          1444.97 2023-03-01 00:50:58+05:30  kWh
# 5795          1444.97 2023-03-01 01:06:05+05:30  kWh
# ...               ...                       ...  ...
# 11581            0.00 2023-03-31 14:06:26+05:30  kWh
# 11582            0.00 2023-03-31 14:21:29+05:30  kWh
# 11583            0.00 2023-03-31 14:36:29+05:30  kWh
# 11584            0.00 2023-03-31 14:51:31+05:30  kWh
# 11585            0.00 2023-03-31 15:06:31+05:30  kWh
#
# [5760 rows x 3 columns]

# %%
filtered_march['Difference'] = filtered_march['Reading values'].diff()

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit  Difference
# 5791          1444.88 2023-03-01 00:06:00+05:30  kWh         NaN
# 5792          1444.96 2023-03-01 00:21:05+05:30  kWh        0.08
# 5793          1444.97 2023-03-01 00:36:02+05:30  kWh        0.01
# 5794          1444.97 2023-03-01 00:50:58+05:30  kWh        0.00
# 5795          1444.97 2023-03-01 01:06:05+05:30  kWh        0.00
# ...               ...                       ...  ...         ...
# 11581            0.00 2023-03-31 14:06:26+05:30  kWh        0.00
# 11582            0.00 2023-03-31 14:21:29+05:30  kWh        0.00
# 11583            0.00 2023-03-31 14:36:29+05:30  kWh        0.00
# 11584            0.00 2023-03-31 14:51:31+05:30  kWh        0.00
# 11585            0.00 2023-03-31 15:06:31+05:30  kWh        0.00
#
# [5760 rows x 4 columns]

# %%
filtered_march['Difference'] = filtered_march['Difference'].fillna(0)

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit  Difference
# 5791          1444.88 2023-03-01 00:06:00+05:30  kWh        0.00
# 5792          1444.96 2023-03-01 00:21:05+05:30  kWh        0.08
# 5793          1444.97 2023-03-01 00:36:02+05:30  kWh        0.01
# 5794          1444.97 2023-03-01 00:50:58+05:30  kWh        0.00
# 5795          1444.97 2023-03-01 01:06:05+05:30  kWh        0.00
# ...               ...                       ...  ...         ...
# 11581            0.00 2023-03-31 14:06:26+05:30  kWh        0.00
# 11582            0.00 2023-03-31 14:21:29+05:30  kWh        0.00
# 11583            0.00 2023-03-31 14:36:29+05:30  kWh        0.00
# 11584            0.00 2023-03-31 14:51:31+05:30  kWh        0.00
# 11585            0.00 2023-03-31 15:06:31+05:30  kWh        0.00
#
# [5760 rows x 4 columns]

# %%
has_negative_values = filtered_march['Difference'].any()
print(has_negative_values)
# Out:
# True

# %%
filtered_march['Difference'] = filtered_march['Difference'].fillna(0)

# %%
import numpy as np
filtered_march['Difference'] = filtered_march['Difference'].replace(np.nan, 0)

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit  Difference
# 5791          1444.88 2023-03-01 00:06:00+05:30  kWh        0.00
# 5792          1444.96 2023-03-01 00:21:05+05:30  kWh        0.08
# 5793          1444.97 2023-03-01 00:36:02+05:30  kWh        0.01
# 5794          1444.97 2023-03-01 00:50:58+05:30  kWh        0.00
# 5795          1444.97 2023-03-01 01:06:05+05:30  kWh        0.00
# ...               ...                       ...  ...         ...
# 11581            0.00 2023-03-31 14:06:26+05:30  kWh        0.00
# 11582            0.00 2023-03-31 14:21:29+05:30  kWh        0.00
# 11583            0.00 2023-03-31 14:36:29+05:30  kWh        0.00
# 11584            0.00 2023-03-31 14:51:31+05:30  kWh        0.00
# 11585            0.00 2023-03-31 15:06:31+05:30  kWh        0.00
#
# [5760 rows x 4 columns]

# %%
has_negative_values = filtered_march['Difference'].any()
print(has_negative_values)
# Out:
# True

# %%
negative_values = filtered_march['Difference'].where(filtered_march['Difference'] < 0)

print(negative_values)
# Out:
# 5791    NaN
# 5792    NaN
# 5793    NaN
# 5794    NaN
# 5795    NaN
#          ..
# 11581   NaN
# 11582   NaN
# 11583   NaN
# 11584   NaN
# 11585   NaN
# Name: Difference, Length: 5760, dtype: float64

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit  Difference
# 5791          1444.88 2023-03-01 00:06:00+05:30  kWh        0.00
# 5792          1444.96 2023-03-01 00:21:05+05:30  kWh        0.08
# 5793          1444.97 2023-03-01 00:36:02+05:30  kWh        0.01
# 5794          1444.97 2023-03-01 00:50:58+05:30  kWh        0.00
# 5795          1444.97 2023-03-01 01:06:05+05:30  kWh        0.00
# ...               ...                       ...  ...         ...
# 11581            0.00 2023-03-31 14:06:26+05:30  kWh        0.00
# 11582            0.00 2023-03-31 14:21:29+05:30  kWh        0.00
# 11583            0.00 2023-03-31 14:36:29+05:30  kWh        0.00
# 11584            0.00 2023-03-31 14:51:31+05:30  kWh        0.00
# 11585            0.00 2023-03-31 15:06:31+05:30  kWh        0.00
#
# [5760 rows x 4 columns]

# %%
def replace_negative_values(value):
    if value < 0:
        return 0
    else:
        return value

filtered_march['Difference'] = filtered_march['Difference'].apply(replace_negative_values)

# %%
filtered_march['Cumulative_Increase'] = filtered_march['Difference'].cumsum()

# %%
filtered_march["Time_Stamp"] = filtered_march["Reading time"].dt.strftime("%H-%M-%S")

# %%
total_energy_consumption = filtered_march["Difference"].sum()

# %%
total_energy_consumption
# Out:
# 369.7399999999998

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit  Difference  \
# 5791          1444.88 2023-03-01 00:06:00+05:30  kWh        0.00
# 5792          1444.96 2023-03-01 00:21:05+05:30  kWh        0.08
# 5793          1444.97 2023-03-01 00:36:02+05:30  kWh        0.01
# 5794          1444.97 2023-03-01 00:50:58+05:30  kWh        0.00
# 5795          1444.97 2023-03-01 01:06:05+05:30  kWh        0.00
# ...               ...                       ...  ...         ...
# 11581            0.00 2023-03-31 14:06:26+05:30  kWh        0.00
# 11582            0.00 2023-03-31 14:21:29+05:30  kWh        0.00
# 11583            0.00 2023-03-31 14:36:29+05:30  kWh        0.00
# 11584            0.00 2023-03-31 14:51:31+05:30  kWh        0.00
# 11585            0.00 2023-03-31 15:06:31+05:30  kWh        0.00
#
#        Cumulative_Increase Time_Stamp
# 5791                  0.00   00-06-00
# 5792                  0.08   00-21-05
# 5793                  0.09   00-36-02
# 5794                  0.09   00-50-58
# 5795                  0.09   01-06-05
# ...                    ...        ...
# 11581               369.74   14-06-26
# 11582               369.74   14-21-29
# 11583               369.74   14-36-29
# 11584               369.74   14-51-31
# 11585               369.74   15-06-31
#
# [5760 rows x 6 columns]

# %%
# Convert 'reading_time' column to datetime format
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Define tariff rates
tariff_rates = {
    'off-peak': 6,
    'peak': 8,
    'mid-peak': 7,
    'high-peak': 8
}

# Function to determine the tariff based on the time of day
def get_tariff(reading_time):
    hour = reading_time.hour
    if 23 <= hour or hour < 6:
        return 'off-peak'
    elif 7 <= hour < 11:
        return 'peak'
    elif 11 <= hour < 19:
        return 'mid-peak'
    else:
        return 'high-peak'

# Apply the get_tariff function to each row to get the tariff for each reading
filtered_march['tariff'] = filtered_march['Reading time'].apply(get_tariff)

# Calculate the price for each 15-minute interval
filtered_march['price'] = filtered_march.apply(lambda row: row['Difference'] * tariff_rates[row['tariff']], axis=1)

# %%
filtered_march.head(1000)
# Out:
#       Reading values              Reading time Unit  Difference  \
# 5791         1444.88 2023-03-01 00:06:00+05:30  kWh        0.00
# 5792         1444.96 2023-03-01 00:21:05+05:30  kWh        0.08
# 5793         1444.97 2023-03-01 00:36:02+05:30  kWh        0.01
# 5794         1444.97 2023-03-01 00:50:58+05:30  kWh        0.00
# 5795         1444.97 2023-03-01 01:06:05+05:30  kWh        0.00
# ...              ...                       ...  ...         ...
# 6786         1601.65 2023-03-11 10:51:21+05:30  kWh        0.01
# 6787         1601.65 2023-03-11 11:06:08+05:30  kWh        0.00
# 6788         1601.65 2023-03-11 11:21:16+05:30  kWh        0.00
# 6789         1601.65 2023-03-11 11:36:05+05:30  kWh        0.00
# 6790         1601.65 2023-03-11 11:51:18+05:30  kWh        0.00
#
#       Cumulative_Increase Time_Stamp    tariff  price
# 5791                 0.00   00-06-00  off-peak   0.00
# 5792                 0.08   00-21-05  off-peak   0.48
# 5793                 0.09   00-36-02  off-peak   0.06
# 5794                 0.09   00-50-58  off-peak   0.00
# 5795                 0.09   01-06-05  off-peak   0.00
# ...                   ...        ...       ...    ...
# 6786               156.77   10-51-21      peak   0.08
# 6787               156.77   11-06-08  mid-peak   0.00
# 6788               156.77   11-21-16  mid-peak   0.00
# 6789               156.77   11-36-05  mid-peak   0.00
# 6790               156.77   11-51-18  mid-peak   0.00
#
# [1000 rows x 8 columns]

# %%
# Calculate the total of the 'price' column
total_price = filtered_march['price'].sum()
total_energy = filtered_march['Difference'].sum()
# Print the total
print(f"Total Energy :{round(total_energy,2)} Units")
print("Total Price Rs:", round(total_price,2))
# Out:
# Total Energy :369.74 Units
# Total Price Rs: 2595.51

# %%
peak_df = filtered_march[filtered_march['tariff'] == 'peak']

# Calculate the total energy consumed during peak hours
total_energy_consumed_peak = peak_df['Difference'].sum()

# Calculate the total price during peak hours
total_price_peak = peak_df['price'].sum()

# Print the results
print("Total Energy Consumed During Peak Hours:", round(total_energy_consumed_peak,2))
print("Total Price During Peak Hours:", round(total_price_peak,2))
# Out:
# Total Energy Consumed During Peak Hours: 30.13
# Total Price During Peak Hours: 241.04

# %%
# Filter rows for off-peak hours (assuming 'off-peak' corresponds to the off-peak hours)
off_peak_df = filtered_march[filtered_march['tariff'] == 'off-peak']

# Calculate the total energy consumed during off-peak hours
total_energy_consumed_off_peak = off_peak_df['Difference'].sum()

# Calculate the total price during off-peak hours
total_price_off_peak = off_peak_df['price'].sum()

# Print the results
print("Total Energy Consumed During Off-Peak Hours:", round(total_energy_consumed_off_peak,2))
print("Total Price During Off-Peak Hours:", round(total_price_off_peak,2))
# Out:
# Total Energy Consumed During Off-Peak Hours: 111.99
# Total Price During Off-Peak Hours: 671.94

# %%
# Filter rows for mid-peak hours (assuming 'mid-peak' corresponds to the mid-peak hours)
mid_peak_df = filtered_march[filtered_march['tariff'] == 'mid-peak']

# Calculate the total energy consumed during mid-peak hours
total_energy_consumed_mid_peak = mid_peak_df['Difference'].sum()

# Calculate the total price during mid-peak hours
total_price_mid_peak = mid_peak_df['price'].sum()

# Print the results
print("Total Energy Consumed During Mid-Peak Hours:", round(total_energy_consumed_mid_peak,2))
print("Total Price During Mid-Peak Hours:", round(total_price_mid_peak,2))
# Out:
# Total Energy Consumed During Mid-Peak Hours: 138.43
# Total Price During Mid-Peak Hours: 969.01

# %%
# Filter rows for high-peak hours (assuming 'high-peak' corresponds to the high-peak hours)
high_peak_df = filtered_march[filtered_march['tariff'] == 'high-peak']

# Calculate the total energy consumed during high-peak hours
total_energy_consumed_high_peak = high_peak_df['Difference'].sum()

# Calculate the total price during high-peak hours
total_price_high_peak = high_peak_df['price'].sum()

# Print the results
print("Total Energy Consumed During High-Peak Hours:", round(total_energy_consumed_high_peak,2))
print("Total Price During High-Peak Hours:", round(total_price_high_peak,2))
# Out:
# Total Energy Consumed During High-Peak Hours: 89.19
# Total Price During High-Peak Hours: 713.52

# %%
Total_Energy_Consumption = total_energy_consumed_peak + total_energy_consumed_off_peak + total_energy_consumed_mid_peak +total_energy_consumed_high_peak

# %%
Total_Energy_Consumption
# Out:
# 369.7399999999998

# %%
Total_Price = total_price_peak + total_price_off_peak + total_price_mid_peak + total_price_high_peak

# %%
Total_Price
# Out:
# 2595.509999999998

# %%
plt.figure(figsize=(12, 6))
plt.plot(filtered_march['Reading time'], filtered_march['Difference'], marker='o', linestyle='-')
plt.xlabel('Date')
plt.ylabel('Energy Usage')
plt.title('Energy Usage Trend for the Month')
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

plt.show()

# %%
# Price plot
plt.figure(figsize=(12, 6))
plt.plot(filtered_march['Reading time'], filtered_march['price'], marker='o', linestyle='-')
plt.xlabel('Reading time')
plt.ylabel('Energy Price based on TOD Tariff')
plt.title('Energy Price Vs Reading Time (based on TOD Tariff)')
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

plt.show()

# %%
total_energy = [total_energy_consumed_peak, total_energy_consumed_off_peak, total_energy_consumed_mid_peak, total_energy_consumed_high_peak]
tariff_categories = ['Peak', 'off-Peak', 'mid-Peak', 'High Peak']
# Create a bar plot
plt.figure(figsize=(5, 5))
plt.bar(tariff_categories, total_energy, color=['skyblue', 'lightgreen', 'lightcoral', 'gold'])
plt.xlabel('Time-of-Day ')
plt.ylabel('Total Energy Usage')
plt.title('Total Energy Usage by Time-of-Day ')
plt.show()

# %%
total_prices = [total_price_peak, total_price_off_peak, total_price_mid_peak, total_price_high_peak]
tariff_categories = ['Peak', 'off-Peak', 'mid-Peak', 'High Peak']
# Create a bar plot
plt.figure(figsize=(5, 5))
plt.bar(tariff_categories, total_prices, color=['yellow', 'blue', 'green', 'red'])
plt.xlabel('Time-of-Day ')
plt.ylabel('Total Price')
plt.title('Total Price based on Time-of-Day Tariff ')
plt.show()

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit  Difference  \
# 5791          1444.88 2023-03-01 00:06:00+05:30  kWh        0.00
# 5792          1444.96 2023-03-01 00:21:05+05:30  kWh        0.08
# 5793          1444.97 2023-03-01 00:36:02+05:30  kWh        0.01
# 5794          1444.97 2023-03-01 00:50:58+05:30  kWh        0.00
# 5795          1444.97 2023-03-01 01:06:05+05:30  kWh        0.00
# ...               ...                       ...  ...         ...
# 11581            0.00 2023-03-31 14:06:26+05:30  kWh        0.00
# 11582            0.00 2023-03-31 14:21:29+05:30  kWh        0.00
# 11583            0.00 2023-03-31 14:36:29+05:30  kWh        0.00
# 11584            0.00 2023-03-31 14:51:31+05:30  kWh        0.00
# 11585            0.00 2023-03-31 15:06:31+05:30  kWh        0.00
#
#        Cumulative_Increase Time_Stamp    tariff  price
# 5791                  0.00   00-06-00  off-peak   0.00
# 5792                  0.08   00-21-05  off-peak   0.48
# 5793                  0.09   00-36-02  off-peak   0.06
# 5794                  0.09   00-50-58  off-peak   0.00
# 5795                  0.09   01-06-05  off-peak   0.00
# ...                    ...        ...       ...    ...
# 11581               369.74   14-06-26  mid-peak   0.00
# 11582               369.74   14-21-29  mid-peak   0.00
# 11583               369.74   14-36-29  mid-peak   0.00
# 11584               369.74   14-51-31  mid-peak   0.00
# 11585               369.74   15-06-31  mid-peak   0.00
#
# [5760 rows x 8 columns]

# %%
# Filter data for the month of March
march_data = filtered_march[(filtered_march['Reading time'] >= '2023-03-01') & (filtered_march['Reading time'] < '2023-04-01')]

# Group by date and sum the energy usage for each day
daily_energy_usage = march_data.groupby(march_data['Reading time'].dt.date)['Difference'].sum()

# The result will be a Series with daily energy usage for each day in March
print(daily_energy_usage)
# Out:
# Reading time
# 2023-03-01    13.22
# 2023-03-02    12.06
# 2023-03-03    15.78
# 2023-03-04    13.97
# 2023-03-05    14.51
# 2023-03-06    13.95
# 2023-03-07    17.23
# 2023-03-08    10.22
# 2023-03-09    17.35
# 2023-03-10    15.07
# 2023-03-11    21.53
# 2023-03-12    10.54
# 2023-03-13    16.24
# 2023-03-14    16.44
# 2023-03-15    17.44
# 2023-03-16    11.23
# 2023-03-17    14.02
# 2023-03-18    18.78
# 2023-03-19    21.99
# 2023-03-20    13.81
# 2023-03-21    23.69
# 2023-03-22    11.82
# 2023-03-23    18.47
# 2023-03-24     9.19
# 2023-03-25     0.26
# 2023-03-26     0.56
# 2023-03-27     0.03
# 2023-03-28     0.00
# 2023-03-29     0.03
# 2023-03-30     0.09
# 2023-03-31     0.22
# Name: Difference, dtype: float64

# %%
# Filter data for the month of March
march_data = filtered_march[(filtered_march['Reading time'] >= '2023-03-01') & (filtered_march['Reading time'] < '2023-04-01')]

# Group by date and sum the price based on tod for each day
daily_energy_pricing = march_data.groupby(march_data['Reading time'].dt.date)['price'].sum()

# The result will be a Series with daily energy usage for each day in March
print(daily_energy_pricing)
# Out:
# Reading time
# 2023-03-01     97.36
# 2023-03-02     89.55
# 2023-03-03    114.71
# 2023-03-04    100.43
# 2023-03-05     99.90
# 2023-03-06     95.96
# 2023-03-07    116.05
# 2023-03-08     72.46
# 2023-03-09    117.58
# 2023-03-10    103.22
# 2023-03-11    147.02
# 2023-03-12     76.15
# 2023-03-13    112.41
# 2023-03-14    116.61
# 2023-03-15    126.49
# 2023-03-16     78.52
# 2023-03-17    102.00
# 2023-03-18    132.64
# 2023-03-19    156.66
# 2023-03-20     94.74
# 2023-03-21    171.68
# 2023-03-22     78.56
# 2023-03-23    127.11
# 2023-03-24     59.39
# 2023-03-25      1.92
# 2023-03-26      3.82
# 2023-03-27      0.18
# 2023-03-28      0.00
# 2023-03-29      0.21
# 2023-03-30      0.68
# 2023-03-31      1.50
# Name: price, dtype: float64

# %%
# Create a bar plot
plt.figure(figsize=(12, 6))
plt.bar(daily_energy_usage.index, daily_energy_usage.values, color='b')
plt.title('Daily Energy Usage in March 2023')
plt.xlabel('Date')
plt.ylabel('Energy Usage')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Create a bar plot
plt.figure(figsize=(12, 6))
plt.bar(daily_energy_pricing.index, daily_energy_pricing.values, color='g')
plt.title('Daily Pricing in March 2023')
plt.xlabel('Date')
plt.ylabel('Energy Usage')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
mean_energy_usage = daily_energy_usage.mean()

# Calculate the median of daily energy usage
median_energy_usage = daily_energy_usage.median()

# Calculate the standard deviation of daily energy usage
std_deviation_energy_usage = daily_energy_usage.std()

# Print the results
print(f"Mean Energy Usage: {mean_energy_usage:.2f}")
print(f"Median Energy Usage: {median_energy_usage:.2f}")
print(f"Standard Deviation of Energy Usage: {std_deviation_energy_usage:.2f}")
# Out:
# Mean Energy Usage: 11.93
# Median Energy Usage: 13.95
# Standard Deviation of Energy Usage: 7.25

# %%
mean_energy_pricing = daily_energy_pricing.mean()

# Calculate the median of daily energy usage
median_energy_pricing = daily_energy_pricing.median()

# Calculate the standard deviation of daily energy usage
std_deviation_energy_pricing = daily_energy_pricing.std()

# Print the results
print(f"Mean Energy Pricing: {mean_energy_pricing:.2f}")
print(f"Median Energy Pricing: {median_energy_pricing:.2f}")
print(f"Standard Deviation of Energy pricing: {std_deviation_energy_pricing:.2f}")
# Out:
# Mean Energy Pricing: 83.73
# Median Energy Pricing: 97.36
# Standard Deviation of Energy pricing: 51.15

# %%
import seaborn as sns

# Create a density plot (KDE)
plt.figure(figsize=(3, 3))
sns.histplot(daily_energy_usage, kde=True, color='skyblue')
plt.title('Density Plot of Daily Energy Usage')
plt.xlabel('Energy Usage')
plt.ylabel('Density')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\et22m\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import seaborn as sns

# Create a density plot (KDE)
plt.figure(figsize=(3, 3))
sns.histplot(daily_energy_pricing, kde=True, color='green')
plt.title('Density Plot of Daily Energy Usage Pricing')
plt.xlabel('Energy Usage Pricing based on TOD')
plt.ylabel('Density')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Calculate the day of the week for each data point (0 = Monday, 6 = Sunday)
filtered_march['Day_of_Week'] = filtered_march['Reading time'].dt.dayofweek

# Group data by the day of the week and calculate the mean energy usage
sum_energy_by_day = filtered_march.groupby('Day_of_Week')['Difference'].sum()

# Define the day names for plotting
day_names = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
print(sum_energy_by_day)
# Out:
# Day_of_Week
# 0    44.03
# 1    57.36
# 2    52.73
# 3    59.20
# 4    54.28
# 5    54.54
# 6    47.60
# Name: Difference, dtype: float64

# %%
# Create a bar plot to visualize mean energy usage by day
plt.figure(figsize=(7, 5))
plt.bar(day_names, sum_energy_by_day, color='green')
plt.title('Sum of Energy Usage by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Sum Energy Usage')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Calculate the day of the week for each data point (0 = Monday, 6 = Sunday)
filtered_march['Day_of_Week'] = filtered_march['Reading time'].dt.dayofweek

# Group data by the day of the week and calculate the mean energy usage
sum_energy_price_by_day = filtered_march.groupby('Day_of_Week')['price'].sum()

# Define the day names for plotting
day_names = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
print(sum_energy_price_by_day)
# Out:
# Day_of_Week
# 0    303.29
# 1    404.34
# 2    375.08
# 3    413.44
# 4    380.82
# 5    382.01
# 6    336.53
# Name: price, dtype: float64

# %%
# Create a bar plot to visualize mean energy usage by day
plt.figure(figsize=(7, 5))
plt.bar(day_names, sum_energy_by_day, color='yellow')
plt.title('Sum of Energy Price by Day of the Week(TOD)')
plt.xlabel('Day of the Week')
plt.ylabel('Sum Energy Price')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
filtered_march['Weekday_Or_Weekend'] = filtered_march['Day_of_Week'].apply(lambda x: 'Weekend' if x >= 5 else 'Weekday')

# Calculate the average energy usage for weekdays and weekends
average_energy_by_category = filtered_march.groupby('Weekday_Or_Weekend')['Difference'].mean()

# Display the result
print(average_energy_by_category)
# Out:
# Weekday_Or_Weekend
# Weekday    0.063262
# Weekend    0.066758
# Name: Difference, dtype: float64

# %%
filtered_march['Weekday_Or_Weekend'] = filtered_march['Day_of_Week'].apply(lambda x: 'Weekend' if x >= 5 else 'Weekday')

# Calculate the average energy usage for weekdays and weekends
average_energy_by_category_sum = filtered_march.groupby('Weekday_Or_Weekend')['Difference'].sum()

# Display the result
print(average_energy_by_category_sum)
# Out:
# Weekday_Or_Weekend
# Weekday    267.60
# Weekend    102.14
# Name: Difference, dtype: float64

# %%
filtered_march['Weekday_Or_Weekend'] = filtered_march['Day_of_Week'].apply(lambda x: 'Weekend' if x >= 5 else 'Weekday')

# Calculate the average energy usage(price) for weekdays and weekends
average_energy_by_category_mean = filtered_march.groupby('Weekday_Or_Weekend')['price'].mean()

# Display the result
print(average_energy_by_category_mean)
# Out:
# Weekday_Or_Weekend
# Weekday    0.443728
# Weekend    0.469634
# Name: price, dtype: float64

# %%
filtered_march['Weekday_Or_Weekend'] = filtered_march['Day_of_Week'].apply(lambda x: 'Weekend' if x >= 5 else 'Weekday')

# Calculate the sum energy usage (price)for weekdays and weekends
average_energy_by_category_sum_price = filtered_march.groupby('Weekday_Or_Weekend')['price'].sum()

# Display the result
print(average_energy_by_category_sum_price)
# Out:
# Weekday_Or_Weekend
# Weekday    1876.97
# Weekend     718.54
# Name: price, dtype: float64

# %%
from scipy import stats

# %%
weekday_data = filtered_march[filtered_march['Weekday_Or_Weekend'] == 'Weekday']['Difference']
weekend_data = filtered_march[filtered_march['Weekday_Or_Weekend'] == 'Weekend']['Difference']

# Perform a t-test to compare the means of the two groups
t_stat, p_value = stats.ttest_ind(weekday_data, weekend_data)

# Set the significance level (alpha)
alpha = 0.05

# Check if the p-value is less than alpha (indicating statistical significance)
if p_value < alpha:
    print("There is a statistically significant difference in energy consumption between weekdays and weekends.")
else:
    print("There is no statistically significant difference in energy consumption between weekdays and weekends.")
# Out:
# There is no statistically significant difference in energy consumption between weekdays and weekends.

# %%
daily_energy_usage = filtered_march.groupby(filtered_march['Reading time'].dt.date)['Difference'].sum()

# Compute basic statistics
mean_energy = daily_energy_usage.mean()
std_deviation_energy = daily_energy_usage.std()

# %%
threshold_high = mean_energy + 1 * std_deviation_energy
threshold_low = mean_energy - 1 * std_deviation_energy
print(threshold_high)
print(threshold_high)
# Out:
# 19.18071205373905
# 19.18071205373905

# %%
# Detect days with exceptionally high energy usage
high_energy_days = daily_energy_usage[daily_energy_usage > threshold_high]
print(high_energy_days)
# Detect days with exceptionally low energy usage
low_energy_days = daily_energy_usage[daily_energy_usage < threshold_low]
print(low_energy_days)
# Out:
# Reading time
# 2023-03-11    21.53
# 2023-03-19    21.99
# 2023-03-21    23.69
# Name: Difference, dtype: float64
# Reading time
# 2023-03-25    0.26
# 2023-03-26    0.56
# 2023-03-27    0.03
# 2023-03-28    0.00
# 2023-03-29    0.03
# 2023-03-30    0.09
# 2023-03-31    0.22
# Name: Difference, dtype: float64

# %%
plt.figure(figsize=(31, 6))
plt.plot(daily_energy_usage.index, daily_energy_usage.values, marker='o', linestyle='-', color='b', label='Daily Energy Usage')

# Scatter plot for high energy days (in red)
plt.scatter(high_energy_days.index, high_energy_days.values, color='red', marker='*', label='High Energy Days')

# Scatter plot for low energy days (in green)
plt.scatter(low_energy_days.index, low_energy_days.values, color='green', marker='*', label='Low Energy Days')

plt.title('Daily Energy Usage with Anomalous Days')
plt.xlabel('Date')
plt.ylabel('Energy Usage')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Convert the "Reading Time" column to a datetime object
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Extract the date and hour from the timestamp
filtered_march['Date'] = filtered_march['Reading time'].dt.date
filtered_march['Hour'] = filtered_march['Reading time'].dt.hour

# Group the data by Date and Hour, and sum the energy usage for each hour
hourly_energy_usageev4 = filtered_march.groupby(['Date', 'Hour'])['Difference'].sum()

hourly_energy_usageev4 = hourly_energy_usageev4.reset_index()

# %%
hourly_energy_usageev4
# Out:
#            Date  Hour  Difference
# 0    2023-03-01     0        0.09
# 1    2023-03-01     1        0.00
# 2    2023-03-01     2        0.01
# 3    2023-03-01     3        0.00
# 4    2023-03-01     4        0.00
# ..          ...   ...         ...
# 721  2023-03-31    11        0.00
# 722  2023-03-31    12        0.00
# 723  2023-03-31    13        0.00
# 724  2023-03-31    14        0.00
# 725  2023-03-31    15        0.00
#
# [726 rows x 3 columns]

# %%
hourly_energy_usageev4.to_csv("hourly_energy_usageev4.csv", index=False)

# %%
filtered_march['Hour'] = filtered_march['Reading time'].dt.hour

# Group the data by Hour and sum the energy usage for each hour over the entire 31 days
hourly_energy_usage1ev4 = filtered_march.groupby('Hour')['Difference'].sum()

# Reset the index to make it a DataFrame
hourly_energy_usage1ev4 = hourly_energy_usage1ev4.reset_index()

# Save the result to a new CSV file
hourly_energy_usage1ev4.to_csv("hourly_energy_usage_over_31_daysev4.csv", index=False)

# %%
hourly_energy_usage1ev4
# Out:
#     Hour  Difference
# 0      0       19.75
# 1      1       17.94
# 2      2       16.25
# 3      3       13.93
# 4      4       17.26
# 5      5       13.46
# 6      6       11.42
# 7      7       11.42
# 8      8        9.29
# 9      9        4.30
# 10    10        5.12
# 11    11       24.12
# 12    12       27.00
# 13    13       21.78
# 14    14       17.16
# 15    15       12.77
# 16    16       14.45
# 17    17       10.98
# 18    18       10.17
# 19    19       22.92
# 20    20       23.97
# 21    21       19.88
# 22    22       11.00
# 23    23       13.40

# %%
total_energy_usage = filtered_march['Difference'].sum()

# %%
total_energy_usage
# Out:
# 369.7399999999998

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame called 'filtered_march' with columns 'Reading time' and 'Difference'
# Convert 'Reading time' to a datetime format
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Group the data by day and hour
filtered_march['date'] = filtered_march['Reading time'].dt.date
filtered_march['hour'] = filtered_march['Reading time'].dt.hour
hourly_usage = filtered_march.groupby(['date', 'hour'])['Difference'].sum()

# Pivot the data to have days on the y-axis and hours on the x-axis
hourly_usage_pivot = hourly_usage.unstack(level='date').fillna(0)

# Create a heatmap to visualize the data with red shades and white cell borders
plt.figure(figsize=(12, 6))
sns.heatmap(hourly_usage_pivot, cmap='Reds', cbar_kws={'label': 'Energy Usage (kWh)'},
            linewidths=0.5, linecolor='white')

# Customize the plot

plt.xlabel('Date')
plt.ylabel('Hour of the Day')

# Format x-axis labels to include both day and month
date_labels = [f"{d.day} {d.strftime('%B')}" for d in hourly_usage_pivot.columns]
plt.xticks(ticks=range(len(hourly_usage_pivot.columns)), labels=date_labels, rotation=45)

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame called 'ev_data' with columns 'reading_time' and 'energy_usage'
# Convert 'reading_time' to a datetime format
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Group the data by day and hour
filtered_march['date'] = filtered_march['Reading time'].dt.date
filtered_march['hour'] = filtered_march['Reading time'].dt.hour
hourly_usage = filtered_march.groupby(['date', 'hour'])['Difference'].sum()

# Pivot the data to have days on the y-axis and hours on the x-axis
hourly_usage_pivot = hourly_usage.unstack(level='date').fillna(0)

# Create a line plot to visualize the data
plt.figure(figsize=(10, 6))

# Plot a line for each day
for date in hourly_usage_pivot.columns:
    plt.plot(hourly_usage_pivot.index, hourly_usage_pivot[date], label=date)

plt.title('Hourly Energy Usage for Charging Station')
plt.xlabel('Hour of the Day')
plt.ylabel('Energy Usage (kWh)')
plt.legend(title='Date')

# Display the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Patch

# Assuming you have a DataFrame called 'filtered_march' with columns 'Reading time' and 'Difference'
# Convert 'Reading time' to a datetime format
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Group the data by day and hour
filtered_march['date'] = filtered_march['Reading time'].dt.date
filtered_march['hour'] = filtered_march['Reading time'].dt.hour
hourly_usage = filtered_march.groupby(['date', 'hour'])['Difference'].sum()

# Pivot the data to have days on the y-axis and hours on the x-axis
hourly_usage_pivot = hourly_usage.unstack(level='date').fillna(0)

# Create a line plot to visualize the data
plt.figure(figsize=(12, 8))
sns.set(style="whitegrid")

# Plot a line for each day with distinct colors
colors = sns.color_palette("husl", n_colors=len(hourly_usage_pivot.columns))
for i, date in enumerate(hourly_usage_pivot.columns):
    plt.plot(hourly_usage_pivot.index, hourly_usage_pivot[date], color=colors[i], linewidth=2)

# Create custom legend with colored bars
legend_labels = [date.strftime('%d %B') for date in hourly_usage_pivot.columns]
legend_handles = [Patch(color=colors[i], label=label) for i, label in enumerate(legend_labels)]

# Add the legend with colored bars in a matrix format
plt.legend(handles=legend_handles, title='Date', title_fontsize='12', fontsize='10', bbox_to_anchor=(1.05, 1), loc='upper left', ncol=2)  # Set ncol to the number of columns you desire

# Customize plot details
plt.title('Hourly Energy Usage for Charging Station', fontsize=16)
plt.xlabel('Hour of the Day', fontsize=14)
plt.ylabel('Energy Usage (kWh)', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Assuming your DataFrame is named filtered_march

# Convert 'Reading time' to Timestamp with the same timezone
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Define the date for March 8th and March 22nd
march_8_date = pd.Timestamp('2023-03-08', tz='Asia/Kolkata')
march_22_date = pd.Timestamp('2023-03-22', tz='Asia/Kolkata')

# Mark March 8th and March 22nd as holidays
filtered_march['Holiday'] = 'Other Days'
filtered_march.loc[filtered_march['Reading time'].dt.date.isin([march_8_date.date(), march_22_date.date()]), 'Holiday'] = 'Holiday'

# Calculate total energy consumption on holidays
holiday_energy_consumption = filtered_march[
    (filtered_march['Holiday'] == 'Holiday')
]['Difference'].sum()

# Calculate total energy consumption on other days
other_days_energy_consumption = filtered_march[
    (filtered_march['Holiday'] == 'Other Days')
]['Difference'].sum()

# Display the total energy consumption
print(f'Total Energy Consumption on Holidays: {holiday_energy_consumption} units')
print(f'Total Energy Consumption on Other Days: {other_days_energy_consumption} units')
# Out:
# Total Energy Consumption on Holidays: 22.039999999999964 units
# Total Energy Consumption on Other Days: 347.6999999999998 units

# %%
# Assuming your DataFrame is named filtered_march

# Convert 'Reading time' to Timestamp with the same timezone
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Define the date for March 8th and March 22nd
march_8_date = pd.Timestamp('2023-03-08', tz='Asia/Kolkata')
march_22_date = pd.Timestamp('2023-03-22', tz='Asia/Kolkata')

# Mark March 8th and March 22nd as holidays
filtered_march['Holiday'] = 'Other Days'
filtered_march.loc[filtered_march['Reading time'].dt.date.isin([march_8_date.date(), march_22_date.date()]), 'Holiday'] = 'Holiday'

# Calculate average energy consumption on holidays and other days
average_holiday_consumption = filtered_march[filtered_march['Holiday'] == 'Holiday']['Difference'].mean()
average_other_days_consumption = filtered_march[filtered_march['Holiday'] == 'Other Days']['Difference'].mean()

# Display the average energy consumption
print(f'Average Energy Consumption on Holidays: {average_holiday_consumption} units')
print(f'Average Energy Consumption on Other Days: {average_other_days_consumption} units')

# Check if holiday consumption is higher than normal
if average_holiday_consumption > average_other_days_consumption:
    print('Holiday consumption is higher than normal.')
else:
    print('Holiday consumption is normal or lower than normal.')
# Out:
# Average Energy Consumption on Holidays: 0.06974683544303786 units
# Average Energy Consumption on Other Days: 0.06386847905951502 units
# Holiday consumption is higher than normal.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named filtered_march

# Convert 'Reading time' to Timestamp with the same timezone
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Define the date for March 8th and March 22nd
march_8_date = pd.Timestamp('2023-03-08', tz='Asia/Kolkata')
march_22_date = pd.Timestamp('2023-03-22', tz='Asia/Kolkata')

# Mark March 8th and March 22nd as holidays
filtered_march['Holiday'] = 'Other Days'
filtered_march.loc[filtered_march['Reading time'].dt.date.isin([march_8_date.date(), march_22_date.date()]), 'Holiday'] = 'Holiday'

# Set the style of seaborn for better aesthetics
sns.set(style="whitegrid")

# Plot the hourly consumption pattern
plt.figure(figsize=(12, 6))
sns.lineplot(x=filtered_march['Hour'], y=filtered_march['Difference'], hue=filtered_march['Holiday'], ci=None)
plt.title('Hourly Energy Consumption Pattern on Holidays and Other Days')
plt.xlabel('Hour of the Day')
plt.ylabel('Energy Consumption(kWh)')
plt.legend(title='Day Type')
plt.show()

# %%
import pandas as pd

# Assuming your DataFrame is named filtered_march

# Convert 'Reading time' to Timestamp with the same timezone
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Define the date for March 8th and March 22nd
march_8_date = pd.Timestamp('2023-03-08', tz='Asia/Kolkata')
march_22_date = pd.Timestamp('2023-03-22', tz='Asia/Kolkata')

# Mark March 8th and March 22nd as holidays
filtered_march['Holiday'] = 'Other Days'
filtered_march.loc[filtered_march['Reading time'].dt.date.isin([march_8_date.date(), march_22_date.date()]), 'Holiday'] = 'Holiday'

# Filter data for holidays only
holiday_data = filtered_march[filtered_march['Holiday'] == 'Holiday']

# Find the hour with the highest energy consumption on holidays
max_hour_holiday = holiday_data.loc[holiday_data['Difference'].idxmax()]['Hour']

# Display the result
print(f'Time of the day with the highest energy consumption on holidays: {max_hour_holiday} hours')
# Out:
# Time of the day with the highest energy consumption on holidays: 13 hours

# %%
# Resample the data on a daily basis and sum the 'Difference' values for each day
daily_df = filtered_march.resample('D', on='Reading time').sum()

# Calculate summary statistics for daily energy consumption
mean_daily_energy = daily_df['Difference'].mean()
median_daily_energy = daily_df['Difference'].median()
std_dev_daily_energy = daily_df['Difference'].std()

# Display the summary statistics for daily energy consumption
print(f'Mean Daily Energy Consumption: {mean_daily_energy}')
print(f'Median Daily Energy Consumption: {median_daily_energy}')
print(f'Standard Deviation of Daily Energy Consumption: {std_dev_daily_energy}')
# Out:
# Mean Daily Energy Consumption: 11.927096774193542
# Median Daily Energy Consumption: 13.949999999999818
# Standard Deviation of Daily Energy Consumption: 7.25361527954551

# %%
import pandas as pd

# Assuming your DataFrame is called 'filtered_march'

# Initialize variables
charging_sessions = 0
charging = False

# Iterate through the DataFrame
for index, row in filtered_march.iterrows():
    diff = row['Difference']
    
    # Check if the current value is greater than 0 and not currently charging
    if diff > 0 and not charging:
        charging_sessions += 1
        charging = True
    elif diff == 0 and charging:
        charging = False

# Print the result
print("Total number of charging sessions:", charging_sessions)
# Out:
# Total number of charging sessions: 244

# %%
import pandas as pd

# Assuming your DataFrame is called 'filtered_march'

# Initialize variables
charging_sessions = 0
charging = False
total_sessions_greater_than_025 = 0

# Iterate through the DataFrame
for index, row in filtered_march.iterrows():
    diff = row['Difference']
    
    # Check if the current value is greater than 0 and not currently charging
    if diff > 0 and not charging:
        charging_sessions += 1
        charging = True
        energy_in_session = diff
    elif diff > 0 and charging:
        energy_in_session += diff
    elif diff == 0 and charging:
        charging = False
        print(f"Energy consumption in session {charging_sessions}: {energy_in_session}")
        
        # Check if the energy consumption in the session is greater than 0.25
        if energy_in_session > 0.25:
            total_sessions_greater_than_025 += 1

# Check if the last session is still ongoing and if the total energy consumption in the session is greater than 0.25
if charging and energy_in_session > 0.25:
    print(f"Energy consumption in session {charging_sessions}: {energy_in_session}")
    total_sessions_greater_than_025 += 1

# Print the total number of sessions where energy consumption is greater than 0.25
print("Total number of sessions where energy consumption is greater than 0.25:", total_sessions_greater_than_025)
# Out:
# Energy consumption in session 1: 0.08999999999991815
# Energy consumption in session 2: 0.009999999999990905
# Energy consumption in session 3: 0.009999999999990905
# Energy consumption in session 4: 0.35999999999989996
# Energy consumption in session 5: 6.310000000000173
# Energy consumption in session 6: 0.5599999999999454
# Energy consumption in session 7: 0.4800000000000182
# Energy consumption in session 8: 0.25
# Energy consumption in session 9: 5.519999999999982
# Energy consumption in session 10: 0.009999999999990905
# Energy consumption in session 11: 0.009999999999990905
# Energy consumption in session 12: 0.009999999999990905
# Energy consumption in session 13: 0.5099999999999909
# Energy consumption in session 14: 0.40000000000009095
# Energy consumption in session 15: 5.779999999999973
# Energy consumption in session 16: 0.5799999999999272
# Energy consumption in session 17: 0.5199999999999818
# Energy consumption in session 18: 3.8700000000001182
# Energy consumption in session 19: 2.459999999999809
# Energy consumption in session 20: 0.010000000000218279
# Energy consumption in session 21: 1.2699999999999818
# Energy consumption in session 22: 0.9699999999997999
# Energy consumption in session 23: 0.3000000000001819
# Energy consumption in session 24: 4.730000000000018
# Energy consumption in session 25: 0.5
# Energy consumption in session 26: 6.259999999999991
# Energy consumption in session 27: 0.009999999999990905
# Energy consumption in session 28: 0.009999999999990905
# Energy consumption in session 29: 0.6099999999999
# Energy consumption in session 30: 0.5099999999999909
# Energy consumption in session 31: 0.2799999999999727
# Energy consumption in session 32: 6.360000000000127
# Energy consumption in session 33: 0.2899999999999636
# Energy consumption in session 34: 0.2699999999999818
# Energy consumption in session 35: 0.2899999999999636
# Energy consumption in session 36: 3.2999999999999545
# Energy consumption in session 37: 4.600000000000136
# Energy consumption in session 38: 0.009999999999990905
# Energy consumption in session 39: 0.9099999999998545
# Energy consumption in session 40: 2.740000000000009
# Energy consumption in session 41: 7.560000000000173
# Energy consumption in session 42: 0.009999999999990905
# Energy consumption in session 43: 0.009999999999990905
# Energy consumption in session 44: 6.75
# Energy consumption in session 45: 0.009999999999990905
# Energy consumption in session 46: 0.009999999999990905
# Energy consumption in session 47: 0.37999999999988177
# Energy consumption in session 48: 0.4600000000000364
# Energy consumption in session 49: 2.6900000000000546
# Energy consumption in session 50: 3.619999999999891
# Energy consumption in session 51: 0.009999999999990905
# Energy consumption in session 52: 0.009999999999990905
# Energy consumption in session 53: 5.540000000000191
# Energy consumption in session 54: 3.3799999999998818
# Energy consumption in session 55: 0.009999999999990905
# Energy consumption in session 56: 0.009999999999990905
# Energy consumption in session 57: 0.009999999999990905
# Energy consumption in session 58: 0.009999999999990905
# Energy consumption in session 59: 0.009999999999990905
# Energy consumption in session 60: 0.2699999999999818
# Energy consumption in session 61: 4.670000000000073
# Energy consumption in session 62: 3.3900000000001
# Energy consumption in session 63: 3.2200000000000273
# Energy consumption in session 64: 0.009999999999990905
# Energy consumption in session 65: 0.009999999999990905
# Energy consumption in session 66: 0.009999999999990905
# Energy consumption in session 67: 0.009999999999990905
# Energy consumption in session 68: 2.4500000000000455
# Energy consumption in session 69: 0.009999999999990905
# Energy consumption in session 70: 0.009999999999990905
# Energy consumption in session 71: 0.25
# Energy consumption in session 72: 4.169999999999845
# Energy consumption in session 73: 7.730000000000018
# Energy consumption in session 74: 0.2699999999999818
# Energy consumption in session 75: 2.75
# Energy consumption in session 76: 5.350000000000136
# Energy consumption in session 77: 1.25
# Energy consumption in session 78: 6.559999999999945
# Energy consumption in session 79: 0.009999999999990905
# Energy consumption in session 80: 0.009999999999990905
# Energy consumption in session 81: 3.9400000000000546
# Energy consumption in session 82: 0.2799999999999727
# Energy consumption in session 83: 4.269999999999982
# Energy consumption in session 84: 13.400000000000091
# Energy consumption in session 85: 0.009999999999990905
# Energy consumption in session 86: 1.0
# Energy consumption in session 87: 5.709999999999809
# Energy consumption in session 88: 1.4100000000000819
# Energy consumption in session 89: 7.170000000000073
# Energy consumption in session 90: 0.009999999999990905
# Energy consumption in session 91: 0.009999999999990905
# Energy consumption in session 92: 0.009999999999990905
# Energy consumption in session 93: 0.009999999999990905
# Energy consumption in session 94: 0.32999999999992724
# Energy consumption in session 95: 2.7200000000000273
# Energy consumption in session 96: 5.7000000000000455
# Energy consumption in session 97: 0.009999999999990905
# Energy consumption in session 98: 0.4900000000000091
# Energy consumption in session 99: 0.2899999999999636
# Energy consumption in session 100: 0.2799999999999727
# Energy consumption in session 101: 5.8900000000001
# Energy consumption in session 102: 2.6900000000000546
# Energy consumption in session 103: 1.1699999999998454
# Energy consumption in session 104: 3.2100000000000364
# Energy consumption in session 105: 0.009999999999990905
# Energy consumption in session 106: 0.009999999999990905
# Energy consumption in session 107: 0.009999999999990905
# Energy consumption in session 108: 0.009999999999990905
# Energy consumption in session 109: 0.22000000000002728
# Energy consumption in session 110: 0.22000000000002728
# Energy consumption in session 111: 5.809999999999945
# Energy consumption in session 112: 0.6400000000001
# Energy consumption in session 113: 0.2300000000000182
# Energy consumption in session 114: 0.2799999999999727
# Energy consumption in session 115: 0.2599999999999909
# Energy consumption in session 116: 1.3199999999999363
# Energy consumption in session 117: 6.180000000000064
# Energy consumption in session 118: 1.6599999999998545
# Energy consumption in session 119: 0.5200000000002092
# Energy consumption in session 120: 0.2799999999999727
# Energy consumption in session 121: 0.25
# Energy consumption in session 122: 0.2400000000000091
# Energy consumption in session 123: 5.490000000000009
# Energy consumption in session 124: 0.5399999999999636
# Energy consumption in session 125: 0.4600000000000364
# Energy consumption in session 126: 0.2999999999999545
# Energy consumption in session 127: 6.2999999999999545
# Energy consumption in session 128: 0.009999999999990905
# Energy consumption in session 129: 0.009999999999990905
# Energy consumption in session 130: 0.009999999999990905
# Energy consumption in session 131: 0.25
# Energy consumption in session 132: 6.480000000000018
# Energy consumption in session 133: 4.150000000000091
# Energy consumption in session 134: 7.7999999999999545
# Energy consumption in session 135: 0.5499999999999545
# Energy consumption in session 136: 0.4600000000000364
# Energy consumption in session 137: 0.2300000000000182
# Energy consumption in session 138: 0.25
# Energy consumption in session 139: 0.25
# Energy consumption in session 140: 3.730000000000018
# Energy consumption in session 141: 5.429999999999836
# Energy consumption in session 142: 0.009999999999990905
# Energy consumption in session 143: 0.9500000000000455
# Energy consumption in session 144: 0.2799999999999727
# Energy consumption in session 145: 5.400000000000091
# Energy consumption in session 146: 1.0199999999999818
# Energy consumption in session 147: 0.09999999999990905
# Energy consumption in session 148: 0.3100000000001728
# Energy consumption in session 149: 0.2400000000000091
# Energy consumption in session 150: 5.539999999999964
# Energy consumption in session 151: 1.7100000000000364
# Energy consumption in session 152: 0.7799999999999727
# Energy consumption in session 153: 4.269999999999982
# Energy consumption in session 154: 0.9300000000000637
# Energy consumption in session 155: 0.2899999999999636
# Energy consumption in session 156: 6.440000000000055
# Energy consumption in session 157: 0.5099999999999909
# Energy consumption in session 158: 0.5499999999999545
# Energy consumption in session 159: 12.720000000000027
# Energy consumption in session 160: 0.459999999999809
# Energy consumption in session 161: 0.2600000000002183
# Energy consumption in session 162: 6.879999999999882
# Energy consumption in session 163: 12.279999999999973
# Energy consumption in session 164: 0.009999999999990905
# Energy consumption in session 165: 7.2999999999999545
# Energy consumption in session 166: 0.3000000000001819
# Energy consumption in session 167: 5.3599999999999
# Energy consumption in session 168: 1.5499999999999545
# Energy consumption in session 169: 1.9800000000000182
# Energy consumption in session 170: 0.009999999999990905
# Energy consumption in session 171: 0.36000000000012733
# Energy consumption in session 172: 4.039999999999964
# Energy consumption in session 173: 0.3999999999998636
# Energy consumption in session 174: 0.9400000000000546
# Energy consumption in session 175: 4.970000000000027
# Energy consumption in session 176: 0.009999999999990905
# Energy consumption in session 177: 0.01999999999998181
# Energy consumption in session 178: 0.009999999999990905
# Energy consumption in session 179: 0.009999999999990905
# Energy consumption in session 180: 0.2799999999999727
# Energy consumption in session 181: 10.440000000000055
# Energy consumption in session 182: 1.6100000000001273
# Energy consumption in session 183: 3.1499999999998636
# Energy consumption in session 184: 0.37000000000011823
# Energy consumption in session 185: 7.5
# Energy consumption in session 186: 0.03999999999996362
# Energy consumption in session 187: 0.03999999999996362
# Energy consumption in session 188: 0.01999999999998181
# Energy consumption in session 189: 0.05999999999994543
# Energy consumption in session 190: 0.009999999999990905
# Energy consumption in session 191: 0.01999999999998181
# Energy consumption in session 192: 0.009999999999990905
# Energy consumption in session 193: 0.009999999999990905
# Energy consumption in session 194: 0.020000000000209184
# Energy consumption in session 195: 0.01999999999998181
# Energy consumption in session 196: 0.01999999999998181
# Energy consumption in session 197: 0.16999999999984539
# Energy consumption in session 198: 0.0500000000001819
# Energy consumption in session 199: 0.03999999999996362
# Energy consumption in session 200: 0.03999999999996362
# Energy consumption in session 201: 0.029999999999972715
# Energy consumption in session 202: 0.06999999999993634
# Energy consumption in session 203: 0.01999999999998181
# Energy consumption in session 204: 0.03000000000020009
# Energy consumption in session 205: 0.06999999999993634
# Energy consumption in session 206: 0.009999999999990905
# Energy consumption in session 207: 0.12999999999988177
# Energy consumption in session 208: 0.009999999999990905
# Energy consumption in session 209: 0.13000000000010914
# Energy consumption in session 210: 0.009999999999990905
# Energy consumption in session 211: 0.009999999999990905
# Energy consumption in session 212: 0.009999999999990905
# Energy consumption in session 213: 0.009999999999990905
# Energy consumption in session 214: 0.009999999999990905
# Energy consumption in session 215: 0.029999999999972715
# Energy consumption in session 216: 0.009999999999990905
# Energy consumption in session 217: 0.009999999999990905
# Energy consumption in session 218: 0.009999999999990905
# Energy consumption in session 219: 0.01999999999998181
# Energy consumption in session 220: 0.009999999999990905
# Energy consumption in session 221: 0.010000000000218279
# Energy consumption in session 222: 0.009999999999990905
# Energy consumption in session 223: 0.009999999999990905
# Energy consumption in session 224: 0.009999999999990905
# Energy consumption in session 225: 0.009999999999990905
# Energy consumption in session 226: 0.009999999999990905
# Energy consumption in session 227: 0.009999999999990905
# Energy consumption in session 228: 0.009999999999990905
# Energy consumption in session 229: 0.009999999999990905
# Energy consumption in session 230: 0.009999999999990905
# Energy consumption in session 231: 0.009999999999990905
# Energy consumption in session 232: 0.009999999999990905
# Energy consumption in session 233: 0.01999999999998181
# Energy consumption in session 234: 0.009999999999990905
# Energy consumption in session 235: 0.009999999999990905
# Energy consumption in session 236: 0.009999999999990905
# Energy consumption in session 237: 0.009999999999990905
# Energy consumption in session 238: 0.009999999999990905
# Energy consumption in session 239: 0.009999999999990905
# Energy consumption in session 240: 0.009999999999990905
# Energy consumption in session 241: 0.009999999999990905
# Energy consumption in session 242: 0.009999999999990905
# Energy consumption in session 243: 0.009999999999990905
# Energy consumption in session 244: 0.009999999999990905
# Total number of sessions where energy consumption is greater than 0.25: 123

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense

# Assuming your DataFrame is called 'filtered_march'
# Make sure 'Reading time' column is in datetime format
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Extract relevant columns and set 'Reading time' as the index
df = filtered_march[['Reading time', 'Difference']].set_index('Reading time')

# Resample the data to hourly frequency and sum the energy consumption for each hour
hourly_energy = df.resample('H').sum()

# Normalize the data
scaler = MinMaxScaler()
scaled_energy = scaler.fit_transform(hourly_energy)

# Function to create time series dataset
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# Define the look-back period (number of previous hours to consider)
look_back = 24  # For example, using the past 24 hours to predict the next hour

# Create the dataset with the look-back period
X, Y = create_dataset(scaled_energy, look_back)

# Reshape the input data for LSTM
X = np.reshape(X, (X.shape[0], 1, X.shape[1]))

# Create and compile the LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(X, Y, epochs=50, batch_size=1, verbose=2)

# Forecast energy consumption for a single day
# Use the last 24 hours of available data to predict the next hour
last_24_hours = scaled_energy[-look_back:]
forecast_input = np.reshape(last_24_hours, (1, 1, look_back))
forecast = model.predict(forecast_input)

# Invert the forecast to get it in the original scale
forecast = scaler.inverse_transform(np.reshape(forecast, (forecast.shape[0], 1)))

print(f"Forecasted energy consumption for the next hour: {forecast[0][0]}")
# Out:
# WARNING:tensorflow:From C:\Users\et22m\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\et22m\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\et22m\anaconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\et22m\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 712/712 - 6s - loss: 0.0223 - 6s/epoch - 9ms/step
# Epoch 2/50
# 712/712 - 3s - loss: 0.0194 - 3s/epoch - 4ms/step
# Epoch 3/50
# 712/712 - 3s - loss: 0.0188 - 3s/epoch - 4ms/step
# Epoch 4/50
# 712/712 - 3s - loss: 0.0177 - 3s/epoch - 4ms/step
# Epoch 5/50
# 712/712 - 3s - loss: 0.0173 - 3s/epoch - 4ms/step
# Epoch 6/50
# 712/712 - 3s - loss: 0.0174 - 3s/epoch - 4ms/step
# Epoch 7/50
# 712/712 - 3s - loss: 0.0170 - 3s/epoch - 5ms/step
# Epoch 8/50
# 712/712 - 3s - loss: 0.0167 - 3s/epoch - 4ms/step
# Epoch 9/50
# 712/712 - 3s - loss: 0.0166 - 3s/epoch - 4ms/step
# Epoch 10/50
# 712/712 - 3s - loss: 0.0164 - 3s/epoch - 4ms/step
# Epoch 11/50
# 712/712 - 2s - loss: 0.0160 - 2s/epoch - 3ms/step
# Epoch 12/50
# 712/712 - 3s - loss: 0.0159 - 3s/epoch - 4ms/step
# Epoch 13/50
# 712/712 - 3s - loss: 0.0155 - 3s/epoch - 4ms/step
# Epoch 14/50
# 712/712 - 3s - loss: 0.0153 - 3s/epoch - 4ms/step
# Epoch 15/50
# 712/712 - 3s - loss: 0.0153 - 3s/epoch - 4ms/step
# Epoch 16/50
# 712/712 - 2s - loss: 0.0151 - 2s/epoch - 3ms/step
# Epoch 17/50
# 712/712 - 3s - loss: 0.0149 - 3s/epoch - 4ms/step
# Epoch 18/50
# 712/712 - 3s - loss: 0.0145 - 3s/epoch - 4ms/step
# Epoch 19/50
# 712/712 - 3s - loss: 0.0145 - 3s/epoch - 4ms/step
# Epoch 20/50
# 712/712 - 3s - loss: 0.0141 - 3s/epoch - 4ms/step
# Epoch 21/50
# 712/712 - 3s - loss: 0.0142 - 3s/epoch - 4ms/step
# Epoch 22/50
# 712/712 - 3s - loss: 0.0138 - 3s/epoch - 4ms/step
# Epoch 23/50
# 712/712 - 3s - loss: 0.0137 - 3s/epoch - 4ms/step
# Epoch 24/50
# 712/712 - 2s - loss: 0.0135 - 2s/epoch - 3ms/step
# Epoch 25/50
# 712/712 - 2s - loss: 0.0132 - 2s/epoch - 3ms/step
# Epoch 26/50
# 712/712 - 3s - loss: 0.0131 - 3s/epoch - 4ms/step
# Epoch 27/50
# 712/712 - 3s - loss: 0.0129 - 3s/epoch - 4ms/step
# Epoch 28/50
# 712/712 - 3s - loss: 0.0129 - 3s/epoch - 4ms/step
# Epoch 29/50
# 712/712 - 3s - loss: 0.0129 - 3s/epoch - 4ms/step
# Epoch 30/50
# 712/712 - 2s - loss: 0.0125 - 2s/epoch - 3ms/step
# Epoch 31/50
# 712/712 - 2s - loss: 0.0125 - 2s/epoch - 3ms/step
# Epoch 32/50
# 712/712 - 2s - loss: 0.0122 - 2s/epoch - 4ms/step
# Epoch 33/50
# 712/712 - 2s - loss: 0.0123 - 2s/epoch - 3ms/step
# Epoch 34/50
# 712/712 - 3s - loss: 0.0120 - 3s/epoch - 4ms/step
# Epoch 35/50
# 712/712 - 2s - loss: 0.0118 - 2s/epoch - 4ms/step
# Epoch 36/50
# 712/712 - 3s - loss: 0.0115 - 3s/epoch - 4ms/step
# Epoch 37/50
# 712/712 - 3s - loss: 0.0116 - 3s/epoch - 4ms/step
# Epoch 38/50
# 712/712 - 3s - loss: 0.0116 - 3s/epoch - 4ms/step
# Epoch 39/50
# 712/712 - 3s - loss: 0.0113 - 3s/epoch - 4ms/step
# Epoch 40/50
# 712/712 - 3s - loss: 0.0110 - 3s/epoch - 4ms/step
# Epoch 41/50
# 712/712 - 3s - loss: 0.0107 - 3s/epoch - 4ms/step
# Epoch 42/50
# 712/712 - 3s - loss: 0.0108 - 3s/epoch - 4ms/step
# Epoch 43/50
# 712/712 - 3s - loss: 0.0105 - 3s/epoch - 4ms/step
# Epoch 44/50
# 712/712 - 3s - loss: 0.0105 - 3s/epoch - 4ms/step
# Epoch 45/50
# 712/712 - 3s - loss: 0.0100 - 3s/epoch - 4ms/step
# Epoch 46/50
# 712/712 - 3s - loss: 0.0102 - 3s/epoch - 4ms/step
# Epoch 47/50
# 712/712 - 3s - loss: 0.0100 - 3s/epoch - 4ms/step
# Epoch 48/50
# 712/712 - 2s - loss: 0.0098 - 2s/epoch - 3ms/step
# Epoch 49/50
# 712/712 - 3s - loss: 0.0098 - 3s/epoch - 4ms/step
# Epoch 50/50
# 712/712 - 3s - loss: 0.0094 - 3s/epoch - 4ms/step
# 1/1 [==============================] - 1s 1s/step
# Forecasted energy consumption for the next hour: 0.032823335379362106

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

# Assuming your DataFrame is called 'filtered_march'
# Make sure 'Reading time' column is in datetime format
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Extract relevant columns and set 'Reading time' as the index
df = filtered_march[['Reading time', 'Difference']].set_index('Reading time')

# Resample the data to daily frequency and sum the energy consumption for each day
daily_energy = df.resample('D').sum()

# Normalize the data
scaler = MinMaxScaler()
scaled_energy = scaler.fit_transform(daily_energy)

# Function to create time series dataset
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# Define the look-back period (number of previous days to consider)
look_back = 29  # Using the past 7 days to predict the next day

# Create the dataset with the look-back period
X, Y = create_dataset(scaled_energy, look_back)

# Reshape the input data for LSTM
X = np.reshape(X, (X.shape[0], 1, X.shape[1]))

# Create and compile the LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(X, Y, epochs=50, batch_size=1, verbose=2)

# Forecast energy consumption for the next day
last_week = scaled_energy[-look_back:]
forecast_input = np.reshape(last_week, (1, 1, look_back))
forecast = model.predict(forecast_input)

# Invert the forecast to get it in the original scale
forecast = scaler.inverse_transform(np.reshape(forecast, (forecast.shape[0], 1)))

print(f"Forecasted energy consumption for the next day: {forecast[0][0]}")

# Plotting the actual and forecasted values
plt.figure(figsize=(12, 6))
plt.plot(daily_energy.index, daily_energy, label='Actual')
plt.plot(daily_energy.index[-1] + pd.DateOffset(days=1), forecast[0], marker='o', color='red', label='Forecasted')
plt.xlabel('Date')
plt.ylabel('Energy Consumption')
plt.title('Actual vs Forecasted Energy Consumption for the Next Day')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 2/2 - 3s - loss: 0.0106 - 3s/epoch - 2s/step
# Epoch 2/50
# 2/2 - 0s - loss: 0.0046 - 11ms/epoch - 6ms/step
# Epoch 3/50
# 2/2 - 0s - loss: 0.0041 - 22ms/epoch - 11ms/step
# Epoch 4/50
# 2/2 - 0s - loss: 0.0039 - 15ms/epoch - 8ms/step
# Epoch 5/50
# 2/2 - 0s - loss: 0.0027 - 16ms/epoch - 8ms/step
# Epoch 6/50
# 2/2 - 0s - loss: 0.0015 - 15ms/epoch - 8ms/step
# Epoch 7/50
# 2/2 - 0s - loss: 0.0017 - 15ms/epoch - 8ms/step
# Epoch 8/50
# 2/2 - 0s - loss: 0.0016 - 16ms/epoch - 8ms/step
# Epoch 9/50
# 2/2 - 0s - loss: 0.0016 - 15ms/epoch - 7ms/step
# Epoch 10/50
# 2/2 - 0s - loss: 0.0011 - 15ms/epoch - 8ms/step
# Epoch 11/50
# 2/2 - 0s - loss: 6.1515e-04 - 17ms/epoch - 8ms/step
# Epoch 12/50
# 2/2 - 0s - loss: 5.0966e-04 - 15ms/epoch - 7ms/step
# Epoch 13/50
# 2/2 - 0s - loss: 3.9222e-04 - 18ms/epoch - 9ms/step
# Epoch 14/50
# 2/2 - 0s - loss: 4.0983e-04 - 16ms/epoch - 8ms/step
# Epoch 15/50
# 2/2 - 0s - loss: 3.8247e-04 - 18ms/epoch - 9ms/step
# Epoch 16/50
# 2/2 - 0s - loss: 1.6715e-04 - 17ms/epoch - 9ms/step
# Epoch 17/50
# 2/2 - 0s - loss: 4.0343e-05 - 18ms/epoch - 9ms/step
# Epoch 18/50
# 2/2 - 0s - loss: 1.1177e-05 - 15ms/epoch - 8ms/step
# Epoch 19/50
# 2/2 - 0s - loss: 6.2826e-05 - 15ms/epoch - 7ms/step
# Epoch 20/50
# 2/2 - 0s - loss: 9.7263e-05 - 15ms/epoch - 8ms/step
# Epoch 21/50
# 2/2 - 0s - loss: 6.6218e-05 - 16ms/epoch - 8ms/step
# Epoch 22/50
# 2/2 - 0s - loss: 1.5403e-05 - 14ms/epoch - 7ms/step
# Epoch 23/50
# 2/2 - 0s - loss: 8.8156e-06 - 15ms/epoch - 7ms/step
# Epoch 24/50
# 2/2 - 0s - loss: 3.0222e-05 - 17ms/epoch - 8ms/step
# Epoch 25/50
# 2/2 - 0s - loss: 3.6815e-05 - 15ms/epoch - 7ms/step
# Epoch 26/50
# 2/2 - 0s - loss: 2.3137e-05 - 15ms/epoch - 8ms/step
# Epoch 27/50
# 2/2 - 0s - loss: 7.9474e-06 - 15ms/epoch - 7ms/step
# Epoch 28/50
# 2/2 - 0s - loss: 6.5445e-06 - 15ms/epoch - 8ms/step
# Epoch 29/50
# 2/2 - 0s - loss: 2.0947e-05 - 15ms/epoch - 7ms/step
# Epoch 30/50
# 2/2 - 0s - loss: 2.2264e-05 - 14ms/epoch - 7ms/step
# Epoch 31/50
# 2/2 - 0s - loss: 1.1454e-05 - 14ms/epoch - 7ms/step
# Epoch 32/50
# 2/2 - 0s - loss: 9.6183e-06 - 15ms/epoch - 7ms/step
# Epoch 33/50
# 2/2 - 0s - loss: 5.3662e-06 - 16ms/epoch - 8ms/step
# Epoch 34/50
# 2/2 - 0s - loss: 7.6824e-06 - 15ms/epoch - 8ms/step
# Epoch 35/50
# 2/2 - 0s - loss: 5.6951e-06 - 18ms/epoch - 9ms/step
# Epoch 36/50
# 2/2 - 0s - loss: 2.3968e-06 - 14ms/epoch - 7ms/step
# Epoch 37/50
# 2/2 - 0s - loss: 6.5893e-07 - 15ms/epoch - 7ms/step
# Epoch 38/50
# 2/2 - 0s - loss: 1.3909e-06 - 15ms/epoch - 8ms/step
# Epoch 39/50
# 2/2 - 0s - loss: 2.0911e-06 - 16ms/epoch - 8ms/step
# Epoch 40/50
# 2/2 - 0s - loss: 1.3106e-06 - 15ms/epoch - 8ms/step
# Epoch 41/50
# 2/2 - 0s - loss: 4.2824e-07 - 16ms/epoch - 8ms/step
# Epoch 42/50
# 2/2 - 0s - loss: 2.3974e-07 - 14ms/epoch - 7ms/step
# Epoch 43/50
# 2/2 - 0s - loss: 7.7316e-07 - 16ms/epoch - 8ms/step
# Epoch 44/50
# 2/2 - 0s - loss: 7.9970e-07 - 15ms/epoch - 8ms/step
# Epoch 45/50
# 2/2 - 0s - loss: 1.9196e-07 - 14ms/epoch - 7ms/step
# Epoch 46/50
# 2/2 - 0s - loss: 6.6477e-08 - 14ms/epoch - 7ms/step
# Epoch 47/50
# 2/2 - 0s - loss: 4.1196e-07 - 15ms/epoch - 7ms/step
# Epoch 48/50
# 2/2 - 0s - loss: 5.7987e-07 - 15ms/epoch - 7ms/step
# Epoch 49/50
# 2/2 - 0s - loss: 2.9527e-07 - 14ms/epoch - 7ms/step
# Epoch 50/50
# 2/2 - 0s - loss: 1.0544e-07 - 14ms/epoch - 7ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001AB0CFE1430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 830ms/step
# Forecasted energy consumption for the next day: 0.3377235531806946

# %%
filtered_march['Power'] = filtered_march['Difference'] / 0.25
total_power_consumption = filtered_march["Power"].sum()
total_power_consumption
# Out:
# 1478.9599999999991

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df' with columns: 'reading_time', 'Difference', 'Power(kW)'
# You may need to load your actual dataset using pd.read_csv or another appropriate method.
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Extract date from the timestamp
filtered_march['date'] = filtered_march['Reading time'].dt.date

# Calculate average and peak load for each day
daily_load = filtered_march.groupby('date')['Power'].agg(['mean', 'max'])

# Calculate load factor for each day
daily_load['load_factor'] = (daily_load['mean'] / daily_load['max']) * 100
print("Load Factor for Each Day:")
print(daily_load[['load_factor']])

# Plot the graph with improved aesthetics
plt.figure(figsize=(10, 6))
plt.plot(daily_load.index, daily_load['load_factor'], marker='o', linestyle='-', color='b', label='Load Factor')
plt.title('Daily Load Factor')
plt.xlabel('Date')
plt.ylabel('Load Factor (%)')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
day_labels = ['Day {}'.format(i + 1) for i in range(len(daily_load))]
plt.xticks(daily_load.index, day_labels, rotation=45)

plt.tight_layout()
plt.show()
# Out:
# Load Factor for Each Day:
#             load_factor
# date
# 2023-03-01    17.213542
# 2023-03-02    13.364362
# 2023-03-03    17.866848
# 2023-03-04    18.656517
# 2023-03-05    18.893229
# 2023-03-06    15.794837
# 2023-03-07    19.093528
# 2023-03-08    11.571558
# 2023-03-09    22.591146
# 2023-03-10     3.937810
# 2023-03-11    14.164474
# 2023-03-12    11.679965
# 2023-03-13    17.996454
# 2023-03-14    18.218085
# 2023-03-15    19.954233
# 2023-03-16    12.715127
# 2023-03-17    19.914773
# 2023-03-18    24.453125
# 2023-03-19    25.992908
# 2023-03-20    13.460039
# 2023-03-21    23.727965
# 2023-03-22    11.214421
# 2023-03-23    23.462907
# 2023-03-24    12.050879
# 2023-03-25     6.770833
# 2023-03-26     9.722222
# 2023-03-27     1.562500
# 2023-03-28          NaN
# 2023-03-29     0.806452
# 2023-03-30     4.736842
# 2023-03-31    18.032787

# %%
# Convert 'reading_time' column to datetime format
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Define tariff rates
tariff_rates = {
    'off-peak': 10,
    'peak': 20,
    'mid-peak': 15,
    'high-peak': 25
}

# Function to determine the tariff based on the time of day
def get_tariff(reading_time):
    hour = reading_time.hour
    if 23 <= hour or hour < 6:
        return 'off-peak'
    elif 7 <= hour < 11:
        return 'peak'
    elif 11 <= hour < 19:
        return 'mid-peak'
    else:
        return 'high-peak'

# Apply the get_tariff function to each row to get the tariff for each reading
filtered_march['tariff'] = filtered_march['Reading time'].apply(get_tariff)

# Calculate the price for each 15-minute interval
filtered_march['evprice'] = filtered_march.apply(lambda row: row['Difference'] * tariff_rates[row['tariff']], axis=1)

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit  Difference  \
# 5791          1444.88 2023-03-01 00:06:00+05:30  kWh        0.00
# 5792          1444.96 2023-03-01 00:21:05+05:30  kWh        0.08
# 5793          1444.97 2023-03-01 00:36:02+05:30  kWh        0.01
# 5794          1444.97 2023-03-01 00:50:58+05:30  kWh        0.00
# 5795          1444.97 2023-03-01 01:06:05+05:30  kWh        0.00
# ...               ...                       ...  ...         ...
# 11581            0.00 2023-03-31 14:06:26+05:30  kWh        0.00
# 11582            0.00 2023-03-31 14:21:29+05:30  kWh        0.00
# 11583            0.00 2023-03-31 14:36:29+05:30  kWh        0.00
# 11584            0.00 2023-03-31 14:51:31+05:30  kWh        0.00
# 11585            0.00 2023-03-31 15:06:31+05:30  kWh        0.00
#
#        Cumulative_Increase Time_Stamp    tariff  price  Day_of_Week  \
# 5791                  0.00   00-06-00  off-peak   0.00            2
# 5792                  0.08   00-21-05  off-peak   1.04            2
# 5793                  0.09   00-36-02  off-peak   0.13            2
# 5794                  0.09   00-50-58  off-peak   0.00            2
# 5795                  0.09   01-06-05  off-peak   0.00            2
# ...                    ...        ...       ...    ...          ...
# 11581               369.74   14-06-26  mid-peak   0.00            4
# 11582               369.74   14-21-29  mid-peak   0.00            4
# 11583               369.74   14-36-29  mid-peak   0.00            4
# 11584               369.74   14-51-31  mid-peak   0.00            4
# 11585               369.74   15-06-31  mid-peak   0.00            4
#
#       Weekday_Or_Weekend        Date  Hour        date  hour     Holiday  \
# 5791             Weekday  2023-03-01     0  2023-03-01     0  Other Days
# 5792             Weekday  2023-03-01     0  2023-03-01     0  Other Days
# 5793             Weekday  2023-03-01     0  2023-03-01     0  Other Days
# 5794             Weekday  2023-03-01     0  2023-03-01     0  Other Days
# 5795             Weekday  2023-03-01     1  2023-03-01     1  Other Days
# ...                  ...         ...   ...         ...   ...         ...
# 11581            Weekday  2023-03-31    14  2023-03-31    14  Other Days
# 11582            Weekday  2023-03-31    14  2023-03-31    14  Other Days
# 11583            Weekday  2023-03-31    14  2023-03-31    14  Other Days
# 11584            Weekday  2023-03-31    14  2023-03-31    14  Other Days
# 11585            Weekday  2023-03-31    15  2023-03-31    15  Other Days
#
#        evtariff  evprice
# 5791   off-peak      0.0
# 5792   off-peak      0.8
# 5793   off-peak      0.1
# 5794   off-peak      0.0
# 5795   off-peak      0.0
# ...         ...      ...
# 11581  mid-peak      0.0
# 11582  mid-peak      0.0
# 11583  mid-peak      0.0
# 11584  mid-peak      0.0
# 11585  mid-peak      0.0
#
# [5760 rows x 17 columns]

# %%
# Calculate the total of the 'price' column
total_price = filtered_march['evprice'].sum()
total_energy = filtered_march['Difference'].sum()
# Print the total
print(f"Total Energy :{round(total_energy,2)} Units")
print("Total Price Rs:", round(total_price,2))
# Out:
# Total Energy :369.74 Units
# Total Price Rs: 6028.7
