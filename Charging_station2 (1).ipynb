# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %%
charge_2 = pd.read_csv('IHM10050175.csv')

# %%
csv_file = 'IHM10050175.csv'

# %%
custom_delimiter = ';'

# %%
cha_station2 = pd.read_csv(csv_file, delimiter=custom_delimiter)

# %%
cha_station2.to_csv('output.csv', index=False, sep=custom_delimiter)

# %%
cha_station2
# Out:
#           Reading values               Profile               Reading time  \
# 0                  1.856  InstantaneousProfile  2023-02-05T08:00:00+05:30
# 1                  1.856  InstantaneousProfile  2023-02-05T08:00:00+05:30
# 2                  1.856  InstantaneousProfile  2023-02-05T08:00:00+05:30
# 3                  1.856  InstantaneousProfile  2023-02-05T08:00:00+05:30
# 4                  1.856  InstantaneousProfile  2023-02-05T08:00:00+05:30
# ...                  ...                   ...                        ...
# 60227            235.320    Block Load Profile  2023-03-31T14:00:00+05:30
# 60228            236.320    Block Load Profile  2023-03-31T14:30:00+05:30
# 60229            235.360    Block Load Profile  2023-03-31T15:00:00+05:30
# 60230  1,677,609,000.000       Billing Profile  2023-03-01T00:00:00+05:30
# 60231  1,677,609,589.000       Billing Profile  2023-03-01T00:09:49+05:30
#
#                      Insert time               Capture time        OBIS code  \
# 0      2023-02-28T00:00:54+05:30  2023-02-28T00:05:18+05:30    1-0:1.6.0*255
# 1      2023-02-28T00:16:04+05:30  2023-02-28T00:20:28+05:30    1-0:1.6.0*255
# 2      2023-02-28T00:30:52+05:30  2023-02-28T00:35:16+05:30    1-0:1.6.0*255
# 3      2023-02-28T00:46:06+05:30  2023-02-28T00:50:30+05:30    1-0:1.6.0*255
# 4      2023-02-28T01:00:54+05:30  2023-02-28T01:05:18+05:30    1-0:1.6.0*255
# ...                          ...                        ...              ...
# 60227  2023-03-31T14:15:41+05:30  2023-03-31T14:00:00+05:30  1-0:12.27.0*255
# 60228  2023-03-31T14:45:39+05:30  2023-03-31T14:30:00+05:30  1-0:12.27.0*255
# 60229  2023-03-31T15:15:46+05:30  2023-03-31T15:00:00+05:30  1-0:12.27.0*255
# 60230  2023-03-01T00:05:25+05:30  2023-03-01T00:00:00+05:30    0-0:0.1.2*255
# 60231  2023-03-01T00:05:25+05:30  2023-03-01T00:09:49+05:30    0-0:0.1.2*255
#
#       Unit  Transformer factor Status word Reading reason     Data source
# 0       kW                   1   No errors       Periodic  DLMS Connector
# 1       kW                   1   No errors       Periodic  DLMS Connector
# 2       kW                   1   No errors       Periodic  DLMS Connector
# 3       kW                   1   No errors       Periodic  DLMS Connector
# 4       kW                   1   No errors       Periodic  DLMS Connector
# ...    ...                 ...         ...            ...             ...
# 60227    V                   1   No errors       Periodic  DLMS Connector
# 60228    V                   1   No errors       Periodic  DLMS Connector
# 60229    V                   1   No errors       Periodic  DLMS Connector
# 60230    s                   1   No errors       Periodic  DLMS Connector
# 60231    s                   1   No errors       Periodic  DLMS Connector
#
# [60232 rows x 11 columns]

# %%
filter1 = cha_station2[cha_station2['Unit'] == 'kWh']

# %%
filter2 = filter1[filter1['Profile'] == 'InstantaneousProfile']

# %%
filter2
# Out:
#       Reading values               Profile               Reading time  \
# 6029       1,571.640  InstantaneousProfile  2023-02-28T00:05:18+05:30
# 6030       1,571.640  InstantaneousProfile  2023-02-28T00:20:28+05:30
# 6031       1,571.640  InstantaneousProfile  2023-02-28T00:35:16+05:30
# 6032       1,571.640  InstantaneousProfile  2023-02-28T00:50:30+05:30
# 6033       1,571.640  InstantaneousProfile  2023-02-28T01:05:18+05:30
# ...              ...                   ...                        ...
# 12061          0.000  InstantaneousProfile  2023-03-31T14:05:48+05:30
# 12062          0.000  InstantaneousProfile  2023-03-31T14:20:49+05:30
# 12063          0.000  InstantaneousProfile  2023-03-31T14:35:51+05:30
# 12064          0.000  InstantaneousProfile  2023-03-31T14:50:52+05:30
# 12065          0.000  InstantaneousProfile  2023-03-31T15:05:43+05:30
#
#                      Insert time               Capture time      OBIS code  \
# 6029   2023-02-28T00:00:54+05:30  2023-02-28T00:05:18+05:30  1-0:1.8.0*255
# 6030   2023-02-28T00:16:04+05:30  2023-02-28T00:20:28+05:30  1-0:1.8.0*255
# 6031   2023-02-28T00:30:52+05:30  2023-02-28T00:35:16+05:30  1-0:1.8.0*255
# 6032   2023-02-28T00:46:06+05:30  2023-02-28T00:50:30+05:30  1-0:1.8.0*255
# 6033   2023-02-28T01:00:54+05:30  2023-02-28T01:05:18+05:30  1-0:1.8.0*255
# ...                          ...                        ...            ...
# 12061  2023-03-31T14:00:56+05:30  2023-03-31T14:05:48+05:30  1-0:2.8.0*255
# 12062  2023-03-31T14:15:57+05:30  2023-03-31T14:20:49+05:30  1-0:2.8.0*255
# 12063  2023-03-31T14:30:59+05:30  2023-03-31T14:35:51+05:30  1-0:2.8.0*255
# 12064  2023-03-31T14:46:00+05:30  2023-03-31T14:50:52+05:30  1-0:2.8.0*255
# 12065  2023-03-31T15:00:51+05:30  2023-03-31T15:05:43+05:30  1-0:2.8.0*255
#
#       Unit  Transformer factor Status word Reading reason     Data source
# 6029   kWh                   1   No errors       Periodic  DLMS Connector
# 6030   kWh                   1   No errors       Periodic  DLMS Connector
# 6031   kWh                   1   No errors       Periodic  DLMS Connector
# 6032   kWh                   1   No errors       Periodic  DLMS Connector
# 6033   kWh                   1   No errors       Periodic  DLMS Connector
# ...    ...                 ...         ...            ...             ...
# 12061  kWh                   1   No errors       Periodic  DLMS Connector
# 12062  kWh                   1   No errors       Periodic  DLMS Connector
# 12063  kWh                   1   No errors       Periodic  DLMS Connector
# 12064  kWh                   1   No errors       Periodic  DLMS Connector
# 12065  kWh                   1   No errors       Periodic  DLMS Connector
#
# [5996 rows x 11 columns]

# %%
filter2['Reading time'] = pd.to_datetime(filter2['Reading time'])
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\607307215.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter2['Reading time'] = pd.to_datetime(filter2['Reading time'])

# %%
filter2['Reading values'] = filter2['Reading values'].str.replace(',', '')
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\3993206803.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter2['Reading values'] = filter2['Reading values'].str.replace(',', '')

# %%
filter2
# Out:
#       Reading values               Profile              Reading time  \
# 6029        1571.640  InstantaneousProfile 2023-02-28 00:05:18+05:30
# 6030        1571.640  InstantaneousProfile 2023-02-28 00:20:28+05:30
# 6031        1571.640  InstantaneousProfile 2023-02-28 00:35:16+05:30
# 6032        1571.640  InstantaneousProfile 2023-02-28 00:50:30+05:30
# 6033        1571.640  InstantaneousProfile 2023-02-28 01:05:18+05:30
# ...              ...                   ...                       ...
# 12061          0.000  InstantaneousProfile 2023-03-31 14:05:48+05:30
# 12062          0.000  InstantaneousProfile 2023-03-31 14:20:49+05:30
# 12063          0.000  InstantaneousProfile 2023-03-31 14:35:51+05:30
# 12064          0.000  InstantaneousProfile 2023-03-31 14:50:52+05:30
# 12065          0.000  InstantaneousProfile 2023-03-31 15:05:43+05:30
#
#                      Insert time               Capture time      OBIS code  \
# 6029   2023-02-28T00:00:54+05:30  2023-02-28T00:05:18+05:30  1-0:1.8.0*255
# 6030   2023-02-28T00:16:04+05:30  2023-02-28T00:20:28+05:30  1-0:1.8.0*255
# 6031   2023-02-28T00:30:52+05:30  2023-02-28T00:35:16+05:30  1-0:1.8.0*255
# 6032   2023-02-28T00:46:06+05:30  2023-02-28T00:50:30+05:30  1-0:1.8.0*255
# 6033   2023-02-28T01:00:54+05:30  2023-02-28T01:05:18+05:30  1-0:1.8.0*255
# ...                          ...                        ...            ...
# 12061  2023-03-31T14:00:56+05:30  2023-03-31T14:05:48+05:30  1-0:2.8.0*255
# 12062  2023-03-31T14:15:57+05:30  2023-03-31T14:20:49+05:30  1-0:2.8.0*255
# 12063  2023-03-31T14:30:59+05:30  2023-03-31T14:35:51+05:30  1-0:2.8.0*255
# 12064  2023-03-31T14:46:00+05:30  2023-03-31T14:50:52+05:30  1-0:2.8.0*255
# 12065  2023-03-31T15:00:51+05:30  2023-03-31T15:05:43+05:30  1-0:2.8.0*255
#
#       Unit  Transformer factor Status word Reading reason     Data source
# 6029   kWh                   1   No errors       Periodic  DLMS Connector
# 6030   kWh                   1   No errors       Periodic  DLMS Connector
# 6031   kWh                   1   No errors       Periodic  DLMS Connector
# 6032   kWh                   1   No errors       Periodic  DLMS Connector
# 6033   kWh                   1   No errors       Periodic  DLMS Connector
# ...    ...                 ...         ...            ...             ...
# 12061  kWh                   1   No errors       Periodic  DLMS Connector
# 12062  kWh                   1   No errors       Periodic  DLMS Connector
# 12063  kWh                   1   No errors       Periodic  DLMS Connector
# 12064  kWh                   1   No errors       Periodic  DLMS Connector
# 12065  kWh                   1   No errors       Periodic  DLMS Connector
#
# [5996 rows x 11 columns]

# %%
filter2['Reading values'] = filter2['Reading values'].astype(float)
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\1969268204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter2['Reading values'] = filter2['Reading values'].astype(float)

# %%
filter3 = filter2.drop(columns= ['Insert time', 'Capture time','Profile','OBIS code','Transformer factor','Status word','Reading reason','Data source'])

# %%
filtered_march = filter3[filter3['Reading time'].dt.month == 3]

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit
# 6125          1582.69 2023-03-01 00:05:15+05:30  kWh
# 6126          1583.10 2023-03-01 00:20:28+05:30  kWh
# 6127          1583.49 2023-03-01 00:35:17+05:30  kWh
# 6128          1583.88 2023-03-01 00:50:20+05:30  kWh
# 6129          1584.17 2023-03-01 01:05:19+05:30  kWh
# ...               ...                       ...  ...
# 12061            0.00 2023-03-31 14:05:48+05:30  kWh
# 12062            0.00 2023-03-31 14:20:49+05:30  kWh
# 12063            0.00 2023-03-31 14:35:51+05:30  kWh
# 12064            0.00 2023-03-31 14:50:52+05:30  kWh
# 12065            0.00 2023-03-31 15:05:43+05:30  kWh
#
# [5804 rows x 3 columns]

# %%
filtered_march['Difference'] = filtered_march['Reading values'].diff()
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\208512279.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Difference'] = filtered_march['Reading values'].diff()

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit  Difference
# 6125          1582.69 2023-03-01 00:05:15+05:30  kWh         NaN
# 6126          1583.10 2023-03-01 00:20:28+05:30  kWh        0.41
# 6127          1583.49 2023-03-01 00:35:17+05:30  kWh        0.39
# 6128          1583.88 2023-03-01 00:50:20+05:30  kWh        0.39
# 6129          1584.17 2023-03-01 01:05:19+05:30  kWh        0.29
# ...               ...                       ...  ...         ...
# 12061            0.00 2023-03-31 14:05:48+05:30  kWh        0.00
# 12062            0.00 2023-03-31 14:20:49+05:30  kWh        0.00
# 12063            0.00 2023-03-31 14:35:51+05:30  kWh        0.00
# 12064            0.00 2023-03-31 14:50:52+05:30  kWh        0.00
# 12065            0.00 2023-03-31 15:05:43+05:30  kWh        0.00
#
# [5804 rows x 4 columns]

# %%
filtered_march['Difference'] = filtered_march['Difference'].fillna(0)
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\2009126434.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Difference'] = filtered_march['Difference'].fillna(0)

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit  Difference
# 6125          1582.69 2023-03-01 00:05:15+05:30  kWh        0.00
# 6126          1583.10 2023-03-01 00:20:28+05:30  kWh        0.41
# 6127          1583.49 2023-03-01 00:35:17+05:30  kWh        0.39
# 6128          1583.88 2023-03-01 00:50:20+05:30  kWh        0.39
# 6129          1584.17 2023-03-01 01:05:19+05:30  kWh        0.29
# ...               ...                       ...  ...         ...
# 12061            0.00 2023-03-31 14:05:48+05:30  kWh        0.00
# 12062            0.00 2023-03-31 14:20:49+05:30  kWh        0.00
# 12063            0.00 2023-03-31 14:35:51+05:30  kWh        0.00
# 12064            0.00 2023-03-31 14:50:52+05:30  kWh        0.00
# 12065            0.00 2023-03-31 15:05:43+05:30  kWh        0.00
#
# [5804 rows x 4 columns]

# %%
has_negative_values = filtered_march['Difference'].any()
print(has_negative_values)
# Out:
# True

# %%
filtered_march['Difference'] = filtered_march['Difference'].fillna(0)
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\2009126434.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Difference'] = filtered_march['Difference'].fillna(0)

# %%
import numpy as np
filtered_march['Difference'] = filtered_march['Difference'].replace(np.nan, 0)
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\2353996151.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Difference'] = filtered_march['Difference'].replace(np.nan, 0)

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit  Difference
# 6125          1582.69 2023-03-01 00:05:15+05:30  kWh        0.00
# 6126          1583.10 2023-03-01 00:20:28+05:30  kWh        0.41
# 6127          1583.49 2023-03-01 00:35:17+05:30  kWh        0.39
# 6128          1583.88 2023-03-01 00:50:20+05:30  kWh        0.39
# 6129          1584.17 2023-03-01 01:05:19+05:30  kWh        0.29
# ...               ...                       ...  ...         ...
# 12061            0.00 2023-03-31 14:05:48+05:30  kWh        0.00
# 12062            0.00 2023-03-31 14:20:49+05:30  kWh        0.00
# 12063            0.00 2023-03-31 14:35:51+05:30  kWh        0.00
# 12064            0.00 2023-03-31 14:50:52+05:30  kWh        0.00
# 12065            0.00 2023-03-31 15:05:43+05:30  kWh        0.00
#
# [5804 rows x 4 columns]

# %%
has_negative_values = filtered_march['Difference'].any()
print(has_negative_values)
# Out:
# True

# %%
negative_values = filtered_march['Difference'].where(filtered_march['Difference'] < 0)

print(negative_values)
# Out:
# 6125    NaN
# 6126    NaN
# 6127    NaN
# 6128    NaN
# 6129    NaN
#          ..
# 12061   NaN
# 12062   NaN
# 12063   NaN
# 12064   NaN
# 12065   NaN
# Name: Difference, Length: 5804, dtype: float64

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit  Difference
# 6125          1582.69 2023-03-01 00:05:15+05:30  kWh        0.00
# 6126          1583.10 2023-03-01 00:20:28+05:30  kWh        0.41
# 6127          1583.49 2023-03-01 00:35:17+05:30  kWh        0.39
# 6128          1583.88 2023-03-01 00:50:20+05:30  kWh        0.39
# 6129          1584.17 2023-03-01 01:05:19+05:30  kWh        0.29
# ...               ...                       ...  ...         ...
# 12061            0.00 2023-03-31 14:05:48+05:30  kWh        0.00
# 12062            0.00 2023-03-31 14:20:49+05:30  kWh        0.00
# 12063            0.00 2023-03-31 14:35:51+05:30  kWh        0.00
# 12064            0.00 2023-03-31 14:50:52+05:30  kWh        0.00
# 12065            0.00 2023-03-31 15:05:43+05:30  kWh        0.00
#
# [5804 rows x 4 columns]

# %%
def replace_negative_values(value):
    if value < 0:
        return 0
    else:
        return value

filtered_march['Difference'] = filtered_march['Difference'].apply(replace_negative_values)
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\3058025850.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Difference'] = filtered_march['Difference'].apply(replace_negative_values)

# %%
filtered_march['Cumulative_Increase'] = filtered_march['Difference'].cumsum()
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\2808991187.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Cumulative_Increase'] = filtered_march['Difference'].cumsum()

# %%
filtered_march["Time_Stamp"] = filtered_march["Reading time"].dt.strftime("%H-%M-%S")
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\1433204948.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march["Time_Stamp"] = filtered_march["Reading time"].dt.strftime("%H-%M-%S")

# %%
total_energy_consumption = filtered_march["Difference"].sum()

# %%
total_energy_consumption
# Out:
# 399.22

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit  Difference  \
# 6125          1582.69 2023-03-01 00:05:15+05:30  kWh        0.00
# 6126          1583.10 2023-03-01 00:20:28+05:30  kWh        0.41
# 6127          1583.49 2023-03-01 00:35:17+05:30  kWh        0.39
# 6128          1583.88 2023-03-01 00:50:20+05:30  kWh        0.39
# 6129          1584.17 2023-03-01 01:05:19+05:30  kWh        0.29
# ...               ...                       ...  ...         ...
# 12061            0.00 2023-03-31 14:05:48+05:30  kWh        0.00
# 12062            0.00 2023-03-31 14:20:49+05:30  kWh        0.00
# 12063            0.00 2023-03-31 14:35:51+05:30  kWh        0.00
# 12064            0.00 2023-03-31 14:50:52+05:30  kWh        0.00
# 12065            0.00 2023-03-31 15:05:43+05:30  kWh        0.00
#
#        Cumulative_Increase Time_Stamp
# 6125                  0.00   00-05-15
# 6126                  0.41   00-20-28
# 6127                  0.80   00-35-17
# 6128                  1.19   00-50-20
# 6129                  1.48   01-05-19
# ...                    ...        ...
# 12061               399.22   14-05-48
# 12062               399.22   14-20-49
# 12063               399.22   14-35-51
# 12064               399.22   14-50-52
# 12065               399.22   15-05-43
#
# [5804 rows x 6 columns]

# %%
# Convert 'reading_time' column to datetime format
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Define tariff rates
tariff_rates = {
    'off-peak': 6,
    'peak': 8,
    'mid-peak': 7,
    'high-peak': 8
}

# Function to determine the tariff based on the time of day
def get_tariff(reading_time):
    hour = reading_time.hour
    if 23 <= hour or hour < 6:
        return 'off-peak'
    elif 7 <= hour < 11:
        return 'peak'
    elif 11 <= hour < 19:
        return 'mid-peak'
    else:
        return 'high-peak'

# Apply the get_tariff function to each row to get the tariff for each reading
filtered_march['tariff'] = filtered_march['Reading time'].apply(get_tariff)

# Calculate the price for each 15-minute interval
filtered_march['price'] = filtered_march.apply(lambda row: row['Difference'] * tariff_rates[row['tariff']], axis=1)
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\859811055.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\859811055.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['tariff'] = filtered_march['Reading time'].apply(get_tariff)
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\859811055.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['price'] = filtered_march.apply(lambda row: row['Difference'] * tariff_rates[row['tariff']], axis=1)

# %%
filtered_march.head(1000)
# Out:
#       Reading values              Reading time Unit  Difference  \
# 6125         1582.69 2023-03-01 00:05:15+05:30  kWh        0.00
# 6126         1583.10 2023-03-01 00:20:28+05:30  kWh        0.41
# 6127         1583.49 2023-03-01 00:35:17+05:30  kWh        0.39
# 6128         1583.88 2023-03-01 00:50:20+05:30  kWh        0.39
# 6129         1584.17 2023-03-01 01:05:19+05:30  kWh        0.29
# ...              ...                       ...  ...         ...
# 7120         1727.10 2023-03-11 11:05:32+05:30  kWh        0.17
# 7121         1727.53 2023-03-11 11:20:39+05:30  kWh        0.43
# 7122         1727.90 2023-03-11 11:35:28+05:30  kWh        0.37
# 7123         1728.29 2023-03-11 11:50:40+05:30  kWh        0.39
# 7124         1728.50 2023-03-11 12:05:32+05:30  kWh        0.21
#
#       Cumulative_Increase Time_Stamp    tariff  price
# 6125                 0.00   00-05-15  off-peak   0.00
# 6126                 0.41   00-20-28  off-peak   2.46
# 6127                 0.80   00-35-17  off-peak   2.34
# 6128                 1.19   00-50-20  off-peak   2.34
# 6129                 1.48   01-05-19  off-peak   1.74
# ...                   ...        ...       ...    ...
# 7120               144.41   11-05-32  mid-peak   1.19
# 7121               144.84   11-20-39  mid-peak   3.01
# 7122               145.21   11-35-28  mid-peak   2.59
# 7123               145.60   11-50-40  mid-peak   2.73
# 7124               145.81   12-05-32  mid-peak   1.47
#
# [1000 rows x 8 columns]

# %%
# Calculate the total of the 'price' column
total_price = filtered_march['price'].sum()
total_energy = filtered_march['Difference'].sum()
# Print the total
print(f"Total Energy :{round(total_energy,2)} Units")
print("Total Price Rs:", round(total_price,2))
# Out:
# Total Energy :399.22 Units
# Total Price Rs: 2819.69

# %%
peak_df = filtered_march[filtered_march['tariff'] == 'peak']

# Calculate the total energy consumed during peak hours
total_energy_consumed_peak = peak_df['Difference'].sum()

# Calculate the total price during peak hours
total_price_peak = peak_df['price'].sum()

# Print the results
print("Total Energy Consumed During Peak Hours:", round(total_energy_consumed_peak,2))
print("Total Price During Peak Hours:", round(total_price_peak,2))
# Out:
# Total Energy Consumed During Peak Hours: 47.66
# Total Price During Peak Hours: 381.28

# %%
# Filter rows for off-peak hours (assuming 'off-peak' corresponds to the off-peak hours)
off_peak_df = filtered_march[filtered_march['tariff'] == 'off-peak']

# Calculate the total energy consumed during off-peak hours
total_energy_consumed_off_peak = off_peak_df['Difference'].sum()

# Calculate the total price during off-peak hours
total_price_off_peak = off_peak_df['price'].sum()

# Print the results
print("Total Energy Consumed During Off-Peak Hours:", round(total_energy_consumed_off_peak,2))
print("Total Price During Off-Peak Hours:", round(total_price_off_peak,2))
# Out:
# Total Energy Consumed During Off-Peak Hours: 103.52
# Total Price During Off-Peak Hours: 621.12

# %%
# Filter rows for mid-peak hours (assuming 'mid-peak' corresponds to the mid-peak hours)
mid_peak_df = filtered_march[filtered_march['tariff'] == 'mid-peak']

# Calculate the total energy consumed during mid-peak hours
total_energy_consumed_mid_peak = mid_peak_df['Difference'].sum()

# Calculate the total price during mid-peak hours
total_price_mid_peak = mid_peak_df['price'].sum()

# Print the results
print("Total Energy Consumed During Mid-Peak Hours:", round(total_energy_consumed_mid_peak,2))
print("Total Price During Mid-Peak Hours:", round(total_price_mid_peak,2))
# Out:
# Total Energy Consumed During Mid-Peak Hours: 167.03
# Total Price During Mid-Peak Hours: 1169.21

# %%
# Filter rows for high-peak hours (assuming 'high-peak' corresponds to the high-peak hours)
high_peak_df = filtered_march[filtered_march['tariff'] == 'high-peak']

# Calculate the total energy consumed during high-peak hours
total_energy_consumed_high_peak = high_peak_df['Difference'].sum()

# Calculate the total price during high-peak hours
total_price_high_peak = high_peak_df['price'].sum()

# Print the results
print("Total Energy Consumed During High-Peak Hours:", round(total_energy_consumed_high_peak,2))
print("Total Price During High-Peak Hours:", round(total_price_high_peak,2))
# Out:
# Total Energy Consumed During High-Peak Hours: 81.01
# Total Price During High-Peak Hours: 648.08

# %%
Total_Energy_Consumption = total_energy_consumed_peak + total_energy_consumed_off_peak + total_energy_consumed_mid_peak +total_energy_consumed_high_peak

# %%
Total_Energy_Consumption
# Out:
# 399.22

# %%
Total_Price = total_price_peak + total_price_off_peak + total_price_mid_peak + total_price_high_peak

# %%
Total_Price
# Out:
# 2819.689999999999

# %%
plt.figure(figsize=(12, 6))
plt.plot(filtered_march['Reading time'], filtered_march['Difference'], marker='o', linestyle='-')
plt.xlabel('Date')
plt.ylabel('Energy Usage')
plt.title('Energy Usage Trend for the Month')
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

plt.show()

# %%
# Price plot
plt.figure(figsize=(12, 6))
plt.plot(filtered_march['Reading time'], filtered_march['price'], marker='o', linestyle='-')
plt.xlabel('Reading time')
plt.ylabel('Energy Price based on TOD Tariff')
plt.title('Energy Price Vs Reading Time (based on TOD Tariff)')
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

plt.show()

# %%
total_energy = [total_energy_consumed_peak, total_energy_consumed_off_peak, total_energy_consumed_mid_peak, total_energy_consumed_high_peak]
tariff_categories = ['Peak', 'off-Peak', 'mid-Peak', 'High Peak']
# Create a bar plot
plt.figure(figsize=(5, 5))
plt.bar(tariff_categories, total_energy, color=['skyblue', 'lightgreen', 'lightcoral', 'gold'])
plt.xlabel('Time-of-Day ')
plt.ylabel('Total Energy Usage')
plt.title('Total Energy Usage by Time-of-Day ')
plt.show()

# %%
total_prices = [total_price_peak, total_price_off_peak, total_price_mid_peak, total_price_high_peak]
tariff_categories = ['Peak', 'off-Peak', 'mid-Peak', 'High Peak']
# Create a bar plot
plt.figure(figsize=(5, 5))
plt.bar(tariff_categories, total_prices, color=['yellow', 'blue', 'green', 'red'])
plt.xlabel('Time-of-Day ')
plt.ylabel('Total Price')
plt.title('Total Price based on Time-of-Day Tariff ')
plt.show()

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit  Difference  \
# 6125          1582.69 2023-03-01 00:05:15+05:30  kWh        0.00
# 6126          1583.10 2023-03-01 00:20:28+05:30  kWh        0.41
# 6127          1583.49 2023-03-01 00:35:17+05:30  kWh        0.39
# 6128          1583.88 2023-03-01 00:50:20+05:30  kWh        0.39
# 6129          1584.17 2023-03-01 01:05:19+05:30  kWh        0.29
# ...               ...                       ...  ...         ...
# 12061            0.00 2023-03-31 14:05:48+05:30  kWh        0.00
# 12062            0.00 2023-03-31 14:20:49+05:30  kWh        0.00
# 12063            0.00 2023-03-31 14:35:51+05:30  kWh        0.00
# 12064            0.00 2023-03-31 14:50:52+05:30  kWh        0.00
# 12065            0.00 2023-03-31 15:05:43+05:30  kWh        0.00
#
#        Cumulative_Increase Time_Stamp    tariff  price
# 6125                  0.00   00-05-15  off-peak   0.00
# 6126                  0.41   00-20-28  off-peak   2.46
# 6127                  0.80   00-35-17  off-peak   2.34
# 6128                  1.19   00-50-20  off-peak   2.34
# 6129                  1.48   01-05-19  off-peak   1.74
# ...                    ...        ...       ...    ...
# 12061               399.22   14-05-48  mid-peak   0.00
# 12062               399.22   14-20-49  mid-peak   0.00
# 12063               399.22   14-35-51  mid-peak   0.00
# 12064               399.22   14-50-52  mid-peak   0.00
# 12065               399.22   15-05-43  mid-peak   0.00
#
# [5804 rows x 8 columns]

# %%
# Filter data for the month of March
march_data = filtered_march[(filtered_march['Reading time'] >= '2023-03-01') & (filtered_march['Reading time'] < '2023-04-01')]

# Group by date and sum the energy usage for each day
daily_energy_usage = march_data.groupby(march_data['Reading time'].dt.date)['Difference'].sum()

# The result will be a Series with daily energy usage for each day in March
print(daily_energy_usage)
# Out:
# Reading time
# 2023-03-01    12.15
# 2023-03-02    17.33
# 2023-03-03     6.47
# 2023-03-04    19.86
# 2023-03-05     9.62
# 2023-03-06    12.52
# 2023-03-07    12.49
# 2023-03-08    21.54
# 2023-03-09    10.06
# 2023-03-10    22.13
# 2023-03-11    10.19
# 2023-03-12    22.26
# 2023-03-13    13.43
# 2023-03-14     5.62
# 2023-03-15    11.92
# 2023-03-16    13.25
# 2023-03-17    11.38
# 2023-03-18     6.96
# 2023-03-19    15.56
# 2023-03-20    12.07
# 2023-03-21     6.65
# 2023-03-22    11.02
# 2023-03-23     6.95
# 2023-03-24    13.85
# 2023-03-25     7.88
# 2023-03-26    16.76
# 2023-03-27    12.27
# 2023-03-28    21.57
# 2023-03-29    10.69
# 2023-03-30     8.90
# 2023-03-31    15.87
# Name: Difference, dtype: float64

# %%
# Filter data for the month of March
march_data = filtered_march[(filtered_march['Reading time'] >= '2023-03-01') & (filtered_march['Reading time'] < '2023-04-01')]

# Group by date and sum the price based on tod for each day
daily_energy_pricing = march_data.groupby(march_data['Reading time'].dt.date)['price'].sum()

# The result will be a Series with daily energy usage for each day in March
print(daily_energy_pricing)
# Out:
# Reading time
# 2023-03-01     81.53
# 2023-03-02    122.12
# 2023-03-03     46.68
# 2023-03-04    147.54
# 2023-03-05     62.44
# 2023-03-06     85.12
# 2023-03-07     89.59
# 2023-03-08    147.64
# 2023-03-09     75.19
# 2023-03-10    153.02
# 2023-03-11     70.24
# 2023-03-12    153.33
# 2023-03-13     96.00
# 2023-03-14     39.41
# 2023-03-15     82.29
# 2023-03-16     90.65
# 2023-03-17     76.07
# 2023-03-18     49.77
# 2023-03-19    118.79
# 2023-03-20     92.06
# 2023-03-21     43.32
# 2023-03-22     81.90
# 2023-03-23     48.92
# 2023-03-24     93.85
# 2023-03-25     58.75
# 2023-03-26    118.15
# 2023-03-27     92.12
# 2023-03-28    153.52
# 2023-03-29     74.22
# 2023-03-30     63.80
# 2023-03-31    111.66
# Name: price, dtype: float64

# %%
# Create a bar plot
plt.figure(figsize=(12, 6))
plt.bar(daily_energy_usage.index, daily_energy_usage.values, color='b')
plt.title('Daily Energy Usage in March 2023')
plt.xlabel('Date')
plt.ylabel('Energy Usage')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Create a bar plot
plt.figure(figsize=(12, 6))
plt.bar(daily_energy_pricing.index, daily_energy_pricing.values, color='g')
plt.title('Daily Pricing in March 2023')
plt.xlabel('Date')
plt.ylabel('Energy Usage')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
mean_energy_usage = daily_energy_usage.mean()

# Calculate the median of daily energy usage
median_energy_usage = daily_energy_usage.median()

# Calculate the standard deviation of daily energy usage
std_deviation_energy_usage = daily_energy_usage.std()

# Print the results
print(f"Mean Energy Usage: {mean_energy_usage:.2f}")
print(f"Median Energy Usage: {median_energy_usage:.2f}")
print(f"Standard Deviation of Energy Usage: {std_deviation_energy_usage:.2f}")
# Out:
# Mean Energy Usage: 12.88
# Median Energy Usage: 12.15
# Standard Deviation of Energy Usage: 4.86

# %%
mean_energy_pricing = daily_energy_pricing.mean()

# Calculate the median of daily energy usage
median_energy_pricing = daily_energy_pricing.median()

# Calculate the standard deviation of daily energy usage
std_deviation_energy_pricing = daily_energy_pricing.std()

# Print the results
print(f"Mean Energy Pricing: {mean_energy_pricing:.2f}")
print(f"Median Energy Pricing: {median_energy_pricing:.2f}")
print(f"Standard Deviation of Energy pricing: {std_deviation_energy_pricing:.2f}")
# Out:
# Mean Energy Pricing: 90.96
# Median Energy Pricing: 85.12
# Standard Deviation of Energy pricing: 34.36

# %%
import seaborn as sns

# Create a density plot (KDE)
plt.figure(figsize=(3, 3))
sns.histplot(daily_energy_usage, kde=True, color='skyblue')
plt.title('Density Plot of Daily Energy Usage')
plt.xlabel('Energy Usage')
plt.ylabel('Density')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\et22m\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import seaborn as sns

# Create a density plot (KDE)
plt.figure(figsize=(3, 3))
sns.histplot(daily_energy_pricing, kde=True, color='green')
plt.title('Density Plot of Daily Energy Usage Pricing')
plt.xlabel('Energy Usage Pricing based on TOD')
plt.ylabel('Density')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Calculate the day of the week for each data point (0 = Monday, 6 = Sunday)
filtered_march['Day_of_Week'] = filtered_march['Reading time'].dt.dayofweek

# Group data by the day of the week and calculate the mean energy usage
sum_energy_by_day = filtered_march.groupby('Day_of_Week')['Difference'].sum()

# Define the day names for plotting
day_names = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
print(sum_energy_by_day)
# Out:
# Day_of_Week
# 0    50.29
# 1    46.33
# 2    67.32
# 3    56.49
# 4    69.70
# 5    44.89
# 6    64.20
# Name: Difference, dtype: float64
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\2347480156.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Day_of_Week'] = filtered_march['Reading time'].dt.dayofweek

# %%
# Create a bar plot to visualize mean energy usage by day
plt.figure(figsize=(7, 5))
plt.bar(day_names, sum_energy_by_day, color='green')
plt.title('Sum of Energy Usage by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Sum Energy Usage')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Calculate the day of the week for each data point (0 = Monday, 6 = Sunday)
filtered_march['Day_of_Week'] = filtered_march['Reading time'].dt.dayofweek

# Group data by the day of the week and calculate the mean energy usage
sum_energy_price_by_day = filtered_march.groupby('Day_of_Week')['price'].sum()

# Define the day names for plotting
day_names = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
print(sum_energy_price_by_day)
# Out:
# Day_of_Week
# 0    365.30
# 1    325.84
# 2    467.58
# 3    400.68
# 4    481.28
# 5    326.30
# 6    452.71
# Name: price, dtype: float64
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\1886559552.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Day_of_Week'] = filtered_march['Reading time'].dt.dayofweek

# %%
# Create a bar plot to visualize mean energy usage by day
plt.figure(figsize=(7, 5))
plt.bar(day_names, sum_energy_by_day, color='yellow')
plt.title('Sum of Energy Price by Day of the Week(TOD)')
plt.xlabel('Day of the Week')
plt.ylabel('Sum Energy Price')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
filtered_march['Weekday_Or_Weekend'] = filtered_march['Day_of_Week'].apply(lambda x: 'Weekend' if x >= 5 else 'Weekday')

# Calculate the average energy usage for weekdays and weekends
average_energy_by_category = filtered_march.groupby('Weekday_Or_Weekend')['Difference'].mean()

# Display the result
print(average_energy_by_category)
# Out:
# Weekday_Or_Weekend
# Weekday    0.067883
# Weekend    0.071301
# Name: Difference, dtype: float64
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\1745808412.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Weekday_Or_Weekend'] = filtered_march['Day_of_Week'].apply(lambda x: 'Weekend' if x >= 5 else 'Weekday')

# %%
filtered_march['Weekday_Or_Weekend'] = filtered_march['Day_of_Week'].apply(lambda x: 'Weekend' if x >= 5 else 'Weekday')

# Calculate the average energy usage for weekdays and weekends
average_energy_by_category_sum = filtered_march.groupby('Weekday_Or_Weekend')['Difference'].sum()

# Display the result
print(average_energy_by_category_sum)
# Out:
# Weekday_Or_Weekend
# Weekday    290.13
# Weekend    109.09
# Name: Difference, dtype: float64
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\1631259048.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Weekday_Or_Weekend'] = filtered_march['Day_of_Week'].apply(lambda x: 'Weekend' if x >= 5 else 'Weekday')

# %%
filtered_march['Weekday_Or_Weekend'] = filtered_march['Day_of_Week'].apply(lambda x: 'Weekend' if x >= 5 else 'Weekday')

# Calculate the average energy usage(price) for weekdays and weekends
average_energy_by_category_mean = filtered_march.groupby('Weekday_Or_Weekend')['price'].mean()

# Display the result
print(average_energy_by_category_mean)
# Out:
# Weekday_Or_Weekend
# Weekday    0.477464
# Weekend    0.509157
# Name: price, dtype: float64
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\2104126346.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Weekday_Or_Weekend'] = filtered_march['Day_of_Week'].apply(lambda x: 'Weekend' if x >= 5 else 'Weekday')

# %%
filtered_march['Weekday_Or_Weekend'] = filtered_march['Day_of_Week'].apply(lambda x: 'Weekend' if x >= 5 else 'Weekday')

# Calculate the sum energy usage (price)for weekdays and weekends
average_energy_by_category_sum_price = filtered_march.groupby('Weekday_Or_Weekend')['price'].sum()

# Display the result
print(average_energy_by_category_sum_price)
# Out:
# Weekday_Or_Weekend
# Weekday    2040.68
# Weekend     779.01
# Name: price, dtype: float64
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\2468143508.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Weekday_Or_Weekend'] = filtered_march['Day_of_Week'].apply(lambda x: 'Weekend' if x >= 5 else 'Weekday')

# %%
from scipy import stats

# %%
weekday_data = filtered_march[filtered_march['Weekday_Or_Weekend'] == 'Weekday']['Difference']
weekend_data = filtered_march[filtered_march['Weekday_Or_Weekend'] == 'Weekend']['Difference']

# Perform a t-test to compare the means of the two groups
t_stat, p_value = stats.ttest_ind(weekday_data, weekend_data)

# Set the significance level (alpha)
alpha = 0.05

# Check if the p-value is less than alpha (indicating statistical significance)
if p_value < alpha:
    print("There is a statistically significant difference in energy consumption between weekdays and weekends.")
else:
    print("There is no statistically significant difference in energy consumption between weekdays and weekends.")
# Out:
# There is no statistically significant difference in energy consumption between weekdays and weekends.

# %%
daily_energy_usage = filtered_march.groupby(filtered_march['Reading time'].dt.date)['Difference'].sum()

# Compute basic statistics
mean_energy = daily_energy_usage.mean()
std_deviation_energy = daily_energy_usage.std()

# %%
threshold_high = mean_energy + 1 * std_deviation_energy
threshold_low = mean_energy - 1 * std_deviation_energy
print(threshold_high)
print(threshold_high)
# Out:
# 17.735653368879515
# 17.735653368879515

# %%
# Detect days with exceptionally high energy usage
high_energy_days = daily_energy_usage[daily_energy_usage > threshold_high]
print(high_energy_days)
# Detect days with exceptionally low energy usage
low_energy_days = daily_energy_usage[daily_energy_usage < threshold_low]
print(low_energy_days)
# Out:
# Reading time
# 2023-03-04    19.86
# 2023-03-08    21.54
# 2023-03-10    22.13
# 2023-03-12    22.26
# 2023-03-28    21.57
# Name: Difference, dtype: float64
# Reading time
# 2023-03-03    6.47
# 2023-03-14    5.62
# 2023-03-18    6.96
# 2023-03-21    6.65
# 2023-03-23    6.95
# 2023-03-25    7.88
# Name: Difference, dtype: float64

# %%
plt.figure(figsize=(31, 6))
plt.plot(daily_energy_usage.index, daily_energy_usage.values, marker='o', linestyle='-', color='b', label='Daily Energy Usage')

# Scatter plot for high energy days (in red)
plt.scatter(high_energy_days.index, high_energy_days.values, color='red', marker='*', label='High Energy Days')

# Scatter plot for low energy days (in green)
plt.scatter(low_energy_days.index, low_energy_days.values, color='green', marker='*', label='Low Energy Days')

plt.title('Daily Energy Usage with Anomalous Days')
plt.xlabel('Date')
plt.ylabel('Energy Usage')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
filtered_march
# Out:
#        Reading values              Reading time Unit  Difference  \
# 6125          1582.69 2023-03-01 00:05:15+05:30  kWh        0.00
# 6126          1583.10 2023-03-01 00:20:28+05:30  kWh        0.41
# 6127          1583.49 2023-03-01 00:35:17+05:30  kWh        0.39
# 6128          1583.88 2023-03-01 00:50:20+05:30  kWh        0.39
# 6129          1584.17 2023-03-01 01:05:19+05:30  kWh        0.29
# ...               ...                       ...  ...         ...
# 12061            0.00 2023-03-31 14:05:48+05:30  kWh        0.00
# 12062            0.00 2023-03-31 14:20:49+05:30  kWh        0.00
# 12063            0.00 2023-03-31 14:35:51+05:30  kWh        0.00
# 12064            0.00 2023-03-31 14:50:52+05:30  kWh        0.00
# 12065            0.00 2023-03-31 15:05:43+05:30  kWh        0.00
#
#        Cumulative_Increase Time_Stamp    tariff  price  Day_of_Week  \
# 6125                  0.00   00-05-15  off-peak   0.00            2
# 6126                  0.41   00-20-28  off-peak   2.46            2
# 6127                  0.80   00-35-17  off-peak   2.34            2
# 6128                  1.19   00-50-20  off-peak   2.34            2
# 6129                  1.48   01-05-19  off-peak   1.74            2
# ...                    ...        ...       ...    ...          ...
# 12061               399.22   14-05-48  mid-peak   0.00            4
# 12062               399.22   14-20-49  mid-peak   0.00            4
# 12063               399.22   14-35-51  mid-peak   0.00            4
# 12064               399.22   14-50-52  mid-peak   0.00            4
# 12065               399.22   15-05-43  mid-peak   0.00            4
#
#       Weekday_Or_Weekend
# 6125             Weekday
# 6126             Weekday
# 6127             Weekday
# 6128             Weekday
# 6129             Weekday
# ...                  ...
# 12061            Weekday
# 12062            Weekday
# 12063            Weekday
# 12064            Weekday
# 12065            Weekday
#
# [5804 rows x 10 columns]

# %%
# Convert the "Reading Time" column to a datetime object
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Extract the date and hour from the timestamp
filtered_march['Date'] = filtered_march['Reading time'].dt.date
filtered_march['Hour'] = filtered_march['Reading time'].dt.hour

# Group the data by Date and Hour, and sum the energy usage for each hour
hourly_energy_usageev3 = filtered_march.groupby(['Date', 'Hour'])['Difference'].sum()

hourly_energy_usageev3 = hourly_energy_usageev3.reset_index()
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\244686230.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\244686230.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Date'] = filtered_march['Reading time'].dt.date
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\244686230.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Hour'] = filtered_march['Reading time'].dt.hour

# %%
hourly_energy_usageev3
hourly_energy_usageev3.to_csv("hourly_energy_usageev3.csv", index=False)

# %%
filtered_march['Hour'] = filtered_march['Reading time'].dt.hour

# Group the data by Hour and sum the energy usage for each hour over the entire 31 days
hourly_energy_usage1ev3 = filtered_march.groupby('Hour')['Difference'].sum()

# Reset the index to make it a DataFrame
hourly_energy_usage1ev3 = hourly_energy_usage1ev3.reset_index()

# Save the result to a new CSV file
hourly_energy_usage1ev3.to_csv("hourly_energy_usage_over_31_daysev3.csv", index=False)
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\1386797808.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Hour'] = filtered_march['Reading time'].dt.hour

# %%
hourly_energy_usage1ev3
# Out:
#     Hour  Difference
# 0      0       16.86
# 1      1       18.76
# 2      2       17.20
# 3      3       16.23
# 4      4       14.31
# 5      5       11.08
# 6      6       11.23
# 7      7       13.97
# 8      8       13.18
# 9      9       11.77
# 10    10        8.74
# 11    11       22.98
# 12    12       25.24
# 13    13       20.08
# 14    14       16.19
# 15    15       19.78
# 16    16       23.80
# 17    17       20.00
# 18    18       18.96
# 19    19       17.10
# 20    20       17.38
# 21    21       21.84
# 22    22       13.46
# 23    23        9.08

# %%
total_energy_usage = filtered_march['Difference'].sum()
total_energy_usage
# Out:
# 399.22

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame called 'filtered_march' with columns 'Reading time' and 'Difference'
# Convert 'Reading time' to a datetime format
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Group the data by day and hour
filtered_march['date'] = filtered_march['Reading time'].dt.date
filtered_march['hour'] = filtered_march['Reading time'].dt.hour
hourly_usage = filtered_march.groupby(['date', 'hour'])['Difference'].sum()

# Pivot the data to have days on the y-axis and hours on the x-axis
hourly_usage_pivot = hourly_usage.unstack(level='date').fillna(0)

# Create a heatmap to visualize the data with red shades and white cell borders
plt.figure(figsize=(12, 6))
sns.heatmap(hourly_usage_pivot, cmap='Reds', cbar_kws={'label': 'Energy Usage (kWh)'},
            linewidths=0.5, linecolor='white')

# Customize the plot

plt.xlabel('Date')
plt.ylabel('Hour of the Day')

# Format x-axis labels to include both day and month
date_labels = [f"{d.day} {d.strftime('%B')}" for d in hourly_usage_pivot.columns]
plt.xticks(ticks=range(len(hourly_usage_pivot.columns)), labels=date_labels, rotation=45)

# Display the plot
plt.show()
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\1653188968.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\1653188968.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['date'] = filtered_march['Reading time'].dt.date
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\1653188968.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['hour'] = filtered_march['Reading time'].dt.hour

# %%
import pandas as pd
import matplotlib.pyplot as plt

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame called 'ev_data' with columns 'reading_time' and 'energy_usage'
# Convert 'reading_time' to a datetime format
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Group the data by day and hour
filtered_march['date'] = filtered_march['Reading time'].dt.date
filtered_march['hour'] = filtered_march['Reading time'].dt.hour
hourly_usage = filtered_march.groupby(['date', 'hour'])['Difference'].sum()

# Pivot the data to have days on the y-axis and hours on the x-axis
hourly_usage_pivot = hourly_usage.unstack(level='date').fillna(0)

# Create a line plot to visualize the data
plt.figure(figsize=(10, 6))

# Plot a line for each day
for date in hourly_usage_pivot.columns:
    plt.plot(hourly_usage_pivot.index, hourly_usage_pivot[date], label=date)

plt.title('Hourly Energy Usage for Charging Station')
plt.xlabel('Hour of the Day')
plt.ylabel('Energy Usage (kWh)')
plt.legend(title='Date')

# Display the plot
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\2065835418.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\2065835418.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['date'] = filtered_march['Reading time'].dt.date
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\2065835418.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['hour'] = filtered_march['Reading time'].dt.hour

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Patch

# Assuming you have a DataFrame called 'filtered_march' with columns 'Reading time' and 'Difference'
# Convert 'Reading time' to a datetime format
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Group the data by day and hour
filtered_march['date'] = filtered_march['Reading time'].dt.date
filtered_march['hour'] = filtered_march['Reading time'].dt.hour
hourly_usage = filtered_march.groupby(['date', 'hour'])['Difference'].sum()

# Pivot the data to have days on the y-axis and hours on the x-axis
hourly_usage_pivot = hourly_usage.unstack(level='date').fillna(0)

# Create a line plot to visualize the data
plt.figure(figsize=(12, 8))
sns.set(style="whitegrid")

# Plot a line for each day with distinct colors
colors = sns.color_palette("husl", n_colors=len(hourly_usage_pivot.columns))
for i, date in enumerate(hourly_usage_pivot.columns):
    plt.plot(hourly_usage_pivot.index, hourly_usage_pivot[date], color=colors[i], linewidth=2)

# Create custom legend with colored bars
legend_labels = [date.strftime('%d %B') for date in hourly_usage_pivot.columns]
legend_handles = [Patch(color=colors[i], label=label) for i, label in enumerate(legend_labels)]

# Add the legend with colored bars in a matrix format
plt.legend(handles=legend_handles, title='Date', title_fontsize='12', fontsize='10', bbox_to_anchor=(1.05, 1), loc='upper left', ncol=2)  # Set ncol to the number of columns you desire

# Customize plot details
plt.title('Hourly Energy Usage for Charging Station', fontsize=16)
plt.xlabel('Hour of the Day', fontsize=14)
plt.ylabel('Energy Usage (kWh)', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\3045971443.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\3045971443.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['date'] = filtered_march['Reading time'].dt.date
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\3045971443.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['hour'] = filtered_march['Reading time'].dt.hour

# %%
# Assuming your DataFrame is named filtered_march

# Convert 'Reading time' to Timestamp with the same timezone
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Define the date for March 8th and March 22nd
march_8_date = pd.Timestamp('2023-03-08', tz='Asia/Kolkata')
march_22_date = pd.Timestamp('2023-03-22', tz='Asia/Kolkata')

# Mark March 8th and March 22nd as holidays
filtered_march['Holiday'] = 'Other Days'
filtered_march.loc[filtered_march['Reading time'].dt.date.isin([march_8_date.date(), march_22_date.date()]), 'Holiday'] = 'Holiday'

# Calculate total energy consumption on holidays
holiday_energy_consumption = filtered_march[
    (filtered_march['Holiday'] == 'Holiday')
]['Difference'].sum()

# Calculate total energy consumption on other days
other_days_energy_consumption = filtered_march[
    (filtered_march['Holiday'] == 'Other Days')
]['Difference'].sum()

# Display the total energy consumption
print(f'Total Energy Consumption on Holidays: {holiday_energy_consumption} units')
print(f'Total Energy Consumption on Other Days: {other_days_energy_consumption} units')
# Out:
# Total Energy Consumption on Holidays: 32.559999999999945 units
# Total Energy Consumption on Other Days: 366.6600000000001 units
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\245511943.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\245511943.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Holiday'] = 'Other Days'

# %%
# Assuming your DataFrame is named filtered_march

# Convert 'Reading time' to Timestamp with the same timezone
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Define the date for March 8th and March 22nd
march_8_date = pd.Timestamp('2023-03-08', tz='Asia/Kolkata')
march_22_date = pd.Timestamp('2023-03-22', tz='Asia/Kolkata')

# Mark March 8th and March 22nd as holidays
filtered_march['Holiday'] = 'Other Days'
filtered_march.loc[filtered_march['Reading time'].dt.date.isin([march_8_date.date(), march_22_date.date()]), 'Holiday'] = 'Holiday'

# Calculate average energy consumption on holidays and other days
average_holiday_consumption = filtered_march[filtered_march['Holiday'] == 'Holiday']['Difference'].mean()
average_other_days_consumption = filtered_march[filtered_march['Holiday'] == 'Other Days']['Difference'].mean()

# Display the average energy consumption
print(f'Average Energy Consumption on Holidays: {average_holiday_consumption} units')
print(f'Average Energy Consumption on Other Days: {average_other_days_consumption} units')

# Check if holiday consumption is higher than normal
if average_holiday_consumption > average_other_days_consumption:
    print('Holiday consumption is higher than normal.')
else:
    print('Holiday consumption is normal or lower than normal.')
# Out:
# Average Energy Consumption on Holidays: 0.0904444444444443 units
# Average Energy Consumption on Other Days: 0.06735121234386482 units
# Holiday consumption is higher than normal.
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\810887589.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\810887589.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Holiday'] = 'Other Days'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named filtered_march

# Convert 'Reading time' to Timestamp with the same timezone
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Define the date for March 8th and March 22nd
march_8_date = pd.Timestamp('2023-03-08', tz='Asia/Kolkata')
march_22_date = pd.Timestamp('2023-03-22', tz='Asia/Kolkata')

# Mark March 8th and March 22nd as holidays
filtered_march['Holiday'] = 'Other Days'
filtered_march.loc[filtered_march['Reading time'].dt.date.isin([march_8_date.date(), march_22_date.date()]), 'Holiday'] = 'Holiday'

# Set the style of seaborn for better aesthetics
sns.set(style="whitegrid")

# Plot the hourly consumption pattern
plt.figure(figsize=(12, 6))
sns.lineplot(x=filtered_march['Hour'], y=filtered_march['Difference'], hue=filtered_march['Holiday'], ci=None)
plt.title('Hourly Energy Consumption Pattern on Holidays and Other Days')
plt.xlabel('Hour of the Day')
plt.ylabel('Energy Consumption(kWh)')
plt.legend(title='Day Type')
plt.show()
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\3235516477.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\3235516477.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Holiday'] = 'Other Days'

# %%
import pandas as pd

# Assuming your DataFrame is named filtered_march

# Convert 'Reading time' to Timestamp with the same timezone
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Define the date for March 8th and March 22nd
march_8_date = pd.Timestamp('2023-03-08', tz='Asia/Kolkata')
march_22_date = pd.Timestamp('2023-03-22', tz='Asia/Kolkata')

# Mark March 8th and March 22nd as holidays
filtered_march['Holiday'] = 'Other Days'
filtered_march.loc[filtered_march['Reading time'].dt.date.isin([march_8_date.date(), march_22_date.date()]), 'Holiday'] = 'Holiday'

# Filter data for holidays only
holiday_data = filtered_march[filtered_march['Holiday'] == 'Holiday']

# Find the hour with the highest energy consumption on holidays
max_hour_holiday = holiday_data.loc[holiday_data['Difference'].idxmax()]['Hour']

# Display the result
print(f'Time of the day with the highest energy consumption on holidays: {max_hour_holiday} hours')
# Out:
# Time of the day with the highest energy consumption on holidays: 19 hours
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\1753797580.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\1753797580.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Holiday'] = 'Other Days'

# %%
# Resample the data on a daily basis and sum the 'Difference' values for each day
daily_df = filtered_march.resample('D', on='Reading time').sum()

# Calculate summary statistics for daily energy consumption
mean_daily_energy = daily_df['Difference'].mean()
median_daily_energy = daily_df['Difference'].median()
std_dev_daily_energy = daily_df['Difference'].std()

# Display the summary statistics for daily energy consumption
print(f'Mean Daily Energy Consumption: {mean_daily_energy}')
print(f'Median Daily Energy Consumption: {median_daily_energy}')
print(f'Standard Deviation of Daily Energy Consumption: {std_dev_daily_energy}')
# Out:
# Mean Daily Energy Consumption: 12.878064516129033
# Median Daily Energy Consumption: 12.149999999999864
# Standard Deviation of Daily Energy Consumption: 4.857588852750482

# %%
import pandas as pd

# Assuming your DataFrame is called 'filtered_march'

# Initialize variables
charging_sessions = 0
charging = False

# Iterate through the DataFrame
for index, row in filtered_march.iterrows():
    diff = row['Difference']
    
    # Check if the current value is greater than 0 and not currently charging
    if diff > 0 and not charging:
        charging_sessions += 1
        charging = True
    elif diff == 0 and charging:
        charging = False

# Print the result
print("Total number of charging sessions:", charging_sessions)
# Out:
# Total number of charging sessions: 230

# %%
import pandas as pd

# Assuming your DataFrame is called 'filtered_march'

# Initialize variables
charging_sessions = 0
charging = False
total_sessions_greater_than_025 = 0

# Iterate through the DataFrame
for index, row in filtered_march.iterrows():
    diff = row['Difference']
    
    # Check if the current value is greater than 0 and not currently charging
    if diff > 0 and not charging:
        charging_sessions += 1
        charging = True
        energy_in_session = diff
    elif diff > 0 and charging:
        energy_in_session += diff
    elif diff == 0 and charging:
        charging = False
        print(f"Energy consumption in session {charging_sessions}: {energy_in_session}")
        
        # Check if the energy consumption in the session is greater than 0.25
        if energy_in_session > 0.25:
            total_sessions_greater_than_025 += 1

# Check if the last session is still ongoing and if the total energy consumption in the session is greater than 0.25
if charging and energy_in_session > 0.25:
    print(f"Energy consumption in session {charging_sessions}: {energy_in_session}")
    total_sessions_greater_than_025 += 1

# Print the total number of sessions where energy consumption is greater than 0.25
print("Total number of sessions where energy consumption is greater than 0.25:", total_sessions_greater_than_025)
# Out:
# Energy consumption in session 1: 5.029999999999973
# Energy consumption in session 2: 0.009999999999990905
# Energy consumption in session 3: 0.009999999999990905
# Energy consumption in session 4: 0.009999999999990905
# Energy consumption in session 5: 5.680000000000064
# Energy consumption in session 6: 1.4099999999998545
# Energy consumption in session 7: 6.580000000000155
# Energy consumption in session 8: 0.009999999999990905
# Energy consumption in session 9: 0.009999999999990905
# Energy consumption in session 10: 0.009999999999990905
# Energy consumption in session 11: 0.009999999999990905
# Energy consumption in session 12: 0.009999999999990905
# Energy consumption in session 13: 5.009999999999991
# Energy consumption in session 14: 0.009999999999990905
# Energy consumption in session 15: 6.400000000000091
# Energy consumption in session 16: 0.009999999999990905
# Energy consumption in session 17: 0.009999999999990905
# Energy consumption in session 18: 0.2300000000000182
# Energy consumption in session 19: 1.8799999999998818
# Energy consumption in session 20: 0.009999999999990905
# Energy consumption in session 21: 0.009999999999990905
# Energy consumption in session 22: 0.7100000000000364
# Energy consumption in session 23: 2.8900000000001
# Energy consumption in session 24: 10.019999999999982
# Energy consumption in session 25: 5.369999999999891
# Energy consumption in session 26: 0.2400000000000091
# Energy consumption in session 27: 0.30999999999994543
# Energy consumption in session 28: 3.9200000000000728
# Energy consumption in session 29: 5.6400000000001
# Energy consumption in session 30: 0.009999999999990905
# Energy consumption in session 31: 0.009999999999990905
# Energy consumption in session 32: 0.009999999999990905
# Energy consumption in session 33: 0.009999999999990905
# Energy consumption in session 34: 0.32999999999992724
# Energy consumption in session 35: 1.2200000000000273
# Energy consumption in session 36: 0.12999999999988177
# Energy consumption in session 37: 1.8200000000001637
# Energy consumption in session 38: 0.009999999999990905
# Energy consumption in session 39: 0.4299999999998363
# Energy consumption in session 40: 4.110000000000127
# Energy consumption in session 41: 0.009999999999990905
# Energy consumption in session 42: 0.01999999999998181
# Energy consumption in session 43: 0.009999999999990905
# Energy consumption in session 44: 4.110000000000127
# Energy consumption in session 45: 0.009999999999990905
# Energy consumption in session 46: 0.3999999999998636
# Energy consumption in session 47: 2.5399999999999636
# Energy consumption in session 48: 1.3100000000001728
# Energy consumption in session 49: 3.979999999999791
# Energy consumption in session 50: 6.4500000000000455
# Energy consumption in session 51: 2.060000000000173
# Energy consumption in session 52: 10.419999999999845
# Energy consumption in session 53: 0.009999999999990905
# Energy consumption in session 54: 6.269999999999982
# Energy consumption in session 55: 0.5700000000001637
# Energy consumption in session 56: 0.4800000000000182
# Energy consumption in session 57: 3.7899999999999636
# Energy consumption in session 58: 4.619999999999891
# Energy consumption in session 59: 5.440000000000055
# Energy consumption in session 60: 12.519999999999982
# Energy consumption in session 61: 0.009999999999990905
# Energy consumption in session 62: 6.589999999999918
# Energy consumption in session 63: 3.0
# Energy consumption in session 64: 0.009999999999990905
# Energy consumption in session 65: 0.009999999999990905
# Energy consumption in session 66: 0.010000000000218279
# Energy consumption in session 67: 0.009999999999990905
# Energy consumption in session 68: 0.009999999999990905
# Energy consumption in session 69: 0.009999999999990905
# Energy consumption in session 70: 0.009999999999990905
# Energy consumption in session 71: 0.009999999999990905
# Energy consumption in session 72: 2.689999999999827
# Energy consumption in session 73: 5.2800000000002
# Energy consumption in session 74: 9.879999999999882
# Energy consumption in session 75: 0.009999999999990905
# Energy consumption in session 76: 0.009999999999990905
# Energy consumption in session 77: 1.7000000000000455
# Energy consumption in session 78: 3.4400000000000546
# Energy consumption in session 79: 0.5599999999999454
# Energy consumption in session 80: 0.5499999999999545
# Energy consumption in session 81: 0.2699999999999818
# Energy consumption in session 82: 0.2599999999999909
# Energy consumption in session 83: 0.2699999999999818
# Energy consumption in session 84: 9.710000000000036
# Energy consumption in session 85: 0.009999999999990905
# Energy consumption in session 86: 4.570000000000164
# Energy consumption in session 87: 0.009999999999990905
# Energy consumption in session 88: 0.5299999999999727
# Energy consumption in session 89: 0.4700000000000273
# Energy consumption in session 90: 6.309999999999945
# Energy consumption in session 91: 0.009999999999990905
# Energy consumption in session 92: 0.009999999999990905
# Energy consumption in session 93: 0.20000000000004547
# Energy consumption in session 94: 0.5199999999999818
# Energy consumption in session 95: 4.1599999999998545
# Energy consumption in session 96: 4.270000000000209
# Energy consumption in session 97: 0.009999999999990905
# Energy consumption in session 98: 0.009999999999990905
# Energy consumption in session 99: 0.009999999999990905
# Energy consumption in session 100: 0.009999999999990905
# Energy consumption in session 101: 0.009999999999990905
# Energy consumption in session 102: 4.470000000000027
# Energy consumption in session 103: 3.119999999999891
# Energy consumption in session 104: 0.009999999999990905
# Energy consumption in session 105: 2.8600000000001273
# Energy consumption in session 106: 5.019999999999982
# Energy consumption in session 107: 0.009999999999990905
# Energy consumption in session 108: 4.6099999999999
# Energy consumption in session 109: 0.75
# Energy consumption in session 110: 5.329999999999927
# Energy consumption in session 111: 0.009999999999990905
# Energy consumption in session 112: 0.13000000000010914
# Energy consumption in session 113: 0.009999999999990905
# Energy consumption in session 114: 0.009999999999990905
# Energy consumption in session 115: 0.34999999999990905
# Energy consumption in session 116: 0.75
# Energy consumption in session 117: 3.6200000000001182
# Energy consumption in session 118: 1.1700000000000728
# Energy consumption in session 119: 1.1099999999999
# Energy consumption in session 120: 4.569999999999936
# Energy consumption in session 121: 0.5099999999999909
# Energy consumption in session 122: 0.009999999999990905
# Energy consumption in session 123: 0.009999999999990905
# Energy consumption in session 124: 0.8600000000001273
# Energy consumption in session 125: 7.279999999999973
# Energy consumption in session 126: 0.2999999999999545
# Energy consumption in session 127: 4.809999999999945
# Energy consumption in session 128: 3.060000000000173
# Energy consumption in session 129: 0.10999999999989996
# Energy consumption in session 130: 4.240000000000009
# Energy consumption in session 131: 0.009999999999990905
# Energy consumption in session 132: 1.2999999999999545
# Energy consumption in session 133: 1.800000000000182
# Energy consumption in session 134: 0.5599999999999454
# Energy consumption in session 135: 0.16999999999984539
# Energy consumption in session 136: 0.2400000000000091
# Energy consumption in session 137: 0.20000000000004547
# Energy consumption in session 138: 0.2300000000000182
# Energy consumption in session 139: 3.2100000000000364
# Energy consumption in session 140: 3.230000000000018
# Energy consumption in session 141: 1.740000000000009
# Energy consumption in session 142: 1.6800000000000637
# Energy consumption in session 143: 2.9299999999998363
# Energy consumption in session 144: 0.5199999999999818
# Energy consumption in session 145: 0.540000000000191
# Energy consumption in session 146: 0.22999999999979082
# Energy consumption in session 147: 0.15000000000009095
# Energy consumption in session 148: 0.19000000000005457
# Energy consumption in session 149: 7.869999999999891
# Energy consumption in session 150: 0.009999999999990905
# Energy consumption in session 151: 0.009999999999990905
# Energy consumption in session 152: 0.38000000000010914
# Energy consumption in session 153: 0.5099999999999909
# Energy consumption in session 154: 0.20000000000004547
# Energy consumption in session 155: 0.5899999999999181
# Energy consumption in session 156: 3.8199999999999363
# Energy consumption in session 157: 0.009999999999990905
# Energy consumption in session 158: 0.009999999999990905
# Energy consumption in session 159: 5.430000000000064
# Energy consumption in session 160: 0.009999999999990905
# Energy consumption in session 161: 0.009999999999990905
# Energy consumption in session 162: 0.009999999999990905
# Energy consumption in session 163: 0.009999999999990905
# Energy consumption in session 164: 0.16000000000008185
# Energy consumption in session 165: 0.6800000000000637
# Energy consumption in session 166: 3.4199999999998454
# Energy consumption in session 167: 0.15000000000009095
# Energy consumption in session 168: 4.0
# Energy consumption in session 169: 0.009999999999990905
# Energy consumption in session 170: 0.009999999999990905
# Energy consumption in session 171: 1.2300000000000182
# Energy consumption in session 172: 0.44000000000005457
# Energy consumption in session 173: 0.2999999999999545
# Energy consumption in session 174: 0.20000000000004547
# Energy consumption in session 175: 0.8599999999999
# Energy consumption in session 176: 4.009999999999991
# Energy consumption in session 177: 0.009999999999990905
# Energy consumption in session 178: 0.009999999999990905
# Energy consumption in session 179: 0.009999999999990905
# Energy consumption in session 180: 0.75
# Energy consumption in session 181: 0.009999999999990905
# Energy consumption in session 182: 0.009999999999990905
# Energy consumption in session 183: 2.0
# Energy consumption in session 184: 2.880000000000109
# Energy consumption in session 185: 0.41000000000008185
# Energy consumption in session 186: 0.2899999999999636
# Energy consumption in session 187: 0.2899999999999636
# Energy consumption in session 188: 5.190000000000055
# Energy consumption in session 189: 0.5499999999999545
# Energy consumption in session 190: 5.129999999999882
# Energy consumption in session 191: 0.009999999999990905
# Energy consumption in session 192: 0.009999999999990905
# Energy consumption in session 193: 0.010000000000218279
# Energy consumption in session 194: 0.009999999999990905
# Energy consumption in session 195: 0.5499999999999545
# Energy consumption in session 196: 0.2300000000000182
# Energy consumption in session 197: 1.1799999999998363
# Energy consumption in session 198: 2.1700000000000728
# Energy consumption in session 199: 0.5699999999999363
# Energy consumption in session 200: 0.5199999999999818
# Energy consumption in session 201: 0.25
# Energy consumption in session 202: 0.19000000000005457
# Energy consumption in session 203: 0.22000000000002728
# Energy consumption in session 204: 7.190000000000055
# Energy consumption in session 205: 7.259999999999991
# Energy consumption in session 206: 0.5599999999999454
# Energy consumption in session 207: 0.25
# Energy consumption in session 208: 0.2999999999999545
# Energy consumption in session 209: 3.990000000000009
# Energy consumption in session 210: 4.6400000000001
# Energy consumption in session 211: 0.2599999999999909
# Energy consumption in session 212: 0.2400000000000091
# Energy consumption in session 213: 3.230000000000018
# Energy consumption in session 214: 0.009999999999990905
# Energy consumption in session 215: 0.30999999999994543
# Energy consumption in session 216: 0.4700000000000273
# Energy consumption in session 217: 1.0199999999999818
# Energy consumption in session 218: 1.6800000000000637
# Energy consumption in session 219: 1.2000000000000455
# Energy consumption in session 220: 0.009999999999990905
# Energy consumption in session 221: 2.6299999999998818
# Energy consumption in session 222: 3.3900000000001
# Energy consumption in session 223: 1.5199999999999818
# Energy consumption in session 224: 5.309999999999945
# Energy consumption in session 225: 1.6000000000001364
# Energy consumption in session 226: 0.2199999999997999
# Energy consumption in session 227: 0.2300000000000182
# Energy consumption in session 228: 0.5199999999999818
# Energy consumption in session 229: 11.710000000000036
# Energy consumption in session 230: 3.6400000000001
# Total number of sessions where energy consumption is greater than 0.25: 133

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense

# Assuming your DataFrame is called 'filtered_march'
# Make sure 'Reading time' column is in datetime format
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Extract relevant columns and set 'Reading time' as the index
df = filtered_march[['Reading time', 'Difference']].set_index('Reading time')

# Resample the data to hourly frequency and sum the energy consumption for each hour
hourly_energy = df.resample('H').sum()

# Normalize the data
scaler = MinMaxScaler()
scaled_energy = scaler.fit_transform(hourly_energy)

# Function to create time series dataset
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# Define the look-back period (number of previous hours to consider)
look_back = 24  # For example, using the past 24 hours to predict the next hour

# Create the dataset with the look-back period
X, Y = create_dataset(scaled_energy, look_back)

# Reshape the input data for LSTM
X = np.reshape(X, (X.shape[0], 1, X.shape[1]))

# Create and compile the LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(X, Y, epochs=50, batch_size=1, verbose=2)

# Forecast energy consumption for a single day
# Use the last 24 hours of available data to predict the next hour
last_24_hours = scaled_energy[-look_back:]
forecast_input = np.reshape(last_24_hours, (1, 1, look_back))
forecast = model.predict(forecast_input)

# Invert the forecast to get it in the original scale
forecast = scaler.inverse_transform(np.reshape(forecast, (forecast.shape[0], 1)))

print(f"Forecasted energy consumption for the next hour: {forecast[0][0]}")
# Out:
# WARNING:tensorflow:From C:\Users\et22m\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# C:\Users\et22m\AppData\Local\Temp\ipykernel_27100\1087053510.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])
# WARNING:tensorflow:From C:\Users\et22m\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\et22m\anaconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\et22m\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 712/712 - 7s - loss: 0.0490 - 7s/epoch - 9ms/step
# Epoch 2/50
# 712/712 - 3s - loss: 0.0400 - 3s/epoch - 4ms/step
# Epoch 3/50
# 712/712 - 3s - loss: 0.0380 - 3s/epoch - 4ms/step
# Epoch 4/50
# 712/712 - 3s - loss: 0.0367 - 3s/epoch - 4ms/step
# Epoch 5/50
# 712/712 - 3s - loss: 0.0361 - 3s/epoch - 4ms/step
# Epoch 6/50
# 712/712 - 3s - loss: 0.0356 - 3s/epoch - 4ms/step
# Epoch 7/50
# 712/712 - 3s - loss: 0.0356 - 3s/epoch - 4ms/step
# Epoch 8/50
# 712/712 - 3s - loss: 0.0352 - 3s/epoch - 4ms/step
# Epoch 9/50
# 712/712 - 3s - loss: 0.0343 - 3s/epoch - 4ms/step
# Epoch 10/50
# 712/712 - 3s - loss: 0.0342 - 3s/epoch - 4ms/step
# Epoch 11/50
# 712/712 - 3s - loss: 0.0331 - 3s/epoch - 4ms/step
# Epoch 12/50
# 712/712 - 3s - loss: 0.0330 - 3s/epoch - 4ms/step
# Epoch 13/50
# 712/712 - 3s - loss: 0.0326 - 3s/epoch - 4ms/step
# Epoch 14/50
# 712/712 - 3s - loss: 0.0324 - 3s/epoch - 4ms/step
# Epoch 15/50
# 712/712 - 3s - loss: 0.0319 - 3s/epoch - 4ms/step
# Epoch 16/50
# 712/712 - 3s - loss: 0.0317 - 3s/epoch - 4ms/step
# Epoch 17/50
# 712/712 - 3s - loss: 0.0307 - 3s/epoch - 4ms/step
# Epoch 18/50
# 712/712 - 3s - loss: 0.0305 - 3s/epoch - 4ms/step
# Epoch 19/50
# 712/712 - 4s - loss: 0.0300 - 4s/epoch - 5ms/step
# Epoch 20/50
# 712/712 - 3s - loss: 0.0304 - 3s/epoch - 4ms/step
# Epoch 21/50
# 712/712 - 3s - loss: 0.0300 - 3s/epoch - 5ms/step
# Epoch 22/50
# 712/712 - 3s - loss: 0.0294 - 3s/epoch - 4ms/step
# Epoch 23/50
# 712/712 - 3s - loss: 0.0295 - 3s/epoch - 4ms/step
# Epoch 24/50
# 712/712 - 3s - loss: 0.0291 - 3s/epoch - 4ms/step
# Epoch 25/50
# 712/712 - 3s - loss: 0.0285 - 3s/epoch - 4ms/step
# Epoch 26/50
# 712/712 - 3s - loss: 0.0282 - 3s/epoch - 4ms/step
# Epoch 27/50
# 712/712 - 3s - loss: 0.0279 - 3s/epoch - 4ms/step
# Epoch 28/50
# 712/712 - 3s - loss: 0.0282 - 3s/epoch - 4ms/step
# Epoch 29/50
# 712/712 - 3s - loss: 0.0270 - 3s/epoch - 4ms/step
# Epoch 30/50
# 712/712 - 3s - loss: 0.0275 - 3s/epoch - 4ms/step
# Epoch 31/50
# 712/712 - 3s - loss: 0.0274 - 3s/epoch - 4ms/step
# Epoch 32/50
# 712/712 - 3s - loss: 0.0266 - 3s/epoch - 4ms/step
# Epoch 33/50
# 712/712 - 3s - loss: 0.0268 - 3s/epoch - 4ms/step
# Epoch 34/50
# 712/712 - 3s - loss: 0.0264 - 3s/epoch - 4ms/step
# Epoch 35/50
# 712/712 - 3s - loss: 0.0254 - 3s/epoch - 5ms/step
# Epoch 36/50
# 712/712 - 3s - loss: 0.0256 - 3s/epoch - 4ms/step
# Epoch 37/50
# 712/712 - 3s - loss: 0.0255 - 3s/epoch - 4ms/step
# Epoch 38/50
# 712/712 - 3s - loss: 0.0249 - 3s/epoch - 4ms/step
# Epoch 39/50
# 712/712 - 3s - loss: 0.0245 - 3s/epoch - 5ms/step
# Epoch 40/50
# 712/712 - 3s - loss: 0.0243 - 3s/epoch - 5ms/step
# Epoch 41/50
# 712/712 - 3s - loss: 0.0243 - 3s/epoch - 4ms/step
# Epoch 42/50
# 712/712 - 3s - loss: 0.0234 - 3s/epoch - 5ms/step
# Epoch 43/50
# 712/712 - 3s - loss: 0.0237 - 3s/epoch - 5ms/step
# Epoch 44/50
# 712/712 - 3s - loss: 0.0229 - 3s/epoch - 4ms/step
# Epoch 45/50
# 712/712 - 3s - loss: 0.0231 - 3s/epoch - 4ms/step
# Epoch 46/50
# 712/712 - 3s - loss: 0.0227 - 3s/epoch - 5ms/step
# Epoch 47/50
# 712/712 - 3s - loss: 0.0220 - 3s/epoch - 5ms/step
# Epoch 48/50
# 712/712 - 3s - loss: 0.0220 - 3s/epoch - 5ms/step
# Epoch 49/50
# 712/712 - 3s - loss: 0.0215 - 3s/epoch - 5ms/step
# Epoch 50/50
# 712/712 - 3s - loss: 0.0210 - 3s/epoch - 5ms/step
# 1/1 [==============================] - 2s 2s/step
# Forecasted energy consumption for the next hour: 0.19802547991275787

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

# Assuming your DataFrame is called 'filtered_march'
# Make sure 'Reading time' column is in datetime format
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Extract relevant columns and set 'Reading time' as the index
df = filtered_march[['Reading time', 'Difference']].set_index('Reading time')

# Resample the data to daily frequency and sum the energy consumption for each day
daily_energy = df.resample('D').sum()

# Normalize the data
scaler = MinMaxScaler()
scaled_energy = scaler.fit_transform(daily_energy)

# Function to create time series dataset
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# Define the look-back period (number of previous days to consider)
look_back = 29  # Using the past 7 days to predict the next day

# Create the dataset with the look-back period
X, Y = create_dataset(scaled_energy, look_back)

# Reshape the input data for LSTM
X = np.reshape(X, (X.shape[0], 1, X.shape[1]))

# Create and compile the LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(X, Y, epochs=50, batch_size=1, verbose=2)

# Forecast energy consumption for the next day
last_week = scaled_energy[-look_back:]
forecast_input = np.reshape(last_week, (1, 1, look_back))
forecast = model.predict(forecast_input)

# Invert the forecast to get it in the original scale
forecast = scaler.inverse_transform(np.reshape(forecast, (forecast.shape[0], 1)))

print(f"Forecasted energy consumption for the next day: {forecast[0][0]}")

# Plotting the actual and forecasted values
plt.figure(figsize=(12, 6))
plt.plot(daily_energy.index, daily_energy, label='Actual')
plt.plot(daily_energy.index[-1] + pd.DateOffset(days=1), forecast[0], marker='o', color='red', label='Forecasted')
plt.xlabel('Date')
plt.ylabel('Energy Consumption')
plt.title('Actual vs Forecasted Energy Consumption for the Next Day')
plt.legend()
plt.show()
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_27100\1602007433.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])
# Epoch 1/50
# 2/2 - 3s - loss: 0.2147 - 3s/epoch - 2s/step
# Epoch 2/50
# 2/2 - 0s - loss: 0.1838 - 14ms/epoch - 7ms/step
# Epoch 3/50
# 2/2 - 0s - loss: 0.1361 - 16ms/epoch - 8ms/step
# Epoch 4/50
# 2/2 - 0s - loss: 0.1095 - 15ms/epoch - 7ms/step
# Epoch 5/50
# 2/2 - 0s - loss: 0.0889 - 16ms/epoch - 8ms/step
# Epoch 6/50
# 2/2 - 0s - loss: 0.0733 - 16ms/epoch - 8ms/step
# Epoch 7/50
# 2/2 - 0s - loss: 0.0712 - 17ms/epoch - 8ms/step
# Epoch 8/50
# 2/2 - 0s - loss: 0.0531 - 17ms/epoch - 8ms/step
# Epoch 9/50
# 2/2 - 0s - loss: 0.0467 - 16ms/epoch - 8ms/step
# Epoch 10/50
# 2/2 - 0s - loss: 0.0460 - 32ms/epoch - 16ms/step
# Epoch 11/50
# 2/2 - 0s - loss: 0.0401 - 13ms/epoch - 7ms/step
# Epoch 12/50
# 2/2 - 0s - loss: 0.0329 - 18ms/epoch - 9ms/step
# Epoch 13/50
# 2/2 - 0s - loss: 0.0286 - 16ms/epoch - 8ms/step
# Epoch 14/50
# 2/2 - 0s - loss: 0.0248 - 17ms/epoch - 8ms/step
# Epoch 15/50
# 2/2 - 0s - loss: 0.0207 - 17ms/epoch - 8ms/step
# Epoch 16/50
# 2/2 - 0s - loss: 0.0165 - 15ms/epoch - 8ms/step
# Epoch 17/50
# 2/2 - 0s - loss: 0.0131 - 17ms/epoch - 8ms/step
# Epoch 18/50
# 2/2 - 0s - loss: 0.0101 - 19ms/epoch - 10ms/step
# Epoch 19/50
# 2/2 - 0s - loss: 0.0075 - 14ms/epoch - 7ms/step
# Epoch 20/50
# 2/2 - 0s - loss: 0.0059 - 14ms/epoch - 7ms/step
# Epoch 21/50
# 2/2 - 0s - loss: 0.0036 - 14ms/epoch - 7ms/step
# Epoch 22/50
# 2/2 - 0s - loss: 0.0026 - 14ms/epoch - 7ms/step
# Epoch 23/50
# 2/2 - 0s - loss: 0.0015 - 14ms/epoch - 7ms/step
# Epoch 24/50
# 2/2 - 0s - loss: 8.8488e-04 - 14ms/epoch - 7ms/step
# Epoch 25/50
# 2/2 - 0s - loss: 5.2213e-04 - 16ms/epoch - 8ms/step
# Epoch 26/50
# 2/2 - 0s - loss: 2.9641e-04 - 16ms/epoch - 8ms/step
# Epoch 27/50
# 2/2 - 0s - loss: 1.9312e-04 - 13ms/epoch - 7ms/step
# Epoch 28/50
# 2/2 - 0s - loss: 2.3042e-04 - 16ms/epoch - 8ms/step
# Epoch 29/50
# 2/2 - 0s - loss: 1.5633e-04 - 15ms/epoch - 8ms/step
# Epoch 30/50
# 2/2 - 0s - loss: 1.6573e-04 - 15ms/epoch - 8ms/step
# Epoch 31/50
# 2/2 - 0s - loss: 1.7828e-04 - 15ms/epoch - 8ms/step
# Epoch 32/50
# 2/2 - 0s - loss: 1.7241e-04 - 15ms/epoch - 8ms/step
# Epoch 33/50
# 2/2 - 0s - loss: 2.0759e-04 - 16ms/epoch - 8ms/step
# Epoch 34/50
# 2/2 - 0s - loss: 2.1223e-04 - 15ms/epoch - 7ms/step
# Epoch 35/50
# 2/2 - 0s - loss: 1.8628e-04 - 16ms/epoch - 8ms/step
# Epoch 36/50
# 2/2 - 0s - loss: 1.8538e-04 - 14ms/epoch - 7ms/step
# Epoch 37/50
# 2/2 - 0s - loss: 1.7610e-04 - 15ms/epoch - 8ms/step
# Epoch 38/50
# 2/2 - 0s - loss: 1.5870e-04 - 18ms/epoch - 9ms/step
# Epoch 39/50
# 2/2 - 0s - loss: 1.3308e-04 - 16ms/epoch - 8ms/step
# Epoch 40/50
# 2/2 - 0s - loss: 1.1308e-04 - 16ms/epoch - 8ms/step
# Epoch 41/50
# 2/2 - 0s - loss: 8.3881e-05 - 18ms/epoch - 9ms/step
# Epoch 42/50
# 2/2 - 0s - loss: 4.9305e-05 - 17ms/epoch - 9ms/step
# Epoch 43/50
# 2/2 - 0s - loss: 3.7636e-05 - 24ms/epoch - 12ms/step
# Epoch 44/50
# 2/2 - 0s - loss: 2.0896e-05 - 15ms/epoch - 8ms/step
# Epoch 45/50
# 2/2 - 0s - loss: 7.2930e-06 - 15ms/epoch - 7ms/step
# Epoch 46/50
# 2/2 - 0s - loss: 2.9886e-06 - 15ms/epoch - 8ms/step
# Epoch 47/50
# 2/2 - 0s - loss: 1.3155e-06 - 14ms/epoch - 7ms/step
# Epoch 48/50
# 2/2 - 0s - loss: 1.5460e-06 - 14ms/epoch - 7ms/step
# Epoch 49/50
# 2/2 - 0s - loss: 1.4565e-06 - 15ms/epoch - 7ms/step
# Epoch 50/50
# 2/2 - 0s - loss: 2.4206e-06 - 15ms/epoch - 8ms/step
# 1/1 [==============================] - 1s 928ms/step
# Forecasted energy consumption for the next day: 9.774789810180664

# %%
filtered_march['Power'] = filtered_march['Difference'] / 0.25
total_power_consumption = filtered_march["Power"].sum()
total_power_consumption
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_27100\2308266882.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Power'] = filtered_march['Difference'] / 0.25
# 1596.88

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df' with columns: 'reading_time', 'Difference', 'Power(kW)'
# You may need to load your actual dataset using pd.read_csv or another appropriate method.
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Extract date from the timestamp
filtered_march['date'] = filtered_march['Reading time'].dt.date

# Calculate average and peak load for each day
daily_load = filtered_march.groupby('date')['Power'].agg(['mean', 'max'])

# Calculate load factor for each day
daily_load['load_factor'] = (daily_load['mean'] / daily_load['max']) * 100
print("Load Factor for Each Day:")
print(daily_load[['load_factor']])

# Plot the graph with improved aesthetics
plt.figure(figsize=(10, 6))
plt.plot(daily_load.index, daily_load['load_factor'], marker='o', linestyle='-', color='b', label='Load Factor')
plt.title('Daily Load Factor')
plt.xlabel('Date')
plt.ylabel('Load Factor (%)')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
day_labels = ['Day {}'.format(i + 1) for i in range(len(daily_load))]
plt.xticks(daily_load.index, day_labels, rotation=45)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_27100\1486217540.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])
# C:\Users\et22m\AppData\Local\Temp\ipykernel_27100\1486217540.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['date'] = filtered_march['Reading time'].dt.date
# Load Factor for Each Day:
#             load_factor
# date
# 2023-03-01    13.464096
# 2023-03-02    19.204344
# 2023-03-03     7.169770
# 2023-03-04    22.007979
# 2023-03-05    10.660461
# 2023-03-06    13.874113
# 2023-03-07    16.263021
# 2023-03-08    23.869681
# 2023-03-09    11.148050
# 2023-03-10    10.478220
# 2023-03-11    11.410974
# 2023-03-12    28.984375
# 2023-03-13    14.882535
# 2023-03-14     6.807171
# 2023-03-15     9.266169
# 2023-03-16    15.002264
# 2023-03-17    13.757253
# 2023-03-18     7.880435
# 2023-03-19    16.891012
# 2023-03-20    13.234649
# 2023-03-21     7.696759
# 2023-03-22    16.398810
# 2023-03-23    11.311849
# 2023-03-24    18.161553
# 2023-03-25    12.071078
# 2023-03-26    21.290650
# 2023-03-27    15.586890
# 2023-03-28    27.400915
# 2023-03-29    15.964755
# 2023-03-30     7.319079
# 2023-03-31    27.677014

# %%
# Convert 'reading_time' column to datetime format
filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])

# Define tariff rates
tariff_rates = {
    'off-peak': 10,
    'peak': 20,
    'mid-peak': 15,
    'high-peak': 25
}

# Function to determine the tariff based on the time of day
def get_tariff(reading_time):
    hour = reading_time.hour
    if 23 <= hour or hour < 6:
        return 'off-peak'
    elif 7 <= hour < 11:
        return 'peak'
    elif 11 <= hour < 19:
        return 'mid-peak'
    else:
        return 'high-peak'

# Apply the get_tariff function to each row to get the tariff for each reading
filtered_march['tariff'] = filtered_march['Reading time'].apply(get_tariff)

# Calculate the price for each 15-minute interval
filtered_march['evprice'] = filtered_march.apply(lambda row: row['Difference'] * tariff_rates[row['tariff']], axis=1)
# Out:
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\2117728619.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['Reading time'] = pd.to_datetime(filtered_march['Reading time'])
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\2117728619.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['tariff'] = filtered_march['Reading time'].apply(get_tariff)
# C:\Users\et22m\AppData\Local\Temp\ipykernel_12340\2117728619.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_march['evprice'] = filtered_march.apply(lambda row: row['Difference'] * tariff_rates[row['tariff']], axis=1)

# %%
# Calculate the total of the 'price' column
total_price = filtered_march['evprice'].sum()
total_energy = filtered_march['Difference'].sum()
# Print the total
print(f"Total Energy :{round(total_energy,2)} Units")
print("Total Price Rs:", round(total_price,2))
# Out:
# Total Energy :399.22 Units
# Total Price Rs: 6519.1
